# %% [markdown]
# ## Notebook for formatting data frames for phase association
# Source:
# - https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file
# - https://www.usgs.gov/software/hypoinverse-earthquake-location
# - https://chatgpt.com/c/67491af9-aaf8-800c-82e9-1033e094d8d0
# - https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2017JB014966

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from pnwstore.mseed import WaveformClient
from obspy import UTCDateTime
from obspy.core.stream import Stream
from obspy.clients.fdsn import Client
from tqdm import tqdm
import datetime

# %% [markdown]
# ### 1.3 Create a CSV file for picks for the association

# %% [markdown]
# ### Format the files for HypoInverse and HypoDD
# References: https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file

# %% [markdown]
# ### Format the station files

# %%
region = 'or_shore'
df = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)

# %%
TOFB = df[df['station_code']=='TOFB']

# %%
TOFB['station_network_code'].unique()
# Out:
# array([], dtype=object)

# %%
from obspy import read_inventory
from collections import defaultdict
import pandas as pd

client2 = Client("IRIS")
networks = pd.read_csv("../data/networks.csv")
networks = ','.join(list(networks['networks']))
starttime = UTCDateTime(year=2011, month=1, day=1)
endtime = UTCDateTime(year=2016, month=1, day=1)
inv = [] 
# inv = read_inventory("./stations/*.xml")
station_locs = defaultdict(dict)
# stations=inv


for station in df['station_code'].unique():
    inv += client2.get_stations(network=networks,
                                    station=station, channel="?H?", 
                                    starttime=starttime, endtime=endtime, level="response")
stations=inv

print(len(stations))

for network in stations:
    print(network)
    for station in network:
        print(station)
        has_HH = bool(station.select(channel="HH?"))
        has_BH = bool(station.select(channel="BH?"))

        # Apply selection logic based on channel presence
        if has_HH and has_BH:
            # If both HH and BH channels are present, select only HH
            selected_station = station.select(channel="HH?")
        elif has_HH:
            # If only HH channels are present
            selected_station = station.select(channel="HH?")
        elif has_BH:
            # If only BH channels are present
            selected_station = station.select(channel="BH?")

        for chn in selected_station:
            print('This is chn: ', chn)
            sid = f"{network.code}.{station.code}.{chn.location_code}.{chn.code[:-1]}"
            if sid in station_locs:
                station_locs[sid]["component"] += f",{chn.code[-1]}"
                station_locs[sid]["response"] += f",{chn.response.instrument_sensitivity.value:.2f}"
            else:
                component = f"{chn.code[-1]}"
                response = f"{chn.response.instrument_sensitivity.value:.2f}"
                dtype = chn.response.instrument_sensitivity.input_units.lower()
                tmp_dict = {}
                tmp_dict["longitude"], tmp_dict["latitude"], tmp_dict["elevation(m)"] = (
                    chn.longitude,
                    chn.latitude,
                    chn.elevation,
                )
                tmp_dict["component"], tmp_dict["response"], tmp_dict["unit"] = component, response, dtype
                station_locs[sid] = tmp_dict
            if station_locs[sid]["component"]=='Z':
                station_locs[sid]["response"]= f"0,0,"+station_locs[sid]["response"]
            elif station_locs[sid]["component"]=='N,Z':
                station_locs[sid]["response"]= f"0,"+station_locs[sid]["response"]
station_locs = pd.DataFrame.from_dict(station_locs, orient='index')
station_locs["id"] = station_locs.index
station_locs = station_locs.rename_axis('station').reset_index()
station_locs.to_csv(f"./stations_{region}.csv",sep='\t')
station_locs
# Out:
# 15
# Network UW (Pacific Northwest Seismic Network (PNSN))
# 	Station Count: 1/876 (Selected/Total)
# 	1963-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			UW.TAKO (Reedsport, OR, USA)
# 		Channels (3):
# 			UW.TAKO..BHZ, UW.TAKO..BHN, UW.TAKO..BHE
# Station TAKO (Reedsport, OR, USA)
# 	Station Code: TAKO
# 	Channel Count: 3/39 (Selected/Total)
# 	2001-10-24T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 43.7431, Longitude: -124.0834, Elevation: 12.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    50.0 Hz  2001-10-24 to 2012-12-14
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2001-10-24T00:00:00.000000Z - 2012-12-14T00:00:00.000000Z
# 	Latitude: 43.7433, Longitude: -124.0825, Elevation: 46.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (CMG-40T,Velocity Sensor,GURALP)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2001-10-24T00:00:00.000000Z - 2012-12-14T00:00:00.000000Z
# 	Latitude: 43.7433, Longitude: -124.0825, Elevation: 46.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (CMG-40T,Velocity Sensor,GURALP)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2001-10-24T00:00:00.000000Z - 2012-12-14T00:00:00.000000Z
# 	Latitude: 43.7433, Longitude: -124.0825, Elevation: 46.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (CMG-40T,Velocity Sensor,GURALP)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J41A (LDEO Trawl-Resistant OBS Site J41A)
# 		Channels (3):
# 			7D.J41A..HHZ, 7D.J41A..HH1, 7D.J41A..HH2
# Station J41A (LDEO Trawl-Resistant OBS Site J41A)
# 	Station Code: J41A
# 	Channel Count: 3/5 (Selected/Total)
# 	2011-07-25T00:00:00.000000Z - 2012-07-13T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.8119, Longitude: -124.5372, Elevation: -175.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-07-25 to 2012-07-13
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-07-25T18:08:00.000000Z - 2012-07-13T03:53:33.000000Z
# 	Latitude: 45.8119, Longitude: -124.5372, Elevation: -175.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-07-25T18:08:00.000000Z - 2012-07-13T03:53:33.000000Z
# 	Latitude: 45.8119, Longitude: -124.5372, Elevation: -175.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-07-25T18:08:00.000000Z - 2012-07-13T03:53:33.000000Z
# 	Latitude: 45.8119, Longitude: -124.5372, Elevation: -175.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J41A (Loganville, WI, USA)
# 		Channels (12):
# 			TA.J41A..BHZ, TA.J41A..BHN, TA.J41A..BHE, TA.J41A..LHZ,
# 			TA.J41A..LHN, TA.J41A..LHE, TA.J41A..UHZ, TA.J41A..UHN,
# 			TA.J41A..UHE, TA.J41A..VHZ, TA.J41A..VHN, TA.J41A..VHE
# Station J41A (Loganville, WI, USA)
# 	Station Code: J41A
# 	Channel Count: 12/40 (Selected/Total)
# 	2011-06-16T00:00:00.000000Z - 2013-06-06T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.3655, Longitude: -90.0137, Elevation: 360.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    40.0 Hz  2011-06-16 to 2013-06-06
# 	    ..LH[ZNE]     1.0 Hz  2011-06-16 to 2013-06-06
# 	    ..VH[ZNE]     0.1 Hz  2011-06-16 to 2013-06-06
# 	    ..UH[ZNE]     0.0 Hz  2011-06-16 to 2013-06-06
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2011-06-16T00:00:00.000000Z - 2013-06-06T20:20:00.000000Z
# 	Latitude: 43.3655, Longitude: -90.0137, Elevation: 360.0 m, Local Depth: 0.0 m
# 	Azimuth: 89.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2011-06-16T00:00:00.000000Z - 2013-06-06T20:20:00.000000Z
# 	Latitude: 43.3655, Longitude: -90.0137, Elevation: 360.0 m, Local Depth: 0.0 m
# 	Azimuth: 359.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-06-16T00:00:00.000000Z - 2013-06-06T20:20:00.000000Z
# 	Latitude: 43.3655, Longitude: -90.0137, Elevation: 360.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J33A (SIO OBS ID J33A)
# 		Channels (3):
# 			7D.J33A..BHZ, 7D.J33A..BH1, 7D.J33A..BH2
# Station J33A (SIO OBS ID J33A)
# 	Station Code: J33A
# 	Channel Count: 3/4 (Selected/Total)
# 	2011-10-16T00:00:00.000000Z - 2012-07-19T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.1066, Longitude: -124.5708, Elevation: -348.7 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-10-16 to 2012-07-19
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-10-16T04:07:00.000000Z - 2012-07-19T08:41:00.000000Z
# 	Latitude: 45.1066, Longitude: -124.5708, Elevation: -348.7 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-10-16T04:07:00.000000Z - 2012-07-19T08:41:00.000000Z
# 	Latitude: 45.1066, Longitude: -124.5708, Elevation: -348.7 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-16T04:07:00.000000Z - 2012-07-19T08:41:00.000000Z
# 	Latitude: 45.1066, Longitude: -124.5708, Elevation: -348.7 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J33A (Davis, SD, USA)
# 		Channels (12):
# 			TA.J33A..BHZ, TA.J33A..BHN, TA.J33A..BHE, TA.J33A..LHZ,
# 			TA.J33A..LHN, TA.J33A..LHE, TA.J33A..UHZ, TA.J33A..UHN,
# 			TA.J33A..UHE, TA.J33A..VHZ, TA.J33A..VHN, TA.J33A..VHE
# Station J33A (Davis, SD, USA)
# 	Station Code: J33A
# 	Channel Count: 12/36 (Selected/Total)
# 	2010-07-27T00:00:00.000000Z - 2012-05-17T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.3185, Longitude: -96.9667, Elevation: 400.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    40.0 Hz  2010-07-27 to 2012-05-17
# 	    ..LH[ZNE]     1.0 Hz  2010-07-27 to 2012-05-17
# 	    ..VH[ZNE]     0.1 Hz  2010-07-27 to 2012-05-17
# 	    ..UH[ZNE]     0.0 Hz  2010-07-27 to 2012-05-17
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2010-07-27T00:00:00.000000Z - 2012-05-17T14:35:00.000000Z
# 	Latitude: 43.3185, Longitude: -96.9667, Elevation: 400.0 m, Local Depth: 0.0 m
# 	Azimuth: 89.20 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2010-07-27T00:00:00.000000Z - 2012-05-17T14:35:00.000000Z
# 	Latitude: 43.3185, Longitude: -96.9667, Elevation: 400.0 m, Local Depth: 0.0 m
# 	Azimuth: 359.20 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-27T00:00:00.000000Z - 2012-05-17T14:35:00.000000Z
# 	Latitude: 43.3185, Longitude: -96.9667, Elevation: 400.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J25A (SIO OBS ID J25A)
# 		Channels (3):
# 			7D.J25A..BHZ, 7D.J25A..BH1, 7D.J25A..BH2
# Station J25A (SIO OBS ID J25A)
# 	Station Code: J25A
# 	Channel Count: 3/4 (Selected/Total)
# 	2011-10-21T00:00:00.000000Z - 2012-07-18T23:59:59.000000Z
# 	Access: open
# 	Latitude: 44.4729, Longitude: -124.6216, Elevation: -142.8 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-10-21 to 2012-07-18
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-10-21T04:26:00.000000Z - 2012-07-18T23:06:00.000000Z
# 	Latitude: 44.4729, Longitude: -124.6216, Elevation: -142.8 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-10-21T04:26:00.000000Z - 2012-07-18T23:06:00.000000Z
# 	Latitude: 44.4729, Longitude: -124.6216, Elevation: -142.8 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-21T04:26:00.000000Z - 2012-07-18T23:06:00.000000Z
# 	Latitude: 44.4729, Longitude: -124.6216, Elevation: -142.8 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J25A (Sunshine Ranch, Edgemont, SD, USA)
# 		Channels (12):
# 			TA.J25A..BHZ, TA.J25A..BHN, TA.J25A..BHE, TA.J25A..LHZ,
# 			TA.J25A..LHN, TA.J25A..LHE, TA.J25A..UHZ, TA.J25A..UHN,
# 			TA.J25A..UHE, TA.J25A..VHZ, TA.J25A..VHN, TA.J25A..VHE
# Station J25A (Sunshine Ranch, Edgemont, SD, USA)
# 	Station Code: J25A
# 	Channel Count: 12/30 (Selected/Total)
# 	2009-06-06T00:00:00.000000Z - 2011-05-10T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.3901, Longitude: -103.8026, Elevation: 1220.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    40.0 Hz  2009-06-06 to 2011-05-10
# 	    ..LH[ZNE]     1.0 Hz  2009-06-06 to 2011-05-10
# 	    ..VH[ZNE]     0.1 Hz  2009-06-06 to 2011-05-10
# 	    ..UH[ZNE]     0.0 Hz  2009-06-06 to 2011-05-10
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2009-06-06T00:00:00.000000Z - 2011-05-10T18:05:00.000000Z
# 	Latitude: 43.3901, Longitude: -103.8026, Elevation: 1220.0 m, Local Depth: 0.0 m
# 	Azimuth: 89.30 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2009-06-06T00:00:00.000000Z - 2011-05-10T18:05:00.000000Z
# 	Latitude: 43.3901, Longitude: -103.8026, Elevation: 1220.0 m, Local Depth: 0.0 m
# 	Azimuth: 359.30 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2009-06-06T00:00:00.000000Z - 2011-05-10T18:05:00.000000Z
# 	Latitude: 43.3901, Longitude: -103.8026, Elevation: 1220.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J33B (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.J33B..HHZ, 7D.J33B..HH1, 7D.J33B..HH2
# Station J33B (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: J33B
# 	Channel Count: 3/5 (Selected/Total)
# 	2012-07-14T00:00:00.000000Z - 2013-06-26T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.1066, Longitude: -124.5706, Elevation: -350.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2012-07-15 to 2013-06-26
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2012-07-15T06:24:00.000000Z - 2013-06-26T21:27:00.000000Z
# 	Latitude: 45.1066, Longitude: -124.5706, Elevation: -350.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2012-07-15T06:24:00.000000Z - 2013-06-26T21:27:00.000000Z
# 	Latitude: 45.1066, Longitude: -124.5706, Elevation: -350.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2012-07-15T06:24:00.000000Z - 2013-06-26T21:27:00.000000Z
# 	Latitude: 45.1066, Longitude: -124.5706, Elevation: -350.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J25B (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.J25B..HHZ, 7D.J25B..HH1, 7D.J25B..HH2
# Station J25B (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: J25B
# 	Channel Count: 3/3 (Selected/Total)
# 	2012-07-15T00:00:00.000000Z - 2013-06-27T23:59:59.000000Z
# 	Access: open
# 	Latitude: 44.4713, Longitude: -124.6217, Elevation: -147.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2012-07-15 to 2013-06-27
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2012-07-15T19:35:00.000000Z - 2013-06-27T18:41:00.000000Z
# 	Latitude: 44.4713, Longitude: -124.6217, Elevation: -147.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2012-07-15T19:35:00.000000Z - 2013-06-27T18:41:00.000000Z
# 	Latitude: 44.4713, Longitude: -124.6217, Elevation: -147.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2012-07-15T19:35:00.000000Z - 2013-06-27T18:41:00.000000Z
# 	Latitude: 44.4713, Longitude: -124.6217, Elevation: -147.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J17B (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.J17B..HHZ, 7D.J17B..HH1, 7D.J17B..HH2
# Station J17B (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: J17B
# 	Channel Count: 3/5 (Selected/Total)
# 	2012-07-16T00:00:00.000000Z - 2013-06-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.7900, Longitude: -124.6148, Elevation: -286.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2012-07-16 to 2013-06-28
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2012-07-16T13:35:00.000000Z - 2013-06-28T17:35:00.000000Z
# 	Latitude: 43.7900, Longitude: -124.6148, Elevation: -286.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2012-07-16T13:35:00.000000Z - 2013-06-28T17:35:00.000000Z
# 	Latitude: 43.7900, Longitude: -124.6148, Elevation: -286.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2012-07-16T13:35:00.000000Z - 2013-06-28T17:35:00.000000Z
# 	Latitude: 43.7900, Longitude: -124.6148, Elevation: -286.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J25C (SIO OBS ID J25C)
# 		Channels (3):
# 			7D.J25C..BHZ, 7D.J25C..BH1, 7D.J25C..BH2
# Station J25C (SIO OBS ID J25C)
# 	Station Code: J25C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-22T00:00:00.000000Z - 2014-06-01T23:59:59.000000Z
# 	Access: open
# 	Latitude: 44.4730, Longitude: -124.6217, Elevation: -144.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-22 to 2014-06-01
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-22T03:28:00.000000Z - 2014-06-01T17:43:56.000000Z
# 	Latitude: 44.4730, Longitude: -124.6217, Elevation: -144.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-22T03:28:00.000000Z - 2014-06-01T17:43:56.000000Z
# 	Latitude: 44.4730, Longitude: -124.6217, Elevation: -144.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-22T03:28:00.000000Z - 2014-06-01T17:43:56.000000Z
# 	Latitude: 44.4730, Longitude: -124.6217, Elevation: -144.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J33C (SIO OBS ID J33C)
# 		Channels (3):
# 			7D.J33C..BHZ, 7D.J33C..BH1, 7D.J33C..BH2
# Station J33C (SIO OBS ID J33C)
# 	Station Code: J33C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-22T00:00:00.000000Z - 2014-05-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.1068, Longitude: -124.5708, Elevation: -354.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-22 to 2014-05-29
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-22T03:44:00.000000Z - 2014-05-29T00:34:00.000000Z
# 	Latitude: 45.1068, Longitude: -124.5708, Elevation: -354.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-22T03:44:00.000000Z - 2014-05-29T00:34:00.000000Z
# 	Latitude: 45.1068, Longitude: -124.5708, Elevation: -354.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-22T03:44:00.000000Z - 2014-05-29T00:34:00.000000Z
# 	Latitude: 45.1068, Longitude: -124.5708, Elevation: -354.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J41C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.J41C..HHZ, 7D.J41C..HH1, 7D.J41C..HH2
# Station J41C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: J41C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-08-30T00:00:00.000000Z - 2014-06-24T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.8117, Longitude: -124.5376, Elevation: -171.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-08-30 to 2014-06-24
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-08-30T18:52:00.000000Z - 2014-06-24T21:54:54.000000Z
# 	Latitude: 45.8117, Longitude: -124.5376, Elevation: -171.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-08-30T18:52:00.000000Z - 2014-06-24T21:54:54.000000Z
# 	Latitude: 45.8117, Longitude: -124.5376, Elevation: -171.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-08-30T18:52:00.000000Z - 2014-06-24T21:54:54.000000Z
# 	Latitude: 45.8117, Longitude: -124.5376, Elevation: -171.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J17D (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.J17D..HHZ, 7D.J17D..HH1, 7D.J17D..HH2
# Station J17D (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: J17D
# 	Channel Count: 3/9 (Selected/Total)
# 	2014-09-09T00:00:00.000000Z - 2015-10-03T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.7873, Longitude: -124.6134, Elevation: -285.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2014-09-09 to 2015-09-04
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2014-09-09T03:56:20.000000Z - 2015-09-04T23:12:23.000000Z
# 	Latitude: 43.7873, Longitude: -124.6134, Elevation: -285.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2014-09-09T03:56:20.000000Z - 2015-09-04T23:12:23.000000Z
# 	Latitude: 43.7873, Longitude: -124.6134, Elevation: -285.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-09-09T03:56:20.000000Z - 2015-09-04T23:12:23.000000Z
# 	Latitude: 43.7873, Longitude: -124.6134, Elevation: -285.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J25D (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.J25D..HHZ, 7D.J25D..HH1, 7D.J25D..HH2
# Station J25D (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: J25D
# 	Channel Count: 3/9 (Selected/Total)
# 	2014-09-21T00:00:00.000000Z - 2015-10-01T23:59:59.000000Z
# 	Access: open
# 	Latitude: 44.4567, Longitude: -124.6310, Elevation: -136.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2014-09-21 to 2015-09-17
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2014-09-21T16:55:50.000000Z - 2015-09-17T12:46:30.000000Z
# 	Latitude: 44.4567, Longitude: -124.6310, Elevation: -136.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2014-09-21T16:55:50.000000Z - 2015-09-17T12:46:30.000000Z
# 	Latitude: 44.4567, Longitude: -124.6310, Elevation: -136.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-09-21T16:55:50.000000Z - 2015-09-17T12:46:30.000000Z
# 	Latitude: 44.4567, Longitude: -124.6310, Elevation: -136.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
#         station   longitude   latitude  elevation(m) component  \
# 0   UW.TAKO..BH -124.082474  43.743340          46.0     E,N,Z
# 1   7D.J41A..HH -124.537201  45.811901        -175.0     1,2,Z
# 2   TA.J41A..BH  -90.013702  43.365501         360.0     E,N,Z
# 3   7D.J33A..BH -124.570801  45.106602        -348.7     1,2,Z
# 4   TA.J33A..BH  -96.966698  43.318501         400.0     E,N,Z
# 5   7D.J25A..BH -124.621597  44.472900        -142.8     1,2,Z
# 6   TA.J25A..BH -103.802597  43.390099        1220.0     E,N,Z
# 7   7D.J33B..HH -124.570602  45.106602        -350.0     1,2,Z
# 8   7D.J25B..HH -124.621696  44.471298        -147.0     1,2,Z
# 9   7D.J17B..HH -124.614799  43.790001        -286.0     1,2,Z
# 10  7D.J25C..BH -124.621696  44.473000        -144.0     1,2,Z
# 11  7D.J33C..BH -124.570801  45.106800        -354.0     1,2,Z
# 12  7D.J41C..HH -124.537598  45.811699        -171.0     1,2,Z
# 13  7D.J17D..HH -124.613403  43.787300        -285.0     1,2,Z
# 14  7D.J25D..HH -124.630997  44.456699        -136.0     1,2,Z
#
#                                      response unit           id
# 0      419430000.00,419430000.00,419430000.00  m/s  UW.TAKO..BH
# 1      971188000.00,971188000.00,971188000.00  m/s  7D.J41A..HH
# 2      627192000.00,627192000.00,627192000.00  m/s  TA.J41A..BH
# 3   1846390000.00,1846390000.00,1846390000.00  m/s  7D.J33A..BH
# 4      627192000.00,627192000.00,627192000.00  m/s  TA.J33A..BH
# 5   1846390000.00,1846390000.00,1846390000.00  m/s  7D.J25A..BH
# 6      627192000.00,627192000.00,627192000.00  m/s  TA.J25A..BH
# 7      971188000.00,971188000.00,971188000.00  m/s  7D.J33B..HH
# 8      971188000.00,971188000.00,971188000.00  m/s  7D.J25B..HH
# 9      971188000.00,971188000.00,971188000.00  m/s  7D.J17B..HH
# 10  1846390000.00,1846390000.00,1846390000.00  m/s  7D.J25C..BH
# 11  1846390000.00,1846390000.00,1846390000.00  m/s  7D.J33C..BH
# 12     971188000.00,971188000.00,971188000.00  m/s  7D.J41C..HH
# 13     250883000.00,250883000.00,250883000.00  m/s  7D.J17D..HH
# 14        35122500.00,35122500.00,35122500.00  m/s  7D.J25D..HH

# %% [markdown]
# ### Convert the station file from a CSV file to dat files

# %%
stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
converted_hypoinverse = []
converted_hypoDD = {}

for i in tqdm(range(len(stations))):

    network_code, station_code, comp_code, channel_code = stations.iloc[i]['station'].split('.')
    station_weight = " "
    lat_degree = int(stations.iloc[i]['latitude'])
    lat_minute = (stations.iloc[i]['latitude'] - lat_degree) * 60
    north = "N" if lat_degree >= 0 else "S"
    lng_degree = int(stations.iloc[i]['longitude'])
    lng_minute = (stations.iloc[i]['longitude'] - lng_degree) * 60
    west = "W" if lng_degree <= 0 else "E"
    elevation = stations.iloc[i]['elevation(m)']
    line_hypoinverse = f"{station_code:<5} {network_code:<2} {comp_code[:-1]:<1}{channel_code:<3} {station_weight}{abs(lat_degree):2.0f} {abs(lat_minute):7.4f}{north}{abs(lng_degree):3.0f} {abs(lng_minute):7.4f}{west}{elevation:4.0f}\n"
    converted_hypoinverse.append(line_hypoinverse)
    converted_hypoDD[f"{station_code}"] = f"{network_code:<2}{station_code:<5} {stations.iloc[i]['latitude']:.3f} {stations.iloc[i]['longitude']:.3f} {elevation:4.0f}\n"

out_file = f'stations_hypoinverse_{region}.dat'
with open(out_file, 'w') as f:
    f.writelines(converted_hypoinverse)

out_file = f'stations_hypoDD_{region}.dat'
with open(out_file, 'w') as f:
    for k, v in converted_hypoDD.items():
        f.write(v)
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 5335.36it/s]

# %% [markdown]
# ### Format the pick files

# %%
# Load necessary files
# Load all event data into a list of DataFrames
import datetime 
pick_assignment_files = [
    f'../data/datasets_{region}/all_pick_assignments_{region}.csv'
]

# Read all event files into DataFrames
dfs = [pd.read_csv(file, index_col=0) for file in pick_assignment_files]

# Concatenate all DataFrames into a single DataFrame
assignments =  pd.concat(dfs)

assignments = assignments.rename(columns={"time": "origin_time"})
assignments['origin_time'] = pd.to_datetime(assignments['origin_time'], utc = True)
assignments["pick_time"] = assignments["time_pick"].apply(datetime.datetime.fromtimestamp, tz=datetime.timezone.utc)
assignments = assignments.sort_values(by='origin_time').reset_index(drop=True)

# Reset the idx column so that each group with the same 'time' has a new numbered event index
assignments['idx'] = assignments.groupby('origin_time').ngroup()


# picks = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)
# picks = picks.sort_values(by='trace_start_time').reset_index(drop=True)

# %%
assignments
# Out:
#      idx                      origin_time           x           y         z  \
# 0      0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761  6.640625
# 1      0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761  6.640625
# 2      0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761  6.640625
# 3      0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761  6.640625
# 4      0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761  6.640625
# ..   ...                              ...         ...         ...       ...
# 123   20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869  0.390625
# 124   20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869  0.390625
# 125   20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869  0.390625
# 126   20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869  0.390625
# 127   20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869  0.390625
#
#      picks   latitude   longitude     depth  event_idx  pick_idx  residual  \
# 0        6  42.932269 -126.832522  6.640625          1     30379  0.186548
# 1        6  42.932269 -126.832522  6.640625          1   1151862  0.083338
# 2        6  42.932269 -126.832522  6.640625          1     30441 -0.238147
# 3        6  42.932269 -126.832522  6.640625          1   1151880 -0.261341
# 4        6  42.932269 -126.832522  6.640625          1     30287  0.012248
# ..     ...        ...         ...       ...        ...       ...       ...
# 123      6  43.510336 -128.321367  0.390625         79    713820 -0.334241
# 124      6  43.510336 -128.321367  0.390625         79    713680  0.414925
# 125      6  43.510336 -128.321367  0.390625         79    713631 -0.057347
# 126      6  43.510336 -128.321367  0.390625         79   1777535  0.313275
# 127      6  43.510336 -128.321367  0.390625         79   1777796  0.211801
#
#     station phase     time_pick   pick_id                        pick_time
# 0      J25A     P  1.320860e+09   1583797 2011-11-09 17:25:26.669200+00:00
# 1      J25A     S  1.320860e+09   1583818 2011-11-09 17:25:52.209200+00:00
# 2      J33A     P  1.320860e+09   1583891 2011-11-09 17:25:32.909500+00:00
# 3      J33A     S  1.320860e+09   1583878 2011-11-09 17:26:03.409500+00:00
# 4      J41A     P  1.320860e+09   1581083 2011-11-09 17:25:41.302000+00:00
# ..      ...   ...           ...       ...                              ...
# 123    J33C     P  1.399921e+09  14680778 2014-05-12 18:51:45.276648+00:00
# 124    J41C     P  1.399921e+09  14671577 2014-05-12 18:51:51.716300+00:00
# 125    J25C     P  1.399921e+09  14661106 2014-05-12 18:51:41.641372+00:00
# 126    J25C     S  1.399921e+09  14661095 2014-05-12 18:52:14.921372+00:00
# 127    J41C     S  1.399921e+09  14671819 2014-05-12 18:52:31.452300+00:00
#
# [128 rows x 17 columns]

# %%
# Merge the picks and assignments DataFrames on the pick_id column

# Convert the datetime columns to datetime objects
# picks['trace_p_arrival'] = pd.to_datetime(picks['trace_p_arrival'])
# picks['trace_s_arrival'] = pd.to_datetime(picks['trace_s_arrival'])
assignments['pick_time'] = pd.to_datetime(assignments['pick_time'])

# picks = pd.merge(picks, assignments, left_on="pick_id", right_on="pick_id", how='left')

# # Fill NaN values and convert idx columns to integers
# picks = picks.fillna(-1).astype({'idx': int})

# # Rename columns for consistency
# picks = picks.rename(columns={"station_code": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
# picks['type'] = picks['type'].str.lower()

# Rename columns for consistency
assignments = assignments.rename(columns={"station": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
assignments['type'] = assignments['type'].str.lower()

# %%
# picks.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
#                     date_format='%Y-%m-%dT%H:%M:%S.%f',
#                     columns=["id", "timestamp", "type", "event_index"])
assignments.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["id", "timestamp", "type", "event_index"])

# %%
assignments
# Out:
#      event_index                      origin_time           x           y  \
# 0              0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761
# 1              0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761
# 2              0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761
# 3              0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761
# 4              0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761
# ..           ...                              ...         ...         ...
# 123           20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869
# 124           20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869
# 125           20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869
# 126           20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869
# 127           20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869
#
#             z  picks   latitude   longitude     depth  event_idx  pick_idx  \
# 0    6.640625      6  42.932269 -126.832522  6.640625          1     30379
# 1    6.640625      6  42.932269 -126.832522  6.640625          1   1151862
# 2    6.640625      6  42.932269 -126.832522  6.640625          1     30441
# 3    6.640625      6  42.932269 -126.832522  6.640625          1   1151880
# 4    6.640625      6  42.932269 -126.832522  6.640625          1     30287
# ..        ...    ...        ...         ...       ...        ...       ...
# 123  0.390625      6  43.510336 -128.321367  0.390625         79    713820
# 124  0.390625      6  43.510336 -128.321367  0.390625         79    713680
# 125  0.390625      6  43.510336 -128.321367  0.390625         79    713631
# 126  0.390625      6  43.510336 -128.321367  0.390625         79   1777535
# 127  0.390625      6  43.510336 -128.321367  0.390625         79   1777796
#
#      residual    id type     time_pick   pick_id  \
# 0    0.186548  J25A    p  1.320860e+09   1583797
# 1    0.083338  J25A    s  1.320860e+09   1583818
# 2   -0.238147  J33A    p  1.320860e+09   1583891
# 3   -0.261341  J33A    s  1.320860e+09   1583878
# 4    0.012248  J41A    p  1.320860e+09   1581083
# ..        ...   ...  ...           ...       ...
# 123 -0.334241  J33C    p  1.399921e+09  14680778
# 124  0.414925  J41C    p  1.399921e+09  14671577
# 125 -0.057347  J25C    p  1.399921e+09  14661106
# 126  0.313275  J25C    s  1.399921e+09  14661095
# 127  0.211801  J41C    s  1.399921e+09  14671819
#
#                            timestamp
# 0   2011-11-09 17:25:26.669200+00:00
# 1   2011-11-09 17:25:52.209200+00:00
# 2   2011-11-09 17:25:32.909500+00:00
# 3   2011-11-09 17:26:03.409500+00:00
# 4   2011-11-09 17:25:41.302000+00:00
# ..                               ...
# 123 2014-05-12 18:51:45.276648+00:00
# 124 2014-05-12 18:51:51.716300+00:00
# 125 2014-05-12 18:51:41.641372+00:00
# 126 2014-05-12 18:52:14.921372+00:00
# 127 2014-05-12 18:52:31.452300+00:00
#
# [128 rows x 17 columns]

# %% [markdown]
# ### Format event files

# %%
catalog = assignments.drop_duplicates(subset='event_idx')

# %%
catalog = catalog.rename(columns={'origin_time':'time',"depth": "depth_km",'idx':'event_index'})

# %%
catalog
# Out:
#      event_index                             time           x           y  \
# 0              0 2011-11-09 17:24:51.454200+00:00 -108.775094 -173.323761
# 6              1 2011-12-08 18:34:06.040983+00:00  -99.849958 -173.323761
# 12             2 2011-12-20 00:00:16.064003+00:00   -0.557821    9.767689
# 18             3 2012-02-03 03:03:40.803628+00:00 -126.625365 -153.298134
# 24             4 2012-02-15 03:31:16.120587+00:00 -179.060539 -143.285320
# 31             5 2012-04-18 15:20:59.528926+00:00   99.849958   14.058895
# 37             6 2012-05-10 10:58:55.563721+00:00 -166.788477 -154.728536
# 44             7 2012-07-10 13:58:25.328216+00:00  -30.680155  -94.651654
# 50             8 2012-07-18 00:20:00.702900+00:00  201.373378 -210.514212
# 56             9 2012-08-29 07:54:52.443774+00:00   22.870661   14.058895
# 62            10 2012-08-29 08:05:26.522418+00:00   96.503032   19.780503
# 68            11 2012-09-18 19:57:10.268089+00:00  -71.958908 -174.754163
# 74            12 2012-11-03 23:54:43.276284+00:00  111.006378   65.553366
# 80            13 2013-01-13 09:16:01.736167+00:00   52.992994   39.806130
# 86            14 2013-03-31 04:18:47.925328+00:00 -143.359995 -104.664467
# 92            15 2013-10-02 01:30:17.005083+00:00 -237.073922 -101.803664
# 98            16 2013-11-13 19:09:34.140431+00:00 -129.972291 -173.323761
# 104           17 2014-01-15 08:31:57.792461+00:00 -127.741007 -177.614967
# 110           18 2014-02-25 23:03:08.886563+00:00   -9.482957  -87.499644
# 116           19 2014-05-12 16:45:45.434971+00:00 -232.611354 -103.234065
# 122           20 2014-05-12 18:50:56.744503+00:00 -228.148786 -106.094869
#
#              z  picks   latitude   longitude   depth_km  event_idx  pick_idx  \
# 0     6.640625      6  42.932269 -126.832522   6.640625          1     30379
# 6     1.171875      6  42.933490 -126.723212   1.171875          2     40961
# 12   25.390625      6  44.587900 -125.507025  25.390625          3   1164233
# 18   12.890625      6  43.109709 -127.055663  12.890625          4     67018
# 24    2.734375      7  43.189203 -127.702694   2.734375          6     71292
# 31    1.171875      6  44.619587 -124.241920   1.171875          9    110314
# 37   44.140625      7  43.089072 -127.548388  44.140625         10    118393
# 44    2.734375      6  43.647522 -125.880272   2.734375         13   1239538
# 50   11.328125      6  42.578980 -123.047148  11.328125         14    151539
# 56   32.421875      6  44.626153 -125.211804  32.421875         15    187160
# 62    1.953125      6  44.671520 -124.283004   1.953125         16    187159
# 68    3.515625      6  42.923756 -126.381396   3.515625         19    203141
# 74   49.609375      6  45.081189 -124.090134  49.609375         21    238710
# 80    5.078125      6  44.856241 -124.829574   5.078125         27   1462927
# 86    0.390625      6  43.544271 -127.273857   0.390625         52    468850
# 92    0.390625      6  43.546134 -128.433469   0.390625         71    659002
# 98   43.359375      6  42.928953 -127.092102  43.359375         74    664859
# 104  26.953125      6  42.890716 -127.063804  26.953125         75    678628
# 110  12.890625      6  43.712465 -125.617665  12.890625         77    689547
# 116   2.734375      6  43.534678 -128.377708   2.734375         78    713637
# 122   0.390625      6  43.510336 -128.321367   0.390625         79   1777865
#
#      residual    id type     time_pick   pick_id  \
# 0    0.186548  J25A    p  1.320860e+09   1583797
# 6    0.747435  J25A    p  1.323369e+09   1884565
# 12  -0.242101  TAKO    s  1.324339e+09   2010370
# 18  -0.196536  J25A    p  1.328238e+09   2453639
# 24   0.638447  TAKO    p  1.329277e+09   2588558
# 31   0.010229  TAKO    p  1.334762e+09   3280439
# 37  -0.330297  J25A    p  1.336648e+09   3524460
# 44   0.141817  TAKO    s  1.341929e+09   4345334
# 50  -0.073185  J25A    p  1.342571e+09   4478376
# 56   0.119793  TAKO    p  1.346227e+09   4717858
# 62   1.355409  TAKO    p  1.346228e+09   4717857
# 68  -0.905047  J25B    p  1.347998e+09   4880188
# 74   0.138985  TAKO    p  1.351987e+09   5802571
# 80  -0.103421  J33B    s  1.358069e+09   7129150
# 86   0.975119  J33B    p  1.364704e+09   8175940
# 92  -0.300111  J41C    p  1.380677e+09   9828333
# 98   0.056652  J25C    p  1.384370e+09  10647027
# 104  0.411287  J41C    p  1.389775e+09  12097570
# 110  0.613801  J41C    p  1.393369e+09  13007502
# 116 -0.269836  J25C    p  1.399913e+09  14661112
# 122 -0.548412  J33C    s  1.399921e+09  14680749
#
#                            timestamp
# 0   2011-11-09 17:25:26.669200+00:00
# 6   2011-12-08 18:34:42.229800+00:00
# 12  2011-12-20 00:00:52.626000+00:00
# 18  2012-02-03 03:04:15.030500+00:00
# 24  2012-02-15 03:31:58.866000+00:00
# 31  2012-04-18 15:21:17.626000+00:00
# 37  2012-05-10 10:59:32.879600+00:00
# 44  2012-07-10 13:59:05.866000+00:00
# 50  2012-07-18 00:20:35.008800+00:00
# 56  2012-08-29 07:55:12.126000+00:00
# 62  2012-08-29 08:05:46.426000+00:00
# 68  2012-09-18 19:57:41.960400+00:00
# 74  2012-11-03 23:55:05.166000+00:00
# 80  2013-01-13 09:16:14.183600+00:00
# 86  2013-03-31 04:19:29.100700+00:00
# 92  2013-10-02 01:31:11.775700+00:00
# 98  2013-11-13 19:10:09.586589+00:00
# 104 2014-01-15 08:32:48.002400+00:00
# 110 2014-02-25 23:03:44.020200+00:00
# 116 2014-05-12 16:46:29.621372+00:00
# 122 2014-05-12 18:52:20.836648+00:00

# %%
catalog.to_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t", index=False,
                    float_format="%.3f",
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["time", "longitude", "latitude", "depth_km",'event_index'])

# %%
events = pd.read_csv(f'../data/datasets_nwa_shelf_trench/events_nwa_shelf_trench.csv', index_col=0)
events
# Out:
#      idx                              time           x           y          z  \
# 0      0  2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 8      8  2011-01-03 22:30:53.445832+00:00  -78.652760  277.252856  12.890625
# 10    10  2011-01-05 05:25:45.145580+00:00  -97.618674  461.774708   4.296875
# 11    11  2011-01-05 09:29:58.041704+00:00  -92.040464  551.890032  24.609375
# 12    12  2011-01-05 14:35:15.536295+00:00 -290.624737  559.042042   5.078125
# ..   ...                               ...         ...         ...        ...
# 266  266  2014-05-04 09:37:25.896488+00:00 -306.243725  507.547571  13.671875
# 273  273  2014-05-21 04:04:16.795543+00:00  -77.537118  533.294806  41.796875
# 275  275  2014-05-25 11:21:40.359990+00:00  232.611354  414.571444  49.609375
# 276  276  2014-05-27 08:51:10.491000+00:00 -285.046527  507.547571  11.328125
# 277  277  2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
#
#      picks   latitude   longitude      depth
# 0       10  49.206819 -125.232068  49.609375
# 8        6  46.989816 -126.533950  12.890625
# 10       6  48.646430 -126.824766   4.296875
# 11       7  49.457391 -126.769550  24.609375
# 12       6  49.459134 -129.509297   5.078125
# ..     ...        ...         ...        ...
# 266      6  48.989699 -129.684922  13.671875
# 273     10  49.292245 -126.565918  41.796875
# 275      7  48.186967 -122.371453  49.609375
# 276      8  48.999834 -129.395983  11.328125
# 277      6  48.910006 -129.388983   7.421875
#
# [123 rows x 9 columns]

# %%
# The parameters in the associator class: n_picks=2,n_p_picks=1,n_s_picks=1,n_p_and_s_picks=1
fig = plt.figure(figsize=(4, 8))
ax = fig.add_subplot()
ax.set_aspect("equal")

# ax.scatter(events["x"], events["y"], c=events["z"])
ax.set_xlabel("Easting [km]")
ax.set_ylabel("Northing [km]")
cax = fig.add_axes([ax.get_position().x1+0.05,ax.get_position().y0,0.02,ax.get_position().height])
cb1 = fig.colorbar(ax.scatter(events["x"], events["y"], c=events["z"],s=0.5,cmap='viridis'), cax=cax)
cb1.ax.invert_yaxis()

# %%
catalog = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv',index_col=0)
len(catalog)
# Out:
# 21

# %%
from datetime import datetime


stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
stations['net'] = stations['station'].apply(lambda x: x.split('.')[0])
stations['sta'] = stations['station'].apply(lambda x: x.split('.')[1])
stations['cha'] = stations['station'].apply(lambda x: x.split('.')[3])

picks = pd.read_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t")
events = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t")

events["match_id"] = events["event_index"]
picks["match_id"] = picks["event_index"]
events.sort_values(by="time", inplace=True, ignore_index=True)

out_file = open(f"../hypoInv/hypoInput_{region}.arc", "w")

events['time'] = pd.to_datetime(events['time'])

picks_by_event = picks.groupby("match_id").groups
for i in tqdm(range(len(events))):

    event = events.iloc[i]
    event_time = event["time"].strftime("%Y%m%d%H%M%S%f")[:-4]
    lat_degree = int(event["latitude"])
    lat_minute = (event["latitude"] - lat_degree) * 60 * 100
    south = "S" if lat_degree <= 0 else " "
    lng_degree = int(event["longitude"])
    lng_minute = (event["longitude"] - lng_degree) * 60 * 100
    east = "E" if lng_degree >= 0 else " "
    depth = event["depth_km"]
    if np.sum(picks[picks["event_index"] == events.iloc[i]['match_id']]['type'] == 'p') == 0:
        continue
    event_line = f"{event_time}{abs(lat_degree):2d}{south}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{east}{abs(lng_minute):4.0f}{depth:5.0f}"
    out_file.write(event_line + "\n")

    picks_idx = picks_by_event[event["match_id"]]
    for j in picks_idx:
        pick = picks.iloc[j]
        station_code = pick['id']
        network_code = stations['net'][stations['sta'] == pick['id']].iloc[0]
        comp_code = ''
        channel_code = stations['cha'][stations['sta'] == pick['id']].iloc[0]
        phase_type = pick['type']
        
        # Check if 'prob' column exists
        if 'prob' in pick:
            phase_weight = min(max(int((1 - pick['prob']) / (1 - 0.3) * 4) - 1, 0), 3)
        else:
            phase_weight = 0  # Default value if 'prob' column is missing
        # 2011-01-02 02:11:06.849100+00:00
        # Assuming pick['timestamp'] has the format '2012-01-01 03:19:00.689664+00:00'
        try:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S.%f")  # Handle timezone with %z
        except:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S%z")  # Handle timezone with %z
        phase_time_minute = pick_time.strftime("%Y%m%d%H%M")  # Extract YYYYMMDDHHMM
        phase_time_second = pick_time.strftime("%S%f")[:-4]  # Extract seconds with first two digits of microseconds
        tmp_line = f"{station_code:<5}{network_code:<2} {comp_code:<1}{channel_code:<3}"
        if phase_type.upper() == 'P':
            pick_line = f"{tmp_line:<13} P {phase_weight:<1d}{phase_time_minute} {phase_time_second}"
        elif phase_type.upper() == 'S':
            pick_line = f"{tmp_line:<13}   4{phase_time_minute} {'':<12}{phase_time_second} S {phase_weight:<1d}"
        else:
            raise ValueError(f"Phase type error {phase_type}")
        out_file.write(pick_line + "\n")

    out_file.write("\n")
    if i > 1e5:
        break

out_file.close()
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 662.17it/s]
