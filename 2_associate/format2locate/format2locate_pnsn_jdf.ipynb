# %% [markdown]
# ## Notebook for formatting data frames for phase association
# Source:
# - https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file
# - https://www.usgs.gov/software/hypoinverse-earthquake-location
# - https://chatgpt.com/c/67491af9-aaf8-800c-82e9-1033e094d8d0
# - https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2017JB014966

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from pnwstore.mseed import WaveformClient
from obspy import UTCDateTime
from obspy.core.stream import Stream
from obspy.clients.fdsn import Client
from tqdm import tqdm
import datetime

# %% [markdown]
# ### 1.3 Create a CSV file for picks for the association

# %% [markdown]
# ### Format the files for HypoInverse and HypoDD
# References: https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file

# %% [markdown]
# ### Format the station files

# %%
region = 'pnsn_jdf'

# %%
df = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)

# %%
TOFB = df[df['station_code']=='TOFB']

# %%
TOFB['station_network_code'].unique()
# Out:
# array([], dtype=object)

# %%
from obspy import read_inventory
from collections import defaultdict
import pandas as pd

client2 = Client("IRIS")
networks = pd.read_csv("../data/networks.csv")
networks = ','.join(list(networks['networks']))
starttime = UTCDateTime(year=2011, month=1, day=1)
endtime = UTCDateTime(year=2016, month=1, day=1)
inv = [] 
# inv = read_inventory("./stations/*.xml")
station_locs = defaultdict(dict)
# stations=inv


for station in df['station_code'].unique():
    inv += client2.get_stations(network=networks,
                                    station=station, channel="?H?", 
                                    starttime=starttime, endtime=endtime, level="response")
stations=inv

print(len(stations))

for network in stations:
    print(network)
    for station in network:
        print(station)
        has_HH = bool(station.select(channel="HH?"))
        has_BH = bool(station.select(channel="BH?"))

        # Apply selection logic based on channel presence
        if has_HH and has_BH:
            # If both HH and BH channels are present, select only HH
            selected_station = station.select(channel="HH?")
        elif has_HH:
            # If only HH channels are present
            selected_station = station.select(channel="HH?")
        elif has_BH:
            # If only BH channels are present
            selected_station = station.select(channel="BH?")

        for chn in selected_station:
            print('This is chn: ', chn)
            sid = f"{network.code}.{station.code}.{chn.location_code}.{chn.code[:-1]}"
            if sid in station_locs:
                station_locs[sid]["component"] += f",{chn.code[-1]}"
                station_locs[sid]["response"] += f",{chn.response.instrument_sensitivity.value:.2f}"
            else:
                component = f"{chn.code[-1]}"
                response = f"{chn.response.instrument_sensitivity.value:.2f}"
                dtype = chn.response.instrument_sensitivity.input_units.lower()
                tmp_dict = {}
                tmp_dict["longitude"], tmp_dict["latitude"], tmp_dict["elevation(m)"] = (
                    chn.longitude,
                    chn.latitude,
                    chn.elevation,
                )
                tmp_dict["component"], tmp_dict["response"], tmp_dict["unit"] = component, response, dtype
                station_locs[sid] = tmp_dict
            if station_locs[sid]["component"]=='Z':
                station_locs[sid]["response"]= f"0,0,"+station_locs[sid]["response"]
            elif station_locs[sid]["component"]=='N,Z':
                station_locs[sid]["response"]= f"0,"+station_locs[sid]["response"]
station_locs = pd.DataFrame.from_dict(station_locs, orient='index')
station_locs["id"] = station_locs.index
station_locs = station_locs.rename_axis('station').reset_index()
station_locs.to_csv(f"./stations_{region}.csv",sep='\t')
station_locs
# Out:
# 80
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J43A (SIO OBS ID J43A)
# 		Channels (3):
# 			7D.J43A..BHZ, 7D.J43A..BH1, 7D.J43A..BH2
# Station J43A (SIO OBS ID J43A)
# 	Station Code: J43A
# 	Channel Count: 3/8 (Selected/Total)
# 	2011-10-19T00:00:00.000000Z - 2012-07-17T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.1378, Longitude: -126.1721, Elevation: -2654.4 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-10-19 to 2012-07-17
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-10-19T21:25:00.000000Z - 2012-07-17T18:41:00.000000Z
# 	Latitude: 46.1378, Longitude: -126.1721, Elevation: -2654.4 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-10-19T21:25:00.000000Z - 2012-07-17T18:41:00.000000Z
# 	Latitude: 46.1378, Longitude: -126.1721, Elevation: -2654.4 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-19T21:25:00.000000Z - 2012-07-17T18:41:00.000000Z
# 	Latitude: 46.1378, Longitude: -126.1721, Elevation: -2654.4 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J43A (Natural Harvest Farm, Hartford, WI, USA)
# 		Channels (12):
# 			TA.J43A..BHZ, TA.J43A..BHN, TA.J43A..BHE, TA.J43A..LHZ,
# 			TA.J43A..LHN, TA.J43A..LHE, TA.J43A..UHZ, TA.J43A..UHN,
# 			TA.J43A..UHE, TA.J43A..VHZ, TA.J43A..VHN, TA.J43A..VHE
# Station J43A (Natural Harvest Farm, Hartford, WI, USA)
# 	Station Code: J43A
# 	Channel Count: 12/40 (Selected/Total)
# 	2011-10-12T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.
0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G03A (WHOI OBS ID S87)
# 		Channels (6):
# 			7D.G03A..BHZ, 7D.G03A..BH1, 7D.G03A..BH2, 7D.G03A..LHZ,
# 			7D.G03A..LH1, 7D.G03A..LH2
# Station G03A (WHOI OBS ID S87)
# 	Station Code: G03A
# 	Channel Count: 6/52 (Selected/Total)
# 	2011-11-17T00:00:00.000000Z - 2012-05-13T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.0591, Longitude: -126.1625, Elevation: -4113.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-11-17 to 2012-05-13
# 	    ..LH[Z21]     1.0 Hz  2011-11-17 to 2012-05-13
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-11-17T00:00:00.000000Z - 2012-05-13T23:59:59.000000Z
# 	Latitude: 40.0591, Longitude: -126.1625, Elevation: -4113.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-11-17T00:00:00.000000Z - 2012-05-13T23:59:59.000000Z
# 	Latitude: 40.0591, Longitude: -126.1625, Elevation: -4113.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-11-17T00:00:00.000000Z - 2012-05-13T23:59:59.000000Z
# 	Latitude: 40.0591, Longitude: -126.1625, Elevation: -4113.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J27B (WHOI OBS ID T107)
# 		Channels (6):
# 			7D.J27B..BHZ, 7D.J27B..BH1, 7D.J27B..BH2, 7D.J27B..LHZ,
# 			7D.J27B..LH1, 7D.J27B..LH2
# Station J27B (WHOI OBS ID T107)
# 	Station Code: J27B
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-24T00:00:00.000000Z - 2013-06-04T23:59:59.000000Z
# 	Access: open
# 	Latitude: 44.8476, Longitude: -126.3069, Elevation: -2824.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-24 to 2013-06-04
# 	    ..LH[Z21]     1.0 Hz  2012-08-24 to 2013-06-04
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-24T00:00:00.000000Z - 2013-06-04T23:59:59.000000Z
# 	Latitude: 44.8476, Longitude: -126.3069, Elevation: -2824.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-24T00:00:00.000000Z - 2013-06-04T23:59:59.000000Z
# 	Latitude: 44.8476, Longitude: -126.3069, Elevation: -2824.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-24T00:00:00.000000Z - 2013-06-04T23:59:59.000000Z
# 	Latitude: 44.8476, Longitude: -126.3069, Elevation: -2824.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FS06B (WHOI OBS ID S87)
# 		Channels (6):
# 			7D.FS06B..BHZ, 7D.FS06B..BH1, 7D.FS06B..BH2, 7D.FS06B..LHZ,
# 			7D.FS06B..LH1, 7D.FS06B..LH2
# Station FS06B (WHOI OBS ID S87)
# 	Station Code: FS06B
# 	Channel Count: 6/45 (Selected/Total)
# 	2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.3812, Longitude: -124.7853, Elevation: -2198.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-27 to 2013-06-12
# 	    ..LH[Z21]     1.0 Hz  2012-08-27 to 2013-06-12
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.3812, Longitude: -124.7853, Elevation: -2198.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.3812, Longitude: -124.7853, Elevation: -2198.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.3812, Longitude: -124.7853, Elevation: -2198.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G03B (WHOI OBS ID S89)
# 		Channels (6):
# 			7D.G03B..BHZ, 7D.G03B..BH1, 7D.G03B..BH2, 7D.G03B..LHZ,
# 			7D.G03B..LH1, 7D.G03B..LH2
# Station G03B (WHOI OBS ID S89)
# 	Station Code: G03B
# 	Channel Count: 6/52 (Selected/Total)
# 	2012-08-27T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.0580, Longitude: -126.1634, Elevation: -4051.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-27 to 2013-06-11
# 	    ..LH[Z21]     1.0 Hz  2012-08-27 to 2013-06-11
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Latitude: 40.0580, Longitude: -126.1634, Elevation: -4051.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Latitude: 40.0580, Longitude: -126.1634, Elevation: -4051.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Latitude: 40.0580, Longitude: -126.1634, Elevation: -4051.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G04B (WHOI OBS ID T103)
# 		Channels (6):
# 			7D.G04B..BHZ, 7D.G04B..BH1, 7D.G04B..BH2, 7D.G04B..LHZ,
# 			7D.G04B..LH1, 7D.G04B..LH2
# Station G04B (WHOI OBS ID T103)
# 	Station Code: G04B
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-27T00:00:00.000000Z - 2013-06-08T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.0585, Longitude: -126.9285, Elevation: -4368.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-27 to 2013-06-08
# 	    ..LH[Z21]     1.0 Hz  2012-08-27 to 2013-06-08
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-08T23:59:59.000000Z
# 	Latitude: 40.0585, Longitude: -126.9285, Elevation: -4368.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-08T23:59:59.000000Z
# 	Latitude: 40.0585, Longitude: -126.9285, Elevation: -4368.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-08T23:59:59.000000Z
# 	Latitude: 40.0585, Longitude: -126.9285, Elevation: -4368.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FS05B (WHOI OBS ID S80)
# 		Channels (6):
# 			7D.FS05B..BHZ, 7D.FS05B..BH1, 7D.FS05B..BH2, 7D.FS05B..LHZ,
# 			7D.FS05B..LH1, 7D.FS05B..LH2
# Station FS05B (WHOI OBS ID S80)
# 	Station Code: FS05B
# 	Channel Count: 6/45 (Selected/Total)
# 	2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.3866, Longitude: -124.8996, Elevation: -2316.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-27 to 2013-06-12
# 	    ..LH[Z21]     1.0 Hz  2012-08-27 to 2013-06-12
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.3866, Longitude: -124.8996, Elevation: -2316.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.3866, Longitude: -124.8996, Elevation: -2316.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-27T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.3866, Longitude: -124.8996, Elevation: -2316.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G11B (WHOI OBS ID T111)
# 		Channels (6):
# 			7D.G11B..BHZ, 7D.G11B..BH1, 7D.G11B..BH2, 7D.G11B..LHZ,
# 			7D.G11B..LH1, 7D.G11B..LH2
# Station G11B (WHOI OBS ID T111)
# 	Station Code: G11B
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-28T00:00:00.000000Z - 2013-06-09T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.6875, Longitude: -126.3764, Elevation: -3123.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-28 to 2013-06-09
# 	    ..LH[Z21]     1.0 Hz  2012-08-28 to 2013-06-09
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-09T23:59:59.000000Z
# 	Latitude: 40.6875, Longitude: -126.3764, Elevation: -3123.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-09T23:59:59.000000Z
# 	Latitude: 40.6875, Longitude: -126.3764, Elevation: -3123.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-09T23:59:59.000000Z
# 	Latitude: 40.6875, Longitude: -126.3764, Elevation: -3123.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FS09B (WHOI OBS ID S85)
# 		Channels (6):
# 			7D.FS09B..BHZ, 7D.FS09B..BH1, 7D.FS09B..BH2, 7D.FS09B..LHZ,
# 			7D.FS09B..LH1, 7D.FS09B..LH2
# Station FS09B (WHOI OBS ID S85)
# 	Station Code: FS09B
# 	Channel Count: 6/45 (Selected/Total)
# 	2012-08-28T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.4387, Longitude: -124.8085, Elevation: -2161.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-28 to 2013-06-12
# 	    ..LH[Z21]     1.0 Hz  2012-08-28 to 2013-06-12
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.4387, Longitude: -124.8085, Elevation: -2161.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.4387, Longitude: -124.8085, Elevation: -2161.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-12T23:59:59.000000Z
# 	Latitude: 40.4387, Longitude: -124.8085, Elevation: -2161.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G19B (WHOI OBS ID T106)
# 		Channels (6):
# 			7D.G19B..BHZ, 7D.G19B..BH1, 7D.G19B..BH2, 7D.G19B..LHZ,
# 			7D.G19B..LH1, 7D.G19B..LH2
# Station G19B (WHOI OBS ID T106)
# 	Station Code: G19B
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-28T00:00:00.000000Z - 2013-06-13T23:59:59.000000Z
# 	Access: open
# 	Latitude: 41.3074, Longitude: -125.7736, Elevation: -3071.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-28 to 2013-06-13
# 	    ..LH[Z21]     1.0 Hz  2012-08-28 to 2013-06-13
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-13T23:59:59.000000Z
# 	Latitude: 41.3074, Longitude: -125.7736, Elevation: -3071.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-13T23:59:59.000000Z
# 	Latitude: 41.3074, Longitude: -125.7736, Elevation: -3071.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-13T23:59:59.000000Z
# 	Latitude: 41.3074, Longitude: -125.7736, Elevation: -3071.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G20B (WHOI OBS ID T113)
# 		Channels (6):
# 			7D.G20B..BHZ, 7D.G20B..BH1, 7D.G20B..BH2, 7D.G20B..LHZ,
# 			7D.G20B..LH1, 7D.G20B..LH2
# Station G20B (WHOI OBS ID T113)
# 	Station Code: G20B
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-28T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Access: open
# 	Latitude: 41.2987, Longitude: -126.6133, Elevation: -3141.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-28 to 2013-06-11
# 	    ..LH[Z21]     1.0 Hz  2012-08-28 to 2013-06-11
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Latitude: 41.2987, Longitude: -126.6133, Elevation: -3141.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Latitude: 41.2987, Longitude: -126.6133, Elevation: -3141.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-28T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Latitude: 41.2987, Longitude: -126.6133, Elevation: -3141.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G36B2 (WHOI OBS ID T101)
# 		Channels (6):
# 			7D.G36B2..BHZ, 7D.G36B2..BH1, 7D.G36B2..BH2, 7D.G36B2..LHZ,
# 			7D.G36B2..LH1, 7D.G36B2..LH2
# Station G36B2 (WHOI OBS ID T101)
# 	Station Code: G36B2
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Access: open
# 	Latitude: 42.5994, Longitude: -126.9038, Elevation: -2423.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-29 to 2013-06-10
# 	    ..LH[Z21]     1.0 Hz  2012-08-29 to 2013-06-10
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Latitude: 42.5994, Longitude: -126.9038, Elevation: -2423.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Latitude: 42.5994, Longitude: -126.9038, Elevation: -2423.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Latitude: 42.5994, Longitude: -126.9038, Elevation: -2423.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G35B (WHOI OBS ID T109)
# 		Channels (6):
# 			7D.G35B..BHZ, 7D.G35B..BH1, 7D.G35B..BH2, 7D.G35B..LHZ,
# 			7D.G35B..LH1, 7D.G35B..LH2
# Station G35B (WHOI OBS ID T109)
# 	Station Code: G35B
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Access: open
# 	Latitude: 42.5658, Longitude: -126.0558, Elevation: -2367.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-29 to 2013-06-10
# 	    ..LH[Z21]     1.0 Hz  2012-08-29 to 2013-06-10
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Latitude: 42.5658, Longitude: -126.0558, Elevation: -2367.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Latitude: 42.5658, Longitude: -126.0558, Elevation: -2367.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-08-29T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Latitude: 42.5658, Longitude: -126.0558, Elevation: -2367.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J19B (WHOI OBS ID T114)
# 		Channels (6):
# 			7D.J19B..BHZ, 7D.J19B..BH1, 7D.J19B..BH2, 7D.J19B..LHZ,
# 			7D.J19B..LH1, 7D.J19B..LH2
# Station J19B (WHOI OBS ID T114)
# 	Station Code: J19B
# 	Channel Count: 6/37 (Selected/Total)
# 	2012-08-30T00:00:00.000000Z - 2013-06-10T23:59:59.000000Z
# 	Access: open
# 	Latitude: 44.1777, Longitude: -126.2717, Elevation: -2968.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2012-08-30 to 2013-06-10
# 	    ..LH[Z21]     1.0 Hz  2012-08-30 to 2013-06-10
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2012-08
LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.G26D..HHZ, 7D.G26D..HH1, 7D.G26D..HH2
# Station G26D (LDEO OBS STANDARD DEEP)
# 	Station Code: G26D
# 	Channel Count: 3/9 (Selected/Total)
# 	2014-09-19T00:00:00.000000Z - 2015-10-04T23:59:59.000000Z
# 	Access: open
# 	Latitude: 41.9838, Longitude: -125.3083, Elevation: -3104.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2014-09-19 to 2015-09-15
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2014-09-19T00:05:00.000000Z - 2015-09-15T11:05:10.000000Z
# 	Latitude: 41.9838, Longitude: -125.3083, Elevation: -3104.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2014-09-19T00:05:00.000000Z - 2015-09-15T11:05:10.000000Z
# 	Latitude: 41.9838, Longitude: -125.3083, Elevation: -3104.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-09-19T00:05:00.000000Z - 2015-09-15T11:05:10.000000Z
# 	Latitude: 41.9838, Longitude: -125.3083, Elevation: -3104.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network Z5 (Seismicity, Structure and Dynamics of the Gorda Deformation Zone (Gorda))
# 	Station Count: 1/64 (Selected/Total)
# 	2013-01-01T00:00:00.000000Z - 2015-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			Z5.BB631 (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			Z5.BB631..HHZ, Z5.BB631..HH1, Z5.BB631..HH2
# Station BB631 (LDEO OBS STANDARD DEEP)
# 	Station Code: BB631
# 	Channel Count: 3/9 (Selected/Total)
# 	2014-09-20T00:00:00.000000Z - 2015-04-18T23:59:59.000000Z
# 	Access: open
# 	Latitude: 42.8787, Longitude: -126.6344, Elevation: -3320.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2014-09-20 to 2015-04-18
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2014-09-20T01:03:50.000000Z - 2015-04-18T15:41:22.000000Z
# 	Latitude: 42.8787, Longitude: -126.6344, Elevation: -3320.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2014-09-20T01:03:50.000000Z - 2015-04-18T15:41:22.000000Z
# 	Latitude: 42.8787, Longitude: -126.6344, Elevation: -3320.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-09-20T01:03:50.000000Z - 2015-04-18T15:41:22.000000Z
# 	Latitude: 42.8787, Longitude: -126.6344, Elevation: -3320.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G27D (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.G27D..HHZ, 7D.G27D..HH1, 7D.G27D..HH2
# Station G27D (LDEO OBS STANDARD DEEP)
# 	Station Code: G27D
# 	Channel Count: 3/9 (Selected/Total)
# 	2014-09-19T00:00:00.000000Z - 2015-10-05T23:59:59.000000Z
# 	Access: open
# 	Latitude: 42.0013, Longitude: -125.9817, Elevation: -2939.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2014-09-19 to 2015-09-15
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2014-09-19T00:05:00.000000Z - 2015-09-15T05:48:05.000000Z
# 	Latitude: 42.0013, Longitude: -125.9817, Elevation: -2939.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2014-09-19T00:05:00.000000Z - 2015-09-15T05:48:05.000000Z
# 	Latitude: 42.0013, Longitude: -125.9817, Elevation: -2939.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-09-19T00:05:00.000000Z - 2015-09-15T05:48:05.000000Z
# 	Latitude: 42.0013, Longitude: -125.9817, Elevation: -2939.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network OO (Ocean Observatories Initiative (OOI))
# 	Station Count: 1/16 (Selected/Total)
# 	2013-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			OO.HYSB1 (RSN Hydrate Slope Base)
# 		Channels (12):
# 			OO.HYSB1..BHZ, OO.HYSB1..BHN, OO.HYSB1..BHE, OO.HYSB1..HHZ,
# 			OO.HYSB1..HHN, OO.HYSB1..HHE, OO.HYSB1..LHZ, OO.HYSB1..LHN,
# 			OO.HYSB1..LHE, OO.HYSB1..MHZ, OO.HYSB1..MHN, OO.HYSB1..MHE
# Station HYSB1 (RSN Hydrate Slope Base)
# 	Station Code: HYSB1
# 	Channel Count: 12/17 (Selected/Total)
# 	2014-08-01T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 44.5098, Longitude: -125.4053, Elevation: -2908.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   200.0 Hz  2014-08-01 to None
# 	    ..BH[ZNE]    40.0 Hz  2014-08-01 to None
# 	    ..MH[ZNE]     8.0 Hz  2014-08-01 to None
# 	    ..LH[ZNE]     1.0 Hz  2014-08-01 to None
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2014-08-01T00:00:00.000000Z - --
# 	Latitude: 44.5098, Longitude: -125.4053, Elevation: -2908.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (CMG-1T, 360 s, 3000 V/m/s-DM-24 Mk3 Fixed Gain, ga)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2014-08-01T00:00:00.000000Z - --
# 	Latitude: 44.5098, Longitude: -125.4053, Elevation: -2908.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (CMG-1T, 360 s, 3000 V/m/s-DM-24 Mk3 Fixed Gain, ga)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-08-01T00:00:00.000000Z - --
# 	Latitude: 44.5098, Longitude: -125.4053, Elevation: -2908.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (CMG-1T, 360 s, 3000 V/m/s-DM-24 Mk3 Fixed Gain, ga)
# 	Response information available
#          station   longitude   latitude  elevation(m) component  \
# 0    7D.J43A..BH -126.172096  46.137798       -2654.4     1,2,Z
# 1    TA.J43A..BH  -88.418503  43.380798         322.0     E,N,Z
# 2    7D.J59A..HH -126.415298  47.509602       -2371.0     1,2,Z
# 3    TA.J59A..HH  -74.504097  43.464699         541.0     E,N,Z
# 4    7D.J51A..HH -126.164101  46.797001       -2610.0     1,2,Z
# ..           ...         ...        ...           ...       ...
# 75   7D.G19D..HH -126.027901  41.331600       -3082.0     1,2,Z
# 76   7D.G26D..HH -125.308296  41.983799       -3104.0     1,2,Z
# 77  Z5.BB631..HH -126.634399  42.878700       -3320.0     1,2,Z
# 78   7D.G27D..HH -125.981697  42.001301       -2939.0     1,2,Z
# 79  OO.HYSB1..HH -125.405258  44.509791       -2908.0     E,N,Z
#
#                                      response unit            id
# 0   1846390000.00,1846390000.00,1846390000.00  m/s   7D.J43A..BH
# 1      627192000.00,627192000.00,627192000.00  m/s   TA.J43A..BH
# 2      971188000.00,971188000.00,971188000.00  m/s   7D.J59A..HH
# 3      629280000.00,629280000.00,629280000.00  m/s   TA.J59A..HH
# 4      971188000.00,971188000.00,971188000.00  m/s   7D.J51A..HH
# ..                                        ...  ...           ...
# 75        35122500.00,35122500.00,35122500.00  m/s   7D.G19D..HH
# 76        35122500.00,35122500.00,35122500.00  m/s   7D.G26D..HH
# 77        35122500.00,35122500.00,35122500.00  m/s  Z5.BB631..HH
# 78        35122500.00,35122500.00,35122500.00  m/s   7D.G27D..HH
# 79     922796000.00,927987000.00,918082000.00  m/s  OO.HYSB1..HH
#
# [80 rows x 8 columns]

# %% [markdown]
# ### Convert the station file from a CSV file to dat files

# %%
stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
converted_hypoinverse = []
converted_hypoDD = {}

for i in tqdm(range(len(stations))):

    network_code, station_code, comp_code, channel_code = stations.iloc[i]['station'].split('.')
    station_weight = " "
    lat_degree = int(stations.iloc[i]['latitude'])
    lat_minute = (stations.iloc[i]['latitude'] - lat_degree) * 60
    north = "N" if lat_degree >= 0 else "S"
    lng_degree = int(stations.iloc[i]['longitude'])
    lng_minute = (stations.iloc[i]['longitude'] - lng_degree) * 60
    west = "W" if lng_degree <= 0 else "E"
    elevation = stations.iloc[i]['elevation(m)']
    line_hypoinverse = f"{station_code:<5} {network_code:<2} {comp_code[:-1]:<1}{channel_code:<3} {station_weight}{abs(lat_degree):2.0f} {abs(lat_minute):7.4f}{north}{abs(lng_degree):3.0f} {abs(lng_minute):7.4f}{west}{elevation:4.0f}\n"
    converted_hypoinverse.append(line_hypoinverse)
    converted_hypoDD[f"{station_code}"] = f"{network_code:<2}{station_code:<5} {stations.iloc[i]['latitude']:.3f} {stations.iloc[i]['longitude']:.3f} {elevation:4.0f}\n"

out_file = f'stations_hypoinverse_{region}.dat'
with open(out_file, 'w') as f:
    f.writelines(converted_hypoinverse)

out_file = f'stations_hypoDD_{region}.dat'
with open(out_file, 'w') as f:
    for k, v in converted_hypoDD.items():
        f.write(v)
# Out:
# 100%|██████████| 80/80 [00:00<00:00, 5569.57it/s]

# %% [markdown]
# ### Format the pick files

# %%
# Load necessary files
# Load all event data into a list of DataFrames
import datetime 
pick_assignment_files = [
    f'../data/datasets_{region}/all_pick_assignments_{region}.csv'
]

# Read all event files into DataFrames
dfs = [pd.read_csv(file, index_col=0) for file in pick_assignment_files]

# Concatenate all DataFrames into a single DataFrame
assignments =  pd.concat(dfs)

assignments = assignments.rename(columns={"time": "origin_time"})
assignments['origin_time'] = pd.to_datetime(assignments['origin_time'], utc = True)
assignments["pick_time"] = assignments["time_pick"].apply(datetime.datetime.fromtimestamp, tz=datetime.timezone.utc)
assignments = assignments.sort_values(by='origin_time').reset_index(drop=True)

# Reset the idx column so that each group with the same 'time' has a new numbered event index
assignments['idx'] = assignments.groupby('origin_time').ngroup()


# picks = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)
# picks = picks.sort_values(by='trace_start_time').reset_index(drop=True)

# %%
assignments
# Out:
#           idx                      origin_time          x           y  \
# 0           0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 1           0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 2           0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 3           0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 4           0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# ...       ...                              ...        ...         ...
# 216712  23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216713  23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216714  23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216715  23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216716  23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
#
#                 z  picks   latitude   longitude      depth  event_idx  \
# 0       12.890625      6  45.018973 -126.724334  12.890625          2
# 1       12.890625      6  45.018973 -126.724334  12.890625          2
# 2       12.890625      6  45.018973 -126.724334  12.890625          2
# 3       12.890625      6  45.018973 -126.724334  12.890625          2
# 4       12.890625      6  45.018973 -126.724334  12.890625          2
# ...           ...    ...        ...         ...        ...        ...
# 216712  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216713  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216714  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216715  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216716  47.265625      6  40.309645 -124.653498  47.265625      37549
#
#         pick_idx  residual station phase     time_pick   pick_id  \
# 0           8982  0.530519    J35A     P  1.323557e+09   1903257
# 1        2163186 -0.450387    J35A     S  1.323557e+09   1903245
# 2           9006 -0.595107    J43A     P  1.323557e+09   1903654
# 3        2163223  0.890423    J43A     S  1.323557e+09   1903682
# 4        2163066 -0.493940    J51A     S  1.323557e+09   1897337
# ...          ...       ...     ...   ...           ...       ...
# 216712   2156928  0.084264    G10D     P  1.442338e+09  23242063
# 216713   3749707  0.057559    G10D     S  1.442338e+09  23242079
# 216714   2156953 -0.003071   GB101     P  1.442338e+09  23242967
# 216715   3749736  0.053190   GB101     S  1.442338e+09  23242979
# 216716   3749818 -0.142164   GB281     S  1.442338e+09  23243756
#
#                               pick_time
# 0      2011-12-10 22:44:54.512800+00:00
# 1      2011-12-10 22:44:59.372800+00:00
# 2      2011-12-10 22:45:01.738500+00:00
# 3      2011-12-10 22:45:15.178500+00:00
# 4      2011-12-10 22:45:29.090000+00:00
# ...                                 ...
# 216712 2015-09-15 17:31:16.100855+00:00
# 216713 2015-09-15 17:31:25.420855+00:00
# 216714 2015-09-15 17:31:34.666088+00:00
# 216715 2015-09-15 17:31:57.726088+00:00
# 216716 2015-09-15 17:31:35.691780+00:00
#
# [216717 rows x 17 columns]

# %%
# Merge the picks and assignments DataFrames on the pick_id column

# Convert the datetime columns to datetime objects
# picks['trace_p_arrival'] = pd.to_datetime(picks['trace_p_arrival'])
# picks['trace_s_arrival'] = pd.to_datetime(picks['trace_s_arrival'])
assignments['pick_time'] = pd.to_datetime(assignments['pick_time'])

# picks = pd.merge(picks, assignments, left_on="pick_id", right_on="pick_id", how='left')

# # Fill NaN values and convert idx columns to integers
# picks = picks.fillna(-1).astype({'idx': int})

# # Rename columns for consistency
# picks = picks.rename(columns={"station_code": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
# picks['type'] = picks['type'].str.lower()

# Rename columns for consistency
assignments = assignments.rename(columns={"station": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
assignments['type'] = assignments['type'].str.lower()

# %%
# picks.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
#                     date_format='%Y-%m-%dT%H:%M:%S.%f',
#                     columns=["id", "timestamp", "type", "event_index"])
assignments.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["id", "timestamp", "type", "event_index"])

# %%
assignments
# Out:
#         event_index                      origin_time          x           y  \
# 0                 0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 1                 0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 2                 0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 3                 0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# 4                 0 2011-12-10 22:44:46.018805+00:00 -96.503032   58.401356
# ...             ...                              ...        ...         ...
# 216712        23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216713        23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216714        23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216715        23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
# 216716        23516 2015-09-15 17:31:03.266140+00:00  71.958908 -465.125761
#
#                 z  picks   latitude   longitude      depth  event_idx  \
# 0       12.890625      6  45.018973 -126.724334  12.890625          2
# 1       12.890625      6  45.018973 -126.724334  12.890625          2
# 2       12.890625      6  45.018973 -126.724334  12.890625          2
# 3       12.890625      6  45.018973 -126.724334  12.890625          2
# 4       12.890625      6  45.018973 -126.724334  12.890625          2
# ...           ...    ...        ...         ...        ...        ...
# 216712  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216713  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216714  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216715  47.265625      6  40.309645 -124.653498  47.265625      37549
# 216716  47.265625      6  40.309645 -124.653498  47.265625      37549
#
#         pick_idx  residual     id type     time_pick   pick_id  \
# 0           8982  0.530519   J35A    p  1.323557e+09   1903257
# 1        2163186 -0.450387   J35A    s  1.323557e+09   1903245
# 2           9006 -0.595107   J43A    p  1.323557e+09   1903654
# 3        2163223  0.890423   J43A    s  1.323557e+09   1903682
# 4        2163066 -0.493940   J51A    s  1.323557e+09   1897337
# ...          ...       ...    ...  ...           ...       ...
# 216712   2156928  0.084264   G10D    p  1.442338e+09  23242063
# 216713   3749707  0.057559   G10D    s  1.442338e+09  23242079
# 216714   2156953 -0.003071  GB101    p  1.442338e+09  23242967
# 216715   3749736  0.053190  GB101    s  1.442338e+09  23242979
# 216716   3749818 -0.142164  GB281    s  1.442338e+09  23243756
#
#                               timestamp
# 0      2011-12-10 22:44:54.512800+00:00
# 1      2011-12-10 22:44:59.372800+00:00
# 2      2011-12-10 22:45:01.738500+00:00
# 3      2011-12-10 22:45:15.178500+00:00
# 4      2011-12-10 22:45:29.090000+00:00
# ...                                 ...
# 216712 2015-09-15 17:31:16.100855+00:00
# 216713 2015-09-15 17:31:25.420855+00:00
# 216714 2015-09-15 17:31:34.666088+00:00
# 216715 2015-09-15 17:31:57.726088+00:00
# 216716 2015-09-15 17:31:35.691780+00:00
#
# [216717 rows x 17 columns]

# %% [markdown]
# ### Format event files

# %%
catalog = assignments.drop_duplicates(subset='event_idx')

# %%
catalog = catalog.rename(columns={'origin_time':'time',"depth": "depth_km",'idx':'event_index'})

# %%
catalog
# Out:
#         event_index                             time           x           y  \
# 0                 0 2011-12-10 22:44:46.018805+00:00  -96.503032   58.401356
# 6                 1 2011-12-26 18:06:15.493905+00:00  -36.258365  132.782258
# 12                2 2012-02-04 20:05:31.130689+00:00 -203.604662  483.230738
# 19                3 2012-02-06 08:17:12.331083+00:00  -71.958908 -123.259693
# 25                4 2012-03-18 18:48:43.937964+00:00  185.754391  252.936022
# ...             ...                              ...         ...         ...
# 216676        23512 2015-09-14 05:33:02.229963+00:00  -60.802488 -370.719232
# 216686        23513 2015-09-14 06:09:08.238133+00:00 -145.591279 -447.960938
# 216696        23514 2015-09-14 13:34:01.138138+00:00 -161.210267 -435.087320
# 216705        23515 2015-09-15 09:12:54.234894+00:00 -142.244353 -277.743104
# 216711        23516 2015-09-15 17:31:03.266140+00:00   71.958908 -465.125761
#
#                 z  picks   latitude   longitude   depth_km  event_idx  \
# 0       12.890625      6  45.018973 -126.724334  12.890625          2
# 6       41.015625      6  45.693849 -125.965511  41.015625          3
# 12      49.609375      7  48.813643 -128.272371  49.609375          8
# 19       1.171875      6  43.387215 -126.388083   1.171875          9
# 25      25.390625      8  46.749918 -123.068939  25.390625         16
# ...           ...    ...        ...         ...        ...        ...
# 216676   0.390625     10  41.160599 -126.224435   0.390625      37542
# 216686  49.609375     10  40.454578 -127.216333  49.609375      37543
# 216696  49.609375      9  40.567566 -127.403644  49.609375      37544
# 216705  16.015625      6  41.987174 -127.216502  16.015625      37548
# 216711  47.265625      6  40.309645 -124.653498  47.265625      37549
#
#         pick_idx  residual     id type     time_pick   pick_id  \
# 0           8982  0.530519   J35A    p  1.323557e+09   1903257
# 6          12851 -0.264564   J59A    p  1.324923e+09   2067611
# 12         22786 -1.158387   J35A    p  1.328386e+09   2460269
# 19       2171911  0.978387   J51A    s  1.328516e+09   2476997
# 25         34870 -0.081932   J35A    p  1.332097e+09   2934085
# ...          ...       ...    ...  ...           ...       ...
# 216676   3749564 -0.089378   G19D    s  1.442209e+09  23237834
# 216686   2156814 -1.049634  GB281    p  1.442211e+09  23238801
# 216696   3749616  0.504090  GB331    s  1.442238e+09  23238752
# 216705   2156870 -0.035427   G10D    p  1.442308e+09  23241984
# 216711   2157084 -0.049777  GB281    p  1.442338e+09  23243768
#
#                               timestamp
# 0      2011-12-10 22:44:54.512800+00:00
# 6      2011-12-26 18:06:41.171000+00:00
# 12     2012-02-04 20:06:19.985700+00:00
# 19     2012-02-06 08:18:35.410000+00:00
# 25     2012-03-18 18:49:19.234900+00:00
# ...                                 ...
# 216676 2015-09-14 05:33:07.478580+00:00
# 216686 2015-09-14 06:09:22.479781+00:00
# 216696 2015-09-14 13:34:19.617886+00:00
# 216705 2015-09-15 09:13:18.060855+00:00
# 216711 2015-09-15 17:31:22.011780+00:00
#
# [23517 rows x 17 columns]

# %%
catalog.to_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t", index=False,
                    float_format="%.3f",
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["time", "longitude", "latitude", "depth_km",'event_index'])

# %%
events = pd.read_csv(f'../data/datasets_nwa_shelf_trench/events_nwa_shelf_trench.csv', index_col=0)
events
# Out:
#      idx                              time           x           y          z  \
# 0      0  2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 8      8  2011-01-03 22:30:53.445832+00:00  -78.652760  277.252856  12.890625
# 10    10  2011-01-05 05:25:45.145580+00:00  -97.618674  461.774708   4.296875
# 11    11  2011-01-05 09:29:58.041704+00:00  -92.040464  551.890032  24.609375
# 12    12  2011-01-05 14:35:15.536295+00:00 -290.624737  559.042042   5.078125
# ..   ...                               ...         ...         ...        ...
# 266  266  2014-05-04 09:37:25.896488+00:00 -306.243725  507.547571  13.671875
# 273  273  2014-05-21 04:04:16.795543+00:00  -77.537118  533.294806  41.796875
# 275  275  2014-05-25 11:21:40.359990+00:00  232.611354  414.571444  49.609375
# 276  276  2014-05-27 08:51:10.491000+00:00 -285.046527  507.547571  11.328125
# 277  277  2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
#
#      picks   latitude   longitude      depth
# 0       10  49.206819 -125.232068  49.609375
# 8        6  46.989816 -126.533950  12.890625
# 10       6  48.646430 -126.824766   4.296875
# 11       7  49.457391 -126.769550  24.609375
# 12       6  49.459134 -129.509297   5.078125
# ..     ...        ...         ...        ...
# 266      6  48.989699 -129.684922  13.671875
# 273     10  49.292245 -126.565918  41.796875
# 275      7  48.186967 -122.371453  49.609375
# 276      8  48.999834 -129.395983  11.328125
# 277      6  48.910006 -129.388983   7.421875
#
# [123 rows x 9 columns]

# %%
# The parameters in the associator class: n_picks=2,n_p_picks=1,n_s_picks=1,n_p_and_s_picks=1
fig = plt.figure(figsize=(4, 8))
ax = fig.add_subplot()
ax.set_aspect("equal")

# ax.scatter(events["x"], events["y"], c=events["z"])
ax.set_xlabel("Easting [km]")
ax.set_ylabel("Northing [km]")
cax = fig.add_axes([ax.get_position().x1+0.05,ax.get_position().y0,0.02,ax.get_position().height])
cb1 = fig.colorbar(ax.scatter(events["x"], events["y"], c=events["z"],s=0.5,cmap='viridis'), cax=cax)
cb1.ax.invert_yaxis()

# %%
catalog = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv',index_col=0)
len(catalog)
# Out:
# 23517

# %%
from datetime import datetime


stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
stations['net'] = stations['station'].apply(lambda x: x.split('.')[0])
stations['sta'] = stations['station'].apply(lambda x: x.split('.')[1])
stations['cha'] = stations['station'].apply(lambda x: x.split('.')[3])

picks = pd.read_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t")
events = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t")

events["match_id"] = events["event_index"]
picks["match_id"] = picks["event_index"]
events.sort_values(by="time", inplace=True, ignore_index=True)

out_file = open(f"../hypoInv/hypoInput_{region}.arc", "w")

events['time'] = pd.to_datetime(events['time'])

picks_by_event = picks.groupby("match_id").groups
for i in tqdm(range(len(events))):
    # 2011-01-01 14:29:08.592014
    event = events.iloc[i]
    event_time = datetime.strftime(event["time"],"%Y%m%d%H%M%S%f")[:-4]
    lat_degree = int(event["latitude"])
    lat_minute = (event["latitude"] - lat_degree) * 60 * 100
    south = "S" if lat_degree <= 0 else " "
    lng_degree = int(event["longitude"])
    lng_minute = (event["longitude"] - lng_degree) * 60 * 100
    east = "E" if lng_degree >= 0 else " "
    depth = event["depth_km"]
    if np.sum(picks[picks["event_index"] == events.iloc[i]['match_id']]['type'] == 'p') == 0:
        continue
    event_line = f"{event_time}{abs(lat_degree):2d}{south}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{east}{abs(lng_minute):4.0f}{int(depth * 100):5d}"
    out_file.write(event_line + "\n")

    picks_idx = picks_by_event[event["match_id"]]
    for j in picks_idx:
        pick = picks.iloc[j]
        station_code = pick['id']
        network_code = stations['net'][stations['sta'] == pick['id']].iloc[0]
        comp_code = ''
        channel_code = stations['cha'][stations['sta'] == pick['id']].iloc[0]
        phase_type = pick['type']
        
        # Check if 'prob' column exists
        if 'prob' in pick:
            phase_weight = min(max(int((1 - pick['prob']) / (1 - 0.3) * 4) - 1, 0), 3)
        else:
            phase_weight = 0  # Default value if 'prob' column is missing
        # 2011-01-02 02:11:06.849100+00:00
        # Assuming pick['timestamp'] has the format '2012-01-01 03:19:00.689664+00:00'
        try:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S.%f")  # Handle timezone with %z
        except:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S%z")  # Handle timezone with %z
        phase_time_minute = pick_time.strftime("%Y%m%d%H%M")  # Extract YYYYMMDDHHMM
        phase_time_second = pick_time.strftime("%S%f")[:-4]  # Extract seconds with first two digits of microseconds
        tmp_line = f"{station_code:<5}{network_code:<2} {comp_code:<1}{channel_code:<3}"
        if phase_type.upper() == 'P':
            pick_line = f"{tmp_line:<13} P {phase_weight:<1d}{phase_time_minute} {phase_time_second}"
        elif phase_type.upper() == 'S':
            pick_line = f"{tmp_line:<13}   4{phase_time_minute} {'':<12}{phase_time_second} S {phase_weight:<1d}"
        else:
            raise ValueError(f"Phase type error {phase_type}")
        out_file.write(pick_line + "\n")
    terminator_line = f"{'    '}{'  '}{event_time[8:12]}{event_time[12:16]}{abs(lat_degree):2d}{' '}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{abs(lng_minute):4.0f}{int(depth * 100):5d}"
    out_file.write(terminator_line+'\n')
    # out_file.write("\n")
    if i > 1e5:
        break

out_file.close()
# Out:
# 100%|██████████| 23517/23517 [00:50<00:00, 463.48it/s]
