# %% [markdown]
# ## Notebook for formatting data frames for phase association
# Source:
# - https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file
# - https://www.usgs.gov/software/hypoinverse-earthquake-location
# - https://chatgpt.com/c/67491af9-aaf8-800c-82e9-1033e094d8d0
# - https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2017JB014966

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from pnwstore.mseed import WaveformClient
from obspy import UTCDateTime
from obspy.core.stream import Stream
from obspy.clients.fdsn import Client
from tqdm import tqdm
import datetime

# %% [markdown]
# ### 1.3 Create a CSV file for picks for the association

# %% [markdown]
# ### Format the files for HypoInverse and HypoDD
# References: https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file

# %% [markdown]
# ### Format the station files

# %%
region = 'swa_shelf_trench'
df = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)

# %%
TOFB = df[df['station_code']=='TOFB']

# %%
TOFB['station_network_code'].unique()
# Out:
# array([], dtype=object)

# %%
from obspy import read_inventory
from collections import defaultdict
import pandas as pd

client2 = Client("IRIS")
networks = pd.read_csv("../data/networks.csv")
networks = ','.join(list(networks['networks']))
starttime = UTCDateTime(year=2011, month=1, day=1)
endtime = UTCDateTime(year=2016, month=1, day=1)
inv = [] 
# inv = read_inventory("./stations/*.xml")
station_locs = defaultdict(dict)
# stations=inv


for station in df['station_code'].unique():
    inv += client2.get_stations(network=networks,
                                    station=station, channel="?H?", 
                                    starttime=starttime, endtime=endtime, level="response")
stations=inv

print(len(stations))

for network in stations:
    print(network)
    for station in network:
        print(station)
        has_HH = bool(station.select(channel="HH?"))
        has_BH = bool(station.select(channel="BH?"))

        # Apply selection logic based on channel presence
        if has_HH and has_BH:
            # If both HH and BH channels are present, select only HH
            selected_station = station.select(channel="HH?")
        elif has_HH:
            # If only HH channels are present
            selected_station = station.select(channel="HH?")
        elif has_BH:
            # If only BH channels are present
            selected_station = station.select(channel="BH?")

        for chn in selected_station:
            print('This is chn: ', chn)
            sid = f"{network.code}.{station.code}.{chn.location_code}.{chn.code[:-1]}"
            if sid in station_locs:
                station_locs[sid]["component"] += f",{chn.code[-1]}"
                station_locs[sid]["response"] += f",{chn.response.instrument_sensitivity.value:.2f}"
            else:
                component = f"{chn.code[-1]}"
                response = f"{chn.response.instrument_sensitivity.value:.2f}"
                dtype = chn.response.instrument_sensitivity.input_units.lower()
                tmp_dict = {}
                tmp_dict["longitude"], tmp_dict["latitude"], tmp_dict["elevation(m)"] = (
                    chn.longitude,
                    chn.latitude,
                    chn.elevation,
                )
                tmp_dict["component"], tmp_dict["response"], tmp_dict["unit"] = component, response, dtype
                station_locs[sid] = tmp_dict
            if station_locs[sid]["component"]=='Z':
                station_locs[sid]["response"]= f"0,0,"+station_locs[sid]["response"]
            elif station_locs[sid]["component"]=='N,Z':
                station_locs[sid]["response"]= f"0,"+station_locs[sid]["response"]
station_locs = pd.DataFrame.from_dict(station_locs, orient='index')
station_locs["id"] = station_locs.index
station_locs = station_locs.rename_axis('station').reset_index()
station_locs.to_csv(f"./stations_{region}.csv",sep='\t')
station_locs
# Out:
# 38
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J49A (LDEO Trawl-resistant OBS Site J49A)
# 		Channels (3):
# 			7D.J49A..HHZ, 7D.J49A..HH1, 7D.J49A..HH2
# Station J49A (LDEO Trawl-resistant OBS Site J49A)
# 	Station Code: J49A
# 	Channel Count: 3/5 (Selected/Total)
# 	2011-07-26T00:00:00.000000Z - 2012-07-13T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.4378, Longitude: -124.4275, Elevation: -120.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-07-26 to 2012-07-13
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-07-26T03:51:10.000000Z - 2012-07-13T14:54:58.000000Z
# 	Latitude: 46.4378, Longitude: -124.4275, Elevation: -120.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-07-26T03:51:10.000000Z - 2012-07-13T14:54:58.000000Z
# 	Latitude: 46.4378, Longitude: -124.4275, Elevation: -120.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-07-26T03:51:10.000000Z - 2012-07-13T14:54:58.000000Z
# 	Latitude: 46.4378, Longitude: -124.4275, Elevation: -120.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J49A (Marlette, MI, USA)
# 		Channels (12):
# 			TA.J49A..BHZ, TA.J49A..BHN, TA.J49A..BHE, TA.J49A..LHZ,
# 			TA.J49A..LHN, TA.J49A..LHE, TA.J49A..UHZ, TA.J49A..UHN,
# 			TA.J49A..UHE, TA.J49A..VHZ, TA.J49A..VHN, TA.J49A..VHE
# Station J49A (Marlette, MI, USA)
# 	Station Code: J49A
# 	Channel Count: 12/40 (Selected/Total)
# 	2012-10-16T00:00:00.000000Z - 2014-06-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.3600, Longitude: -83.1389, Elevation: 253.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    40.0 Hz  2012-10-16 to 2014-06-29
# 	    ..LH[ZNE]     1.0 Hz  2012-10-16 to 2014-06-29
# 	    ..VH[ZNE]     0.1 Hz  2012-10-16 to 2014-06-29
# 	    ..UH[ZNE]     0.0 Hz  2012-10-16 to 2014-06-29
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2012-10-16T00:00:00.000000Z - 2014-06-29T15:25:00.000000Z
# 	Latitude: 43.3600, Longitude: -83.1389, Elevation: 253.0 m, Local Depth: 0.0 m
# 	Azimuth: 88.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Guralp CMG3T/Quanterra 330 Linear Phase Composite)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2012-10-16T00:00:00.000000Z - 2014-06-29T15:25:00.000000Z
# 	Latitude: 43.3600, Longitude: -83.1389, Elevation: 253.0 m, Local Depth: 0.0 m
# 	Azimuth: 358.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Guralp CMG3T/Quanterra 330 Linear Phase Composite)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2012-10-16T00:00:00.000000Z - 2014-06-29T15:25:00.000000Z
# 	Latitude: 43.3600, Longitude: -83.1389, Elevation: 253.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Guralp CMG3T/Quanterra 330 Linear Phase Composite)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN07A (LDEO Trawl-Resistant OBS Site FN07A)
# 		Channels (3):
# 			7D.FN07A..HHZ, 7D.FN07A..HH1, 7D.FN07A..HH2
# Station FN07A (LDEO Trawl-Resistant OBS Site FN07A)
# 	Station Code: FN07A
# 	Channel Count: 3/5 (Selected/Total)
# 	2011-07-28T00:00:00.000000Z - 2012-07-20T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.8555, Longitude: -124.7865, Elevation: -154.0 m
# 	Available Channels:
# 	    ..HH[Z1]    125.0 Hz  2011-07-28 to 2012-07-20
# 	    ..HH2       125.0 Hz  2011-07-28 to 2012-07-20
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-07-28T22:35:30.000000Z - 2012-07-20T22:26:54.000000Z
# 	Latitude: 46.8555, Longitude: -124.7865, Elevation: -154.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-07-28T22:35:30.000000Z - 2012-07-20T22:26:53.000000Z
# 	Latitude: 46.8555, Longitude: -124.7865, Elevation: -154.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-07-28T22:35:30.000000Z - 2012-07-20T22:26:54.000000Z
# 	Latitude: 46.8555, Longitude: -124.7865, Elevation: -154.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN14A (LDEO Trawl-Resistant OBS Site FN14A)
# 		Channels (3):
# 			7D.FN14A..HHZ, 7D.FN14A..HH1, 7D.FN14A..HH2
# Station FN14A (LDEO Trawl-Resistant OBS Site FN14A)
# 	Station Code: FN14A
# 	Channel Count: 3/5 (Selected/Total)
# 	2011-07-31T00:00:00.000000Z - 2012-07-20T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.0248, Longitude: -124.9647, Elevation: -173.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-07-31 to 2012-07-20
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-07-31T20:28:00.000000Z - 2012-07-20T05:54:43.000000Z
# 	Latitude: 47.0248, Longitude: -124.9647, Elevation: -173.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-07-31T20:28:00.000000Z - 2012-07-20T05:54:43.000000Z
# 	Latitude: 47.0248, Longitude: -124.9647, Elevation: -173.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-07-31T20:28:00.000000Z - 2012-07-20T05:54:43.000000Z
# 	Latitude: 47.0248, Longitude: -124.9647, Elevation: -173.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J42A (LDEO Standard Deep OBS Site J42A)
# 		Channels (3):
# 			7D.J42A..HHZ, 7D.J42A..HH1, 7D.J42A..HH2
# Station J42A (LDEO Standard Deep OBS Site J42A)
# 	Station Code: J42A
# 	Channel Count: 3/5 (Selected/Total)
# 	2011-10-16T00:00:00.000000Z - 2012-07-17T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.9331, Longitude: -125.2997, Elevation: -1540.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-10-16 to 2012-07-17
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-10-16T20:38:00.000000Z - 2012-07-17T18:46:39.000000Z
# 	Latitude: 45.9331, Longitude: -125.2997, Elevation: -1540.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-10-16T20:38:00.000000Z - 2012-07-17T18:46:39.000000Z
# 	Latitude: 45.9331, Longitude: -125.2997, Elevation: -1540.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-10-16T20:38:00.000000Z - 2012-07-17T18:46:39.000000Z
# 	Latitude: 45.9331, Longitude: -125.2997, Elevation: -1540.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J42A (Columbus, WI, USA)
# 		Channels (12):
# 			TA.J42A..BHZ, TA.J42A..BHN, TA.J42A..BHE, TA.J42A..LHZ,
# 			TA.J42A..LHN, TA.J42A..LHE, TA.J42A..UHZ, TA.J42A..UHN,
# 			TA.J42A..UHE, TA.J42A..VHZ, TA.J42A..VHN, TA.J42A..VHE
# Station J42A (Columbus, WI, USA)
# 	Station Code: J42A
# 	Channel Count: 12/40 (Selected/Total)
# 	2011-10-15T00:00:00.000000Z - 2013-06-11T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.3179, Longitude: -89.1234, Elevation: 313.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    40.0 Hz  2011-10-15 to 2013-06-11
# 	    ..LH[ZNE]     1.0 Hz  2011-10-15 to 2013-06-11
# 	    ..VH[ZNE]     0.1 Hz  2011-10-15 to 2013-06-11
# 	    ..UH[ZNE]     0.0 Hz  2011-10-15 to 2013-06-11
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2011-10-15T00:00:00.000000Z - 2013-06-11T15:10:00.000000Z
# 	Latitude: 43.3179, Longitude: -89.1234, Elevation: 313.0 m, Local Depth: 0.0 m
# 	Azimuth: 88.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2011-10-15T00:00:00.000000Z - 2013-06-11T15:10:00.000000Z
# 	Latitude: 43.3179, Longitude: -89.1234, Elevation: 313.0 m, Local Depth: 0.0 m
# 	Azimuth: 358.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-15T00:00:00.000000Z - 2013-06-11T15:10:00.000000Z
# 	Latitude: 43.3179, Longitude: -89.1234, Elevation: 313.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J50A (LDEO Standard Deep OBS Site J50A)
# 		Channels (3):
# 			7D.J50A..HHZ, 7D.J50A..HH1, 7D.J50A..HH2
# Station J50A (LDEO Standard Deep OBS Site J50A)
# 	Station Code: J50A
# 	Channel Count: 3/5 (Selected/Total)
# 	2011-10-17T00:00:00.000000Z - 2012-07-20T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.6402, Longitude: -125.2991, Elevation: -1909.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-10-17 to 2012-07-20
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-10-17T05:56:30.000000Z - 2012-07-20T17:36:11.000000Z
# 	Latitude: 46.6402, Longitude: -125.2991, Elevation: -1909.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-10-17T05:56:30.000000Z - 2012-07-20T17:36:11.000000Z
# 	Latitude: 46.6402, Longitude: -125.2991, Elevation: -1909.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-10-17T05:56:30.000000Z - 2012-07-20T17:36:11.000000Z
# 	Latitude: 46.6402, Longitude: -125.2991, Elevation: -1909.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J57A (SIO OBS ID J57A)
# 		Channels (3):
# 			7D.J57A..BHZ, 7D.J57A..BH1, 7D.J57A..BH2
# Station J57A (SIO OBS ID J57A)
# 	Station Code: J57A
# 	Channel Count: 3/4 (Selected/Total)
# 	2011-10-17T00:00:00.000000Z - 2012-07-15T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.0801, Longitude: -124.4505, Elevation: -55.8 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-10-17 to 2012-07-15
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-10-17T17:13:00.000000Z - 2012-07-15T22:47:00.000000Z
# 	Latitude: 47.0801, Longitude: -124.4505, Elevation: -55.8 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-10-17T17:13:00.000000Z - 2012-07-15T22:47:00.000000Z
# 	Latitude: 47.0801, Longitude: -124.4505, Elevation: -55.8 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-17T17:13:00.000000Z - 2012-07-15T22:47:00.000000Z
# 	Latitude: 47.0801, Longitude: -124.4505, Elevation: -55.8 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J57A (Williamstown, NY, USA)
# 		Channels (15):
# 			TA.J57A..BHZ, TA.J57A..BHN, TA.J57A..BHE, TA.J57A..HHZ,
# 			TA.J57A..HHN, TA.J57A..HHE, TA.J57A..LHZ, TA.J57A..LHN,
# 			TA.J57A..LHE, TA.J57A..UHZ, TA.J57A..UHN, TA.J57A..UHE,
# 			TA.J57A..VHZ, TA.J57A..VHN, TA.J57A..VHE
# Station J57A (Williamstown, NY, USA)
# 	Station Code: J57A
# 	Channel Count: 15/43 (Selected/Total)
# 	2013-08-22T00:00:00.000000Z - 2015-06-22T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.4099, Longitude: -75.9968, Elevation: 191.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2015-01-20 to 2015-06-22
# 	    ..BH[ZNE]    40.0 Hz  2013-08-22 to 2015-06-22
# 	    ..LH[ZNE]     1.0 Hz  2013-08-22 to 2015-06-22
# 	    ..VH[ZNE]     0.1 Hz  2013-08-22 to 2015-06-22
# 	    ..UH[ZNE]     0.0 Hz  2013-08-22 to 2015-06-22
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-06-22T14:39:27.000000Z
# 	Latitude: 43.4099, Longitude: -75.9968, Elevation: 191.0 m, Local Depth: 0.0 m
# 	Azimuth: 91.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-06-22T14:39:27.000000Z
# 	Latitude: 43.4099, Longitude: -75.9968, Elevation: 191.0 m, Local Depth: 0.0 m
# 	Azimuth: 1.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-06-22T14:39:27.000000Z
# 	Latitude: 43.4099, Longitude: -75.9968, Elevation: 191.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN16A (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.FN16A..HHZ, 7D.FN16A..HH1, 7D.FN16A..HH2
# Station FN16A (LDEO OBS STANDARD DEEP)
# 	Station Code: FN16A
# 	Channel Count: 3/8 (Selected/Total)
# 	2011-10-17T00:00:00.000000Z - 2012-07-21T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.7996, Longitude: -125.5161, Elevation: -1907.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-10-17 to 2012-07-21
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-10-17T21:58:30.000000Z - 2012-07-21T10:23:11.000000Z
# 	Latitude: 46.7996, Longitude: -125.5161, Elevation: -1907.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-10-17T21:58:30.000000Z - 2012-07-21T10:23:11.000000Z
# 	Latitude: 46.7996, Longitude: -125.5161, Elevation: -1907.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-10-17T21:58:30.000000Z - 2012-07-21T10:23:11.000000Z
# 	Latitude: 46.7996, Longitude: -125.5161, Elevation: -1907.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J58A (LDEO Standard Deep OBS)
# 		Channels (3):
# 			7D.J58A..HHZ, 7D.J58A..HH1, 7D.J58A..HH2
# Station J58A (LDEO Standard Deep OBS)
# 	Station Code: J58A
# 	Channel Count: 3/6 (Selected/Total)
# 	2011-10-18T00:00:00.000000Z - 2012-07-11T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-10-18 to 2012-07-11
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-10-18T09:03:00.000000Z - 2012-07-11T18:11:00.000000Z
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-10-18T09:03:00.000000Z - 2012-07-11T18:11:00.000000Z
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-10-18T09:03:00.000000Z - 2012-07-11T18:11:00.000000Z
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J58A (Remsen, NY, USA)
# 		Channels (15):
# 			TA.J58A..BHZ, TA.J58A..BHN, TA.J58A..BHE, TA.J58A..HHZ,
# 			TA.J58A..HHN, TA.J58A..HHE, TA.J58A..LHZ, TA.J58A..LHN,
# 			TA.J58A..LHE, TA.J58A..UHZ, TA.J58A..UHN, TA.J58A..UHE,
# 			TA.J58A..VHZ, TA.J58A..VHN, TA.J58A..VHE
# Station J58A (Remsen, NY, USA)
# 	Station Code: J58A
# 	Channel Count: 15/43 (Selected/Total)
# 	2013-08-27T00:00:00.000000Z - 2015-08-10T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2015-01-20 to 2015-08-10
# 	    ..BH[ZNE]    40.0 Hz  2013-08-27 to 2015-08-10
# 	    ..LH[ZNE]     1.0 Hz  2013-08-27 to 2015-08-10
# 	    ..VH[ZNE]     0.1 Hz  2013-08-27 to 2015-08-10
# 	    ..UH[ZNE]     0.0 Hz  2013-08-27 to 2015-08-10
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-08-10T15:11:16.000000Z
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-08-10T15:11:16.000000Z
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-08-10T15:11:16.000000Z
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M04C (SIO OBS ID M04C)
# 		Channels (3):
# 			7D.M04C..BHZ, 7D.M04C..BH1, 7D.M04C..BH2
# Station M04C (SIO OBS ID M04C)
# 	Station Code: M04C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-29
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T00:31:00.000000Z - 2014-05-29T21:05:12.000000Z
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T00:31:00.000000Z - 2014-05-29T21:05:12.000000Z
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T00:31:00.000000Z - 2014-05-29T21:05:12.000000Z
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.M04C (Macdoel, CA, USA)
# 		Channels (30):
# 			TA.M04C..BHZ (2x), TA.M04C..BHN (2x), TA.M04C..BHE (2x),
# 			TA.M04C..HHZ (2x), TA.M04C..HHN (2x), TA.M04C..HHE (2x),
# 			TA.M04C..LHZ (2x), TA.M04C..LHN (2x), TA.M04C..LHE (2x),
# 			TA.M04C..UHZ (2x), TA.M04C..UHN (2x), TA.M04C..UHE (2x),
# 			TA.M04C..VHZ (2x), TA.M04C..VHN (2x), TA.M04C..VHE (2x)
# Station M04C (Macdoel, CA, USA)
# 	Station Code: M04C
# 	Channel Count: 30/207 (Selected/Total)
# 	2005-06-30T00:00:00.000000Z - 2016-04-25T23:59:59.000000Z
# 	Access: open
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2014-04-15 to 2016-04-25
# 	    ..HH[ZNE]   100.0 Hz  2011-05-02 to 2014-04-15
# 	    ..BH[ZNE]    40.0 Hz  2014-04-15 to 2016-04-25
# 	    ..BH[ZNE]    40.0 Hz  2009-10-11 to 2014-04-15
# 	    ..LH[ZNE]     1.0 Hz  2014-04-15 to 2016-04-25
# 	    ..LH[ZNE]     1.0 Hz  2009-10-11 to 2014-04-15
# 	    ..VH[ZNE]     0.1 Hz  2014-04-15 to 2016-04-25
# 	    ..VH[ZNE]     0.1 Hz  2009-10-11 to 2014-04-15
# 	    ..UH[ZNE]     0.0 Hz  2014-04-15 to 2016-04-25
# 	    ..UH[ZNE]     0.0 Hz  2009-10-11 to 2014-04-15
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2014-04-15T19:55:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2014-04-15T19:55:00.000000Z - 2016-04-25T21:25:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2014-04-15T19:55:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2014-04-15T19:55:00.000000Z - 2016-04-25T21:25:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2014-04-15T19:55:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-04-15T19:55:00.000000Z - 2016-04-25T21:25:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M05C (SIO OBS ID M05C)
# 		Channels (3):
# 			7D.M05C..BHZ, 7D.M05C..BH1, 7D.M05C..BH2
# Station M05C (SIO OBS ID M05C)
# 	Station Code: M05C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.1735, Longitude: -124.9345, Elevation: -837.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-29
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T00:52:00.000000Z - 2014-05-29T12:44:00.000000Z
# 	Latitude: 46.1735, Longitude: -124.9345, Elevation: -837.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T00:52:00.000000Z - 2014-05-29T12:44:00.000000Z
# 	Latitude: 46.1735, Longitude: -124.9345, Elevation: -837.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T00:52:00.000000Z - 2014-05-29T12:44:00.000000Z
# 	Latitude: 46.1735, Longitude: -124.9345, Elevation: -837.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J49C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.J49C..HHZ, 7D.J49C..HH1, 7D.J49C..HH2
# Station J49C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: J49C
# 	Channel Count: 3/7 (Selected/Total)
# 	2013-08-30T00:00:00.000000Z - 2014-06-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.4380, Longitude: -124.4278, Elevation: -113.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-08-31 to 2014-06-29
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-08-31T06:57:00.000000Z - 2014-06-29T05:40:27.000000Z
# 	Latitude: 46.4380, Longitude: -124.4278, Elevation: -113.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-08-31T06:57:00.000000Z - 2014-06-29T05:40:27.000000Z
# 	Latitude: 46.4380, Longitude: -124.4278, Elevation: -113.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-08-31T06:57:00.000000Z - 2014-06-29T05:40:27.000000Z
# 	Latitude: 46.4380, Longitude: -124.4278, Elevation: -113.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN19C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN19C..HHZ, 7D.FN19C..HH1, 7D.FN19C..HH2
# Station FN19C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN19C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-08-30T00:00:00.000000Z - 2014-06-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.7301, Longitude: -124.3668, Elevation: -72.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-08-31 to 2014-06-28
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-08-31T12:22:00.000000Z - 2014-06-28T23:39:05.000000Z
# 	Latitude: 46.7301, Longitude: -124.3668, Elevation: -72.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-08-31T12:22:00.000000Z - 2014-06-28T23:39:05.000000Z
# 	Latitude: 46.7301, Longitude: -124.3668, Elevation: -72.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-08-31T12:22:00.000000Z - 2014-06-28T23:39:05.000000Z
# 	Latitude: 46.7301, Longitude: -124.3668, Elevation: -72.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN01C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN01C..HHZ, 7D.FN01C..HH1, 7D.FN01C..HH2
# Station FN01C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN01C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-08-30T00:00:00.000000Z - 2014-06-27T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.8823, Longitude: -124.3333, Elevation: -56.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-08-31 to 2014-06-27
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-08-31T16:14:00.000000Z - 2014-06-27T05:00:17.000000Z
# 	Latitude: 46.8823, Longitude: -124.3333, Elevation: -56.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-08-31T16:14:00.000000Z - 2014-06-27T05:00:17.000000Z
# 	Latitude: 46.8823, Longitude: -124.3333, Elevation: -56.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-08-31T16:14:00.000000Z - 2014-06-27T05:00:17.000000Z
# 	Latitude: 46.8823, Longitude: -124.3333, Elevation: -56.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN02C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN02C..HHZ, 7D.FN02C..HH1, 7D.FN02C..HH2
# Station FN02C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN02C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-08-31T00:00:00.000000Z - 2014-06-28T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.9497, Longitude: -124.4280, Elevation: -67.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-08-31 to 2014-06-28
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-08-31T20:23:00.000000Z - 2014-06-28T19:03:07.000000Z
# 	Latitude: 46.9497, Longitude: -124.4280, Elevation: -67.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-08-31T20:23:00.000000Z - 2014-06-28T19:03:07.000000Z
# 	Latitude: 46.9497, Longitude: -124.4280, Elevation: -67.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-08-31T20:23:00.000000Z - 2014-06-28T19:03:07.000000Z
# 	Latitude: 46.9497, Longitude: -124.4280, Elevation: -67.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN03C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN03C..HHZ, 7D.FN03C..HH1, 7D.FN03C..HH2
# Station FN03C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN03C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-08-31T00:00:00.000000Z - 2014-06-28T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.8872, Longitude: -124.5251, Elevation: -93.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-01 to 2014-06-28
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-01T08:28:00.000000Z - 2014-06-28T21:50:45.000000Z
# 	Latitude: 46.8872, Longitude: -124.5251, Elevation: -93.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-01T08:28:00.000000Z - 2014-06-28T21:50:45.000000Z
# 	Latitude: 46.8872, Longitude: -124.5251, Elevation: -93.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-01T08:28:00.000000Z - 2014-06-28T21:50:45.000000Z
# 	Latitude: 46.8872, Longitude: -124.5251, Elevation: -93.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN04C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN04C..HHZ, 7D.FN04C..HH1, 7D.FN04C..HH2
# Station FN04C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN04C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-08-31T00:00:00.000000Z - 2014-06-26T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.9175, Longitude: -124.6013, Elevation: -104.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-01 to 2014-06-26
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-01T11:56:00.000000Z - 2014-06-26T01:52:11.000000Z
# 	Latitude: 46.9175, Longitude: -124.6013, Elevation: -104.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-01T11:56:00.000000Z - 2014-06-26T01:52:11.000000Z
# 	Latitude: 46.9175, Longitude: -124.6013, Elevation: -104.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-01T11:56:00.000000Z - 2014-06-26T01:52:11.000000Z
# 	Latitude: 46.9175, Longitude: -124.6013, Elevation: -104.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN05C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN05C..HHZ, 7D.FN05C..HH1, 7D.FN05C..HH2
# Station FN05C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN05C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-08-31T00:00:00.000000Z - 2014-06-26T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.8575, Longitude: -124.6556, Elevation: -123.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-01 to 2014-06-25
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-01T15:07:00.000000Z - 2014-06-25T23:16:14.000000Z
# 	Latitude: 46.8575, Longitude: -124.6556, Elevation: -123.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-01T15:07:00.000000Z - 2014-06-25T23:16:14.000000Z
# 	Latitude: 46.8575, Longitude: -124.6556, Elevation: -123.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-01T15:07:00.000000Z - 2014-06-25T23:16:14.000000Z
# 	Latitude: 46.8575, Longitude: -124.6556, Elevation: -123.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN07C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN07C..HHZ, 7D.FN07C..HH1, 7D.FN07C..HH2
# Station FN07C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN07C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-01T00:00:00.000000Z - 2014-06-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.8554, Longitude: -124.7860, Elevation: -158.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-02 to 2014-06-29
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-02T08:09:00.000000Z - 2014-06-29T20:03:00.000000Z
# 	Latitude: 46.8554, Longitude: -124.7860, Elevation: -158.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-02T08:09:00.000000Z - 2014-06-29T20:03:00.000000Z
# 	Latitude: 46.8554, Longitude: -124.7860, Elevation: -158.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# ...
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-05T15:31:00.000000Z - 2014-06-27T22:09:20.000000Z
# 	Latitude: 47.3178, Longitude: -125.5346, Elevation: -1527.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J42C (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.J42C..HHZ, 7D.J42C..HH1, 7D.J42C..HH2
# Station J42C (LDEO OBS STANDARD DEEP)
# 	Station Code: J42C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-05T00:00:00.000000Z - 2014-06-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.9323, Longitude: -125.2991, Elevation: -1550.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-06 to 2014-06-29
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-06T12:03:00.000000Z - 2014-06-29T15:42:30.000000Z
# 	Latitude: 45.9323, Longitude: -125.2991, Elevation: -1550.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-06T12:03:00.000000Z - 2014-06-29T15:42:30.000000Z
# 	Latitude: 45.9323, Longitude: -125.2991, Elevation: -1550.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-06T12:03:00.000000Z - 2014-06-29T15:42:30.000000Z
# 	Latitude: 45.9323, Longitude: -125.2991, Elevation: -1550.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN06C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN06C..HHZ, 7D.FN06C..HH1, 7D.FN06C..HH2
# Station FN06C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN06C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-01T00:00:00.000000Z - 2014-06-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.9220, Longitude: -124.7313, Elevation: -137.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-01 to 2014-06-29
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-01T19:36:30.000000Z - 2014-06-29T17:50:14.000000Z
# 	Latitude: 46.9220, Longitude: -124.7313, Elevation: -137.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-01T19:36:30.000000Z - 2014-06-29T17:50:14.000000Z
# 	Latitude: 46.9220, Longitude: -124.7313, Elevation: -137.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-01T19:36:30.000000Z - 2014-06-29T17:50:14.000000Z
# 	Latitude: 46.9220, Longitude: -124.7313, Elevation: -137.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN17C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN17C..HHZ, 7D.FN17C..HH1, 7D.FN17C..HH2
# Station FN17C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN17C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-03T00:00:00.000000Z - 2014-06-25T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.6816, Longitude: -125.0005, Elevation: -1015.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-04 to 2014-06-01
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-04T15:24:00.000000Z - 2014-06-01T11:28:13.000000Z
# 	Latitude: 46.6816, Longitude: -125.0005, Elevation: -1015.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-04T15:24:00.000000Z - 2014-06-01T11:28:13.000000Z
# 	Latitude: 46.6816, Longitude: -125.0005, Elevation: -1015.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-04T15:24:00.000000Z - 2014-06-01T11:28:13.000000Z
# 	Latitude: 46.6816, Longitude: -125.0005, Elevation: -1015.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN16C (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.FN16C..HHZ, 7D.FN16C..HH1, 7D.FN16C..HH2
# Station FN16C (LDEO OBS STANDARD DEEP)
# 	Station Code: FN16C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-04T00:00:00.000000Z - 2014-06-30T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.8005, Longitude: -125.5001, Elevation: -1728.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-05 to 2014-06-30
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-05T08:06:00.000000Z - 2014-06-30T18:31:01.000000Z
# 	Latitude: 46.8005, Longitude: -125.5001, Elevation: -1728.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-05T08:06:00.000000Z - 2014-06-30T18:31:01.000000Z
# 	Latitude: 46.8005, Longitude: -125.5001, Elevation: -1728.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-05T08:06:00.000000Z - 2014-06-30T18:31:01.000000Z
# 	Latitude: 46.8005, Longitude: -125.5001, Elevation: -1728.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN18C (LDEO OBS TRAWL-RESISTANT)
# 		Channels (3):
# 			7D.FN18C..HHZ, 7D.FN18C..HH1, 7D.FN18C..HH2
# Station FN18C (LDEO OBS TRAWL-RESISTANT)
# 	Station Code: FN18C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-02T00:00:00.000000Z - 2014-06-25T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.7001, Longitude: -124.7248, Elevation: -166.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-03 to 2014-06-25
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-03T09:13:00.000000Z - 2014-06-25T19:37:35.000000Z
# 	Latitude: 46.7001, Longitude: -124.7248, Elevation: -166.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-03T09:13:00.000000Z - 2014-06-25T19:37:35.000000Z
# 	Latitude: 46.7001, Longitude: -124.7248, Elevation: -166.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-03T09:13:00.000000Z - 2014-06-25T19:37:35.000000Z
# 	Latitude: 46.7001, Longitude: -124.7248, Elevation: -166.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
#          station   longitude   latitude  elevation(m)    component  \
# 0    7D.J49A..HH -124.427498  46.437801        -120.0        1,2,Z
# 1    TA.J49A..BH  -83.138901  43.360001         253.0        E,N,Z
# 2   7D.FN07A..HH -124.786499  46.855499        -154.0        1,2,Z
# 3   7D.FN14A..HH -124.964699  47.024799        -173.0        1,2,Z
# 4    7D.J42A..HH -125.299698  45.933102       -1540.0        1,2,Z
# 5    TA.J42A..BH  -89.123398  43.317902         313.0        E,N,Z
# 6    7D.J50A..HH -125.299103  46.640202       -1909.0        1,2,Z
# 7    7D.J57A..BH -124.450500  47.080101         -55.8        1,2,Z
# 8    TA.J57A..HH  -75.996803  43.409901         191.0        E,N,Z
# 9   7D.FN16A..HH -125.516098  46.799599       -1907.0        1,2,Z
# 10   7D.J58A..HH -125.534401  47.318802       -1511.0        1,2,Z
# 11   TA.J58A..HH  -75.285202  43.360298         436.0        E,N,Z
# 12   7D.M04C..BH -125.192299  47.558399        -570.0        1,2,Z
# 13   TA.M04C..HH -121.839302  41.782600        1391.0  E,E,N,N,Z,Z
# 14   7D.M05C..BH -124.934502  46.173500        -837.0        1,2,Z
# 15   7D.J49C..HH -124.427803  46.438000        -113.0        1,2,Z
# 16  7D.FN19C..HH -124.366798  46.730099         -72.0        1,2,Z
# 17  7D.FN01C..HH -124.333298  46.882301         -56.0        1,2,Z
# 18  7D.FN02C..HH -124.428001  46.949699         -67.0        1,2,Z
# 19  7D.FN03C..HH -124.525101  46.887199         -93.0        1,2,Z
# 20  7D.FN04C..HH -124.601303  46.917500        -104.0        1,2,Z
# 21  7D.FN05C..HH -124.655602  46.857498        -123.0        1,2,Z
# 22  7D.FN07C..HH -124.786003  46.855400        -158.0        1,2,Z
# 23  7D.FN08C..HH -124.875999  46.888699        -176.0        1,2,Z
# 24  7D.FN09C..HH -124.887199  46.840199        -198.0        1,2,Z
# 25  7D.FN10C..HH -124.993500  46.898102        -811.0        1,2,Z
# 26   7D.J57C..HH -124.450600  47.080399         -67.0        1,2,Z
# 27  7D.FN14C..HH -124.964203  47.024899        -173.0        1,2,Z
# 28  7D.FN12C..HH -125.119003  46.888699        -656.0        1,2,Z
# 29  7D.FN11C..HH -125.045403  46.820499        -619.0        1,2,Z
# 30   7D.J50C..HH -125.298698  46.641102       -1931.0        1,2,Z
# 31  7D.FN13C..HH -125.301102  47.000401       -1764.0        1,2,Z
# 32   7D.J58C..HH -125.534599  47.317799       -1527.0        1,2,Z
# 33   7D.J42C..HH -125.299103  45.932301       -1550.0        1,2,Z
# 34  7D.FN06C..HH -124.731300  46.922001        -137.0        1,2,Z
# 35  7D.FN17C..HH -125.000504  46.681599       -1015.0        1,2,Z
# 36  7D.FN16C..HH -125.500099  46.800499       -1728.0        1,2,Z
# 37  7D.FN18C..HH -124.724800  46.700100        -166.0        1,2,Z
#
#                                              response unit            id
# 0              971188000.00,971188000.00,971188000.00  m/s   7D.J49A..HH
# 1              630907000.00,630907000.00,630907000.00  m/s   TA.J49A..BH
# 2              971188000.00,971188000.00,971188000.00  m/s  7D.FN07A..HH
# 3              971188000.00,971188000.00,971188000.00  m/s  7D.FN14A..HH
# 4              971188000.00,971188000.00,971188000.00  m/s   7D.J42A..HH
# 5              627192000.00,627192000.00,627192000.00  m/s   TA.J42A..BH
# 6              971188000.00,971188000.00,971188000.00  m/s   7D.J50A..HH
# 7           1846390000.00,1846390000.00,1846390000.00  m/s   7D.J57A..BH
# 8              627604000.00,627604000.00,627604000.00  m/s   TA.J57A..HH
# 9              971188000.00,971188000.00,971188000.00  m/s  7D.FN16A..HH
# 10             971188000.00,971188000.00,971188000.00  m/s   7D.J58A..HH
# 11             627604000.00,627604000.00,627604000.00  m/s   TA.J58A..HH
# 12          1846390000.00,1846390000.00,1846390000.00  m/s   7D.M04C..BH
# 13  502116000.00,502116000.00,502116000.00,5021160...  m/s   TA.M04C..HH
# 14          1846390000.00,1846390000.00,1846390000.00  m/s   7D.M05C..BH
# 15             971188000.00,971188000.00,971188000.00  m/s   7D.J49C..HH
# 16             971188000.00,971188000.00,971188000.00  m/s  7D.FN19C..HH
# 17             971188000.00,971188000.00,971188000.00  m/s  7D.FN01C..HH
# 18             971188000.00,971188000.00,971188000.00  m/s  7D.FN02C..HH
# 19             971188000.00,971188000.00,971188000.00  m/s  7D.FN03C..HH
# 20             971188000.00,971188000.00,971188000.00  m/s  7D.FN04C..HH
# 21             971188000.00,971188000.00,971188000.00  m/s  7D.FN05C..HH
# 22             971188000.00,971188000.00,971188000.00  m/s  7D.FN07C..HH
# 23             971188000.00,971188000.00,971188000.00  m/s  7D.FN08C..HH
# 24             971188000.00,971188000.00,971188000.00  m/s  7D.FN09C..HH
# 25             971188000.00,971188000.00,971188000.00  m/s  7D.FN10C..HH
# 26             971188000.00,971188000.00,971188000.00  m/s   7D.J57C..HH
# 27             971188000.00,971188000.00,971188000.00  m/s  7D.FN14C..HH
# 28             971188000.00,971188000.00,971188000.00  m/s  7D.FN12C..HH
# 29             971188000.00,971188000.00,971188000.00  m/s  7D.FN11C..HH
# 30             971188000.00,971188000.00,971188000.00  m/s   7D.J50C..HH
# 31             971188000.00,971188000.00,971188000.00  m/s  7D.FN13C..HH
# 32             971188000.00,971188000.00,971188000.00  m/s   7D.J58C..HH
# 33             971188000.00,971188000.00,971188000.00  m/s   7D.J42C..HH
# 34             971188000.00,971188000.00,971188000.00  m/s  7D.FN06C..HH
# 35             971188000.00,971188000.00,971188000.00  m/s  7D.FN17C..HH
# 36             971188000.00,971188000.00,971188000.00  m/s  7D.FN16C..HH
# 37             971188000.00,971188000.00,971188000.00  m/s  7D.FN18C..HH

# %% [markdown]
# ### Convert the station file from a CSV file to dat files

# %%
stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
converted_hypoinverse = []
converted_hypoDD = {}

for i in tqdm(range(len(stations))):

    network_code, station_code, comp_code, channel_code = stations.iloc[i]['station'].split('.')
    station_weight = " "
    lat_degree = int(stations.iloc[i]['latitude'])
    lat_minute = (stations.iloc[i]['latitude'] - lat_degree) * 60
    north = "N" if lat_degree >= 0 else "S"
    lng_degree = int(stations.iloc[i]['longitude'])
    lng_minute = (stations.iloc[i]['longitude'] - lng_degree) * 60
    west = "W" if lng_degree <= 0 else "E"
    elevation = stations.iloc[i]['elevation(m)']
    line_hypoinverse = f"{station_code:<5} {network_code:<2} {comp_code[:-1]:<1}{channel_code:<3} {station_weight}{abs(lat_degree):2.0f} {abs(lat_minute):7.4f}{north}{abs(lng_degree):3.0f} {abs(lng_minute):7.4f}{west}{elevation:4.0f}\n"
    converted_hypoinverse.append(line_hypoinverse)
    converted_hypoDD[f"{station_code}"] = f"{network_code:<2}{station_code:<5} {stations.iloc[i]['latitude']:.3f} {stations.iloc[i]['longitude']:.3f} {elevation:4.0f}\n"

out_file = f'stations_hypoinverse_{region}.dat'
with open(out_file, 'w') as f:
    f.writelines(converted_hypoinverse)

out_file = f'stations_hypoDD_{region}.dat'
with open(out_file, 'w') as f:
    for k, v in converted_hypoDD.items():
        f.write(v)
# Out:
# 100%|██████████| 38/38 [00:00<00:00, 5467.52it/s]

# %% [markdown]
# ### Format the pick files

# %%
# Load necessary files
# Load all event data into a list of DataFrames
import datetime 
pick_assignment_files = [
    f'../data/datasets_{region}/all_pick_assignments_{region}.csv'
]

# Read all event files into DataFrames
dfs = [pd.read_csv(file, index_col=0) for file in pick_assignment_files]

# Concatenate all DataFrames into a single DataFrame
assignments =  pd.concat(dfs)

assignments = assignments.rename(columns={"time": "origin_time"})
assignments['origin_time'] = pd.to_datetime(assignments['origin_time'], utc = True)
assignments["pick_time"] = assignments["time_pick"].apply(datetime.datetime.fromtimestamp, tz=datetime.timezone.utc)
assignments = assignments.sort_values(by='origin_time').reset_index(drop=True)

# Reset the idx column so that each group with the same 'time' has a new numbered event index
assignments['idx'] = assignments.groupby('origin_time').ngroup()


# picks = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)
# picks = picks.sort_values(by='trace_start_time').reset_index(drop=True)

# %%
assignments
# Out:
#           idx                      origin_time          x           y  \
# 0           0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 1           0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 2           0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 3           0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 4           0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# ...       ...                              ...        ...         ...
# 162858  26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162859  26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162860  26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162861  26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162862  26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
#
#                 z  picks   latitude   longitude      depth  event_idx  \
# 0        0.390625      6  46.795434 -124.323648   0.390625          2
# 1        0.390625      6  46.795434 -124.323648   0.390625          2
# 2        0.390625      6  46.795434 -124.323648   0.390625          2
# 3        0.390625      6  46.795434 -124.323648   0.390625          2
# 4        0.390625      6  46.795434 -124.323648   0.390625          2
# ...           ...    ...        ...         ...        ...        ...
# 162858  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162859  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162860  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162861  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162862  37.109375      6  46.619156 -124.793571  37.109375      96669
#
#         pick_idx  residual station phase     time_pick   pick_id  \
# 0          17464 -0.530608   FN07A     P  1.312886e+09    712572
# 1        3034713 -0.160235   FN07A     S  1.312886e+09    712186
# 2          17209 -0.348758   FN14A     P  1.312886e+09    711536
# 3        3034386  0.828527   FN14A     S  1.312886e+09    711742
# 4          17010  0.505961    J49A     P  1.312886e+09    709571
# ...          ...       ...     ...   ...           ...       ...
# 162858   5888811  0.012324   FN03C     S  1.403969e+09  15643840
# 162859   5889230 -0.039125   FN12C     S  1.403969e+09  15644694
# 162860   3011750  1.222291    J49C     P  1.403969e+09  15649077
# 162861   5890779 -0.647115    J49C     S  1.403969e+09  15649834
# 162862   5889517  0.638240    J57C     S  1.403969e+09  15645175
#
#                               pick_time
# 0      2011-08-09 10:26:27.133000+00:00
# 1      2011-08-09 10:26:33.749000+00:00
# 2      2011-08-09 10:26:29.786000+00:00
# 3      2011-08-09 10:26:39.018000+00:00
# 4      2011-08-09 10:26:28.808000+00:00
# ...                                 ...
# 162858 2014-06-28 15:26:43.640800+00:00
# 162859 2014-06-28 15:26:43.880900+00:00
# 162860 2014-06-28 15:26:38.965100+00:00
# 162861 2014-06-28 15:26:42.701100+00:00
# 162862 2014-06-28 15:26:48.192900+00:00
#
# [162863 rows x 17 columns]

# %%
# Merge the picks and assignments DataFrames on the pick_id column

# Convert the datetime columns to datetime objects
# picks['trace_p_arrival'] = pd.to_datetime(picks['trace_p_arrival'])
# picks['trace_s_arrival'] = pd.to_datetime(picks['trace_s_arrival'])
assignments['pick_time'] = pd.to_datetime(assignments['pick_time'])

# picks = pd.merge(picks, assignments, left_on="pick_id", right_on="pick_id", how='left')

# # Fill NaN values and convert idx columns to integers
# picks = picks.fillna(-1).astype({'idx': int})

# # Rename columns for consistency
# picks = picks.rename(columns={"station_code": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
# picks['type'] = picks['type'].str.lower()

# Rename columns for consistency
assignments = assignments.rename(columns={"station": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
assignments['type'] = assignments['type'].str.lower()

# %%
# picks.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
#                     date_format='%Y-%m-%dT%H:%M:%S.%f',
#                     columns=["id", "timestamp", "type", "event_index"])
assignments.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["id", "timestamp", "type", "event_index"])

# %%
assignments
# Out:
#         event_index                      origin_time          x           y  \
# 0                 0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 1                 0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 2                 0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 3                 0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# 4                 0 2011-08-09 10:26:19.132811+00:00  89.809180  255.796826
# ...             ...                              ...        ...         ...
# 162858        26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162859        26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162860        26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162861        26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
# 162862        26318 2014-06-28 15:26:30.086334+00:00  54.108636  235.771199
#
#                 z  picks   latitude   longitude      depth  event_idx  \
# 0        0.390625      6  46.795434 -124.323648   0.390625          2
# 1        0.390625      6  46.795434 -124.323648   0.390625          2
# 2        0.390625      6  46.795434 -124.323648   0.390625          2
# 3        0.390625      6  46.795434 -124.323648   0.390625          2
# 4        0.390625      6  46.795434 -124.323648   0.390625          2
# ...           ...    ...        ...         ...        ...        ...
# 162858  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162859  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162860  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162861  37.109375      6  46.619156 -124.793571  37.109375      96669
# 162862  37.109375      6  46.619156 -124.793571  37.109375      96669
#
#         pick_idx  residual     id type     time_pick   pick_id  \
# 0          17464 -0.530608  FN07A    p  1.312886e+09    712572
# 1        3034713 -0.160235  FN07A    s  1.312886e+09    712186
# 2          17209 -0.348758  FN14A    p  1.312886e+09    711536
# 3        3034386  0.828527  FN14A    s  1.312886e+09    711742
# 4          17010  0.505961   J49A    p  1.312886e+09    709571
# ...          ...       ...    ...  ...           ...       ...
# 162858   5888811  0.012324  FN03C    s  1.403969e+09  15643840
# 162859   5889230 -0.039125  FN12C    s  1.403969e+09  15644694
# 162860   3011750  1.222291   J49C    p  1.403969e+09  15649077
# 162861   5890779 -0.647115   J49C    s  1.403969e+09  15649834
# 162862   5889517  0.638240   J57C    s  1.403969e+09  15645175
#
#                               timestamp
# 0      2011-08-09 10:26:27.133000+00:00
# 1      2011-08-09 10:26:33.749000+00:00
# 2      2011-08-09 10:26:29.786000+00:00
# 3      2011-08-09 10:26:39.018000+00:00
# 4      2011-08-09 10:26:28.808000+00:00
# ...                                 ...
# 162858 2014-06-28 15:26:43.640800+00:00
# 162859 2014-06-28 15:26:43.880900+00:00
# 162860 2014-06-28 15:26:38.965100+00:00
# 162861 2014-06-28 15:26:42.701100+00:00
# 162862 2014-06-28 15:26:48.192900+00:00
#
# [162863 rows x 17 columns]

# %% [markdown]
# ### Format event files

# %%
catalog = assignments.drop_duplicates(subset='event_idx')

# %%
catalog = catalog.rename(columns={'origin_time':'time',"depth": "depth_km",'idx':'event_index'})

# %%
catalog
# Out:
#         event_index                             time           x           y  \
# 0                 0 2011-08-09 10:26:19.132811+00:00   89.809180  255.796826
# 6                 1 2011-09-06 02:20:45.987458+00:00  150.053847  447.470689
# 12                2 2011-10-16 22:22:10.356972+00:00   55.224278  262.948836
# 18                3 2011-10-18 19:52:35.725327+00:00   80.884044  -18.840350
# 24                4 2011-10-18 23:16:12.259843+00:00  116.584587  307.291297
# ...             ...                              ...         ...         ...
# 162833        26314 2014-06-27 18:32:09.672467+00:00   25.101945  107.035022
# 162839        26315 2014-06-28 03:39:41.802026+00:00   38.489648  207.163160
# 162845        26316 2014-06-28 04:31:17.685598+00:00  143.359995  240.062405
# 162851        26317 2014-06-28 05:37:14.863551+00:00  143.359995  254.366424
# 162857        26318 2014-06-28 15:26:30.086334+00:00   54.108636  235.771199
#
#                 z  picks   latitude   longitude   depth_km  event_idx  \
# 0        0.390625      6  46.795434 -124.323648   0.390625          2
# 6       19.140625      6  48.507501 -123.469189  19.140625         12
# 12       0.390625      6  46.863524 -124.775741   0.390625         39
# 18      49.609375      6  44.325950 -124.485982  49.609375         49
# 24      33.984375      8  47.254326 -123.959784  33.984375         51
# ...           ...    ...        ...         ...        ...        ...
# 162833  13.671875      6  45.462688 -125.179043  13.671875      96627
# 162839  12.890625      6  46.362886 -124.999844  12.890625      96653
# 162845  49.609375      6  46.644614 -123.627434  49.609375      96655
# 162851  36.328125      6  46.773218 -123.622980  36.328125      96657
# 162857  37.109375      6  46.619156 -124.793571  37.109375      96669
#
#         pick_idx  residual     id type     time_pick   pick_id  \
# 0          17464 -0.530608  FN07A    p  1.312886e+09    712572
# 6        3084270 -0.151578   J49A    s  1.315276e+09    965327
# 12        129563 -1.146687  FN07A    p  1.318804e+09   1321332
# 18       3158777  0.240079   J49A    s  1.318968e+09   1347877
# 24        135368 -0.315616   J57A    p  1.318980e+09   1349459
# ...          ...       ...    ...  ...           ...       ...
# 162833   3009072  1.146371  FN07C    p  1.403894e+09  15639654
# 162839   5890100 -0.772335   J49C    s  1.403927e+09  15648774
# 162845   3012526  0.668001  FN02C    p  1.403930e+09  15650557
# 162851   5890378 -0.152890   J49C    s  1.403934e+09  15649095
# 162857   3010990 -1.186613   J57C    p  1.403969e+09  15645700
#
#                               timestamp
# 0      2011-08-09 10:26:27.133000+00:00
# 6      2011-09-06 02:21:41.683000+00:00
# 12     2011-10-16 22:22:09.737000+00:00
# 18     2011-10-18 19:53:31.118000+00:00
# 24     2011-10-18 23:16:20.130500+00:00
# ...                                 ...
# 162833 2014-06-27 18:32:32.606700+00:00
# 162839 2014-06-28 03:39:54.333100+00:00
# 162845 2014-06-28 04:31:30.557200+00:00
# 162851 2014-06-28 05:37:34.965100+00:00
# 162857 2014-06-28 15:26:38.984900+00:00
#
# [26319 rows x 17 columns]

# %%
catalog.to_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t", index=False,
                    float_format="%.3f",
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["time", "longitude", "latitude", "depth_km",'event_index'])

# %%
events = pd.read_csv(f'../data/datasets_nwa_shelf_trench/events_nwa_shelf_trench.csv', index_col=0)
events
# Out:
#      idx                              time           x           y          z  \
# 0      0  2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 8      8  2011-01-03 22:30:53.445832+00:00  -78.652760  277.252856  12.890625
# 10    10  2011-01-05 05:25:45.145580+00:00  -97.618674  461.774708   4.296875
# 11    11  2011-01-05 09:29:58.041704+00:00  -92.040464  551.890032  24.609375
# 12    12  2011-01-05 14:35:15.536295+00:00 -290.624737  559.042042   5.078125
# ..   ...                               ...         ...         ...        ...
# 266  266  2014-05-04 09:37:25.896488+00:00 -306.243725  507.547571  13.671875
# 273  273  2014-05-21 04:04:16.795543+00:00  -77.537118  533.294806  41.796875
# 275  275  2014-05-25 11:21:40.359990+00:00  232.611354  414.571444  49.609375
# 276  276  2014-05-27 08:51:10.491000+00:00 -285.046527  507.547571  11.328125
# 277  277  2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
#
#      picks   latitude   longitude      depth
# 0       10  49.206819 -125.232068  49.609375
# 8        6  46.989816 -126.533950  12.890625
# 10       6  48.646430 -126.824766   4.296875
# 11       7  49.457391 -126.769550  24.609375
# 12       6  49.459134 -129.509297   5.078125
# ..     ...        ...         ...        ...
# 266      6  48.989699 -129.684922  13.671875
# 273     10  49.292245 -126.565918  41.796875
# 275      7  48.186967 -122.371453  49.609375
# 276      8  48.999834 -129.395983  11.328125
# 277      6  48.910006 -129.388983   7.421875
#
# [123 rows x 9 columns]

# %%
# The parameters in the associator class: n_picks=2,n_p_picks=1,n_s_picks=1,n_p_and_s_picks=1
fig = plt.figure(figsize=(4, 8))
ax = fig.add_subplot()
ax.set_aspect("equal")

# ax.scatter(events["x"], events["y"], c=events["z"])
ax.set_xlabel("Easting [km]")
ax.set_ylabel("Northing [km]")
cax = fig.add_axes([ax.get_position().x1+0.05,ax.get_position().y0,0.02,ax.get_position().height])
cb1 = fig.colorbar(ax.scatter(events["x"], events["y"], c=events["z"],s=0.5,cmap='viridis'), cax=cax)
cb1.ax.invert_yaxis()

# %%
catalog = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv',index_col=0)
len(catalog)
# Out:
# 26319

# %%
from datetime import datetime

region = 'swa_shelf_trench'
stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
stations['net'] = stations['station'].apply(lambda x: x.split('.')[0])
stations['sta'] = stations['station'].apply(lambda x: x.split('.')[1])
stations['cha'] = stations['station'].apply(lambda x: x.split('.')[3])

picks = pd.read_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t")
events = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t")

events["match_id"] = events["event_index"]
picks["match_id"] = picks["event_index"]
events.sort_values(by="time", inplace=True, ignore_index=True)

out_file = open(f"../hypoInv/hypoInput_{region}.arc", "w")

events['time'] = pd.to_datetime(events['time'])

picks_by_event = picks.groupby("match_id").groups
for i in tqdm(range(len(events))):
    # 2011-01-01 14:29:08.592014
    event = events.iloc[i]
    event_time = datetime.strftime(event["time"],"%Y%m%d%H%M%S%f")[:-4]
    lat_degree = int(event["latitude"])
    lat_minute = (event["latitude"] - lat_degree) * 60 * 100
    south = "S" if lat_degree <= 0 else " "
    lng_degree = int(event["longitude"])
    lng_minute = (event["longitude"] - lng_degree) * 60 * 100
    east = "E" if lng_degree >= 0 else " "
    depth = event["depth_km"]
    if np.sum(picks[picks["event_index"] == events.iloc[i]['match_id']]['type'] == 'p') == 0:
        continue
    event_line = f"{event_time}{abs(lat_degree):2d}{south}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{east}{abs(lng_minute):4.0f}{int(depth * 100):5d}"
    out_file.write(event_line + "\n")

    picks_idx = picks_by_event[event["match_id"]]
    for j in picks_idx:
        pick = picks.iloc[j]
        station_code = pick['id']
        network_code = stations['net'][stations['sta'] == pick['id']].iloc[0]
        comp_code = ''
        channel_code = stations['cha'][stations['sta'] == pick['id']].iloc[0]
        phase_type = pick['type']
        
        # Check if 'prob' column exists
        if 'prob' in pick:
            phase_weight = min(max(int((1 - pick['prob']) / (1 - 0.3) * 4) - 1, 0), 3)
        else:
            phase_weight = 0  # Default value if 'prob' column is missing
        # 2011-01-02 02:11:06.849100+00:00
        # Assuming pick['timestamp'] has the format '2012-01-01 03:19:00.689664+00:00'
        try:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S.%f")  # Handle timezone with %z
        except:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S%z")  # Handle timezone with %z
        phase_time_minute = pick_time.strftime("%Y%m%d%H%M")  # Extract YYYYMMDDHHMM
        phase_time_second = pick_time.strftime("%S%f")[:-4]  # Extract seconds with first two digits of microseconds
        tmp_line = f"{station_code:<5}{network_code:<2} {comp_code:<1}{channel_code:<3}"
        if phase_type.upper() == 'P':
            pick_line = f"{tmp_line:<13} P {phase_weight:<1d}{phase_time_minute} {phase_time_second}"
        elif phase_type.upper() == 'S':
            pick_line = f"{tmp_line:<13}   4{phase_time_minute} {'':<12}{phase_time_second} S {phase_weight:<1d}"
        else:
            raise ValueError(f"Phase type error {phase_type}")
        out_file.write(pick_line + "\n")
    terminator_line = f"{'    '}{'  '}{event_time[8:12]}{event_time[12:16]}{abs(lat_degree):2d}{' '}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{abs(lng_minute):4.0f}{int(depth * 100):5d}"
    out_file.write(terminator_line+'\n')
    # out_file.write("\n")
    if i > 1e5:
        break

out_file.close()
# Out:
# 100%|██████████| 26319/26319 [00:41<00:00, 640.94it/s]
