# %% [markdown]
# Notebook for matching the relocated events with catalogs by ANSS and Morton (2023)
#
# by Hiroto Bito (hbito@uw.edu)

# %%
import os
import sys
import pandas as pd
import numpy as np
import obspy
from tqdm import tqdm

from obspy.clients.fdsn import Client
from obspy.clients.fdsn import Client as FDSNClient

from mpl_toolkits.basemap import Basemap


from pnwstore.mseed import WaveformClient
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

from obspy import UTCDateTime

from tqdm import tqdm
from obspy.geodetics import locations2degrees, degrees2kilometers

notebook_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(notebook_dir, '../'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import datetime

# %% [markdown]
# ## Morton Catalog

# %%
# Read Morton's catalog
events_morton = pd.read_csv('../data/ds01.csv')
# Convert the TSTRING to datetime
events_morton['datetime'] = pd.to_datetime(events_morton['TSTRING'], format='%Y%m%d%H%M%S', utc=True)
# Get the events in the Morton catalog 
t1 = pd.Timestamp('2010-1-1 00:00:00.000000+0000', tz='UTC')
t2 = pd.Timestamp('2015-12-31 23:59:59.999999+0000', tz='UTC')

events_morton= events_morton.loc[(events_morton['datetime'] > t1) & (events_morton['datetime'] < t2) ]

events_morton.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Read Morton's catalog
# ----> 2 events_morton = pd.read_csv('../data/ds01.csv')
#       3 # Convert the TSTRING to datetime
#       4 events_morton['datetime'] = pd.to_datetime(events_morton['TSTRING'], format='%Y%m%d%H%M%S', utc=True)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.9/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.9/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.9/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/ds01.csv'

# %%
events_morton
# Out:
#       CI YEAR       TSTRING  YEAR  MONTH  DAY  HOUR  MINUTE  SECOND      LAT  \
# 0           1  2.011073e+13  2011      7   26     1       2    7.37  47.3217
# 1           1  2.011073e+13  2011      7   26     1       2    7.72  44.2888
# 2           1  2.011073e+13  2011      7   26     1       2    8.56  44.3017
# 3           1  2.011073e+13  2011      7   26     7      31    2.17  48.2635
# 4           1  2.011073e+13  2011      7   26     9      50   27.63  48.3032
# ...       ...           ...   ...    ...  ...   ...     ...     ...      ...
# 5277        4  2.015101e+13  2015     10    7     8       1   50.83  40.5895
# 5278        4  2.015101e+13  2015     10    7     8       7    8.40  40.5380
# 5279        4  2.015101e+13  2015     10    7    11      31   26.69  40.5822
# 5280        4  2.015101e+13  2015     10    7    18      11    9.52  40.2710
# 5281        4  2.015101e+13  2015     10    7    21      45   50.37  40.1602
#
#            LON  ...  dist to nearest stn  tt RMS   ERH   ERZ  STRIKE  DIP  \
# 0    -123.2708  ...                 27.4    0.19   0.8   1.2     NaN  NaN
# 1    -124.3340  ...                163.8    0.06  13.1   3.2     NaN  NaN
# 2    -124.3180  ...                131.1    0.50  35.4  22.2     NaN  NaN
# 3    -124.9298  ...                 44.4    0.77   3.5   6.4     NaN  NaN
# 4    -124.9157  ...                 46.1    0.94   4.0   6.9     NaN  NaN
# ...        ...  ...                  ...     ...   ...   ...     ...  ...
# 5277 -124.0455  ...                  5.4    0.14   0.9   0.8     NaN  NaN
# 5278 -123.7217  ...                 14.9    0.09   3.3  13.5     NaN  NaN
# 5279 -124.0432  ...                  5.6    0.05   1.7   0.8     NaN  NaN
# 5280 -124.3777  ...                  7.9    0.19   0.7   0.2     NaN  NaN
# 5281 -123.8320  ...                 29.4    0.22   1.3  18.6     NaN  NaN
#
#       RAKE  PLATE DESIGNATION  TEMPLATE EVENT?                  datetime
# 0      NaN          Interface          Catalog 2011-07-26 01:02:07+00:00
# 1      NaN        Upper Plate              NaN 2011-07-26 01:02:07+00:00
# 2      NaN        Upper Plate              NaN 2011-07-26 01:02:08+00:00
# 3      NaN        Upper Plate              NaN 2011-07-26 07:31:02+00:00
# 4      NaN        Upper Plate                T 2011-07-26 09:50:27+00:00
# ...    ...                ...              ...                       ...
# 5277   NaN               Slab              NaN 2015-10-07 08:01:50+00:00
# 5278   NaN        Upper Plate              NaN 2015-10-07 08:07:08+00:00
# 5279   NaN               Slab              NaN 2015-10-07 11:31:26+00:00
# 5280   NaN        Upper Plate              NaN 2015-10-07 18:11:09+00:00
# 5281   NaN              Undef              NaN 2015-10-07 21:45:50+00:00
#
# [5282 rows x 24 columns]

# %% [markdown]
# ## ANSS Catalog

# %%
events_anss = pd.read_csv('/wd1/hbito_data/data/datasets_anss/anss_2010-15.csv')
events_anss['datetime'] = pd.to_datetime(events_anss['time'], format='%Y-%m-%dT%H:%M:%S.%fZ', utc=True)
events_anss= events_anss.loc[(events_anss['datetime'] > t1) & (events_anss['datetime'] < t2) ]
events_anss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 events_anss = pd.read_csv('/wd1/hbito_data/data/datasets_anss/anss_2010-15.csv')
#       2 events_anss['datetime'] = pd.to_datetime(events_anss['time'], format='%Y-%m-%dT%H:%M:%S.%fZ', utc=True)
# ----> 3 events_anss= events_anss.loc[(events_anss['datetime'] > t1) & (events_anss['datetime'] < t2) ]
#       4 events_anss
#
# NameError: name 't1' is not defined

# %% [markdown]
# ## Our Catalog

# %%
region = 'all_regions'
mycatalog = pd.read_csv(f'/wd1/hbito_data/data/datasets_all_regions/origin_2010_2015_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv',index_col=0)
mycatalog["datetime"] = pd.to_datetime(mycatalog["time"].apply(datetime.datetime.fromtimestamp, tz=datetime.timezone.utc))
mycatalog = mycatalog.rename(columns={"lat": "latitude", "lon": "longitude"})
mycatalog['idx'] = mycatalog['orid']

# %%
mycatalog
# Out:
#        latitude  longitude   depth          time   orid  nass  p_picks  \
# 27593  40.46402 -124.63921  21.674  1.350339e+09  27593    33       14
# 33313  40.46453 -124.64685  19.221  1.363883e+09  33313    23        9
# 44330  49.75784 -123.42677   4.296  1.395439e+09  44330    10        5
# 42581  49.04914 -122.09718  13.249  1.393710e+09  42581    26       16
# 36355  40.39732 -124.58839  16.076  1.371875e+09  36355    22        9
# ...         ...        ...     ...           ...    ...   ...      ...
# 1542   46.14740 -122.14032  44.614  1.266069e+09   1542    10        5
# 8390   48.79538 -123.26321  -0.782  1.293723e+09   8390    10        5
# 8590   48.57995 -123.03222  13.812  1.294554e+09   8590    10        5
# 41383  46.32146 -122.37012  13.638  1.390093e+09  41383    10        5
# 774    48.46791 -123.44927  20.314  1.264059e+09    774    10        5
#
#        s_picks    rms  nsphz         gap algorithm  id_Morton      dist  \
# 27593       19  2.498   19.0   70.689876     genie        676  0.043925
# 33313       14  2.497   14.0  104.305083     genie       1239  0.064674
# 44330        5  2.494    5.0  273.037707     genie       1821  1.710027
# 42581       10  2.491   10.0  254.509741     genie       1805  1.868034
# 36355       13  2.491   13.0  206.224926     genie       1556  0.607235
# ...        ...    ...    ...         ...       ...        ...       ...
# 1542         5  0.044    5.0  123.524895     genie          0  1.406842
# 8390         5  0.043    5.0  159.143198     genie          0  1.473689
# 8590         5  0.042    5.0  230.479217     genie          0  1.268354
# 41383        5  0.036    5.0  260.537377     genie       1768  2.804629
# 774          5  0.032    5.0  185.189076     genie          0  1.152438
#
#                  dt     NonDimDist                         datetime    idx
# 27593  1.489598e+00       0.012537 2012-10-15 22:03:37.489598+00:00  27593
# 33313  1.564381e+03      13.036509 2013-03-21 16:22:28.381014+00:00  33313
# 44330  9.866703e+03      82.222555 2014-03-21 21:53:00.703153+00:00  44330
# 42581  6.251413e+04     520.951049 2014-03-01 21:39:46.874711+00:00  42581
# 36355  5.253552e+04     437.796015 2013-06-22 04:16:06.478228+00:00  36355
# ...             ...            ...                              ...    ...
# 1542   4.557335e+07  379777.923383 2010-02-13 13:46:16.194077+00:00   1542
# 8390   1.791899e+07  149324.956402 2010-12-30 15:32:12.231767+00:00   8390
# 8590   1.708779e+07  142398.279265 2011-01-09 06:25:33.488215+00:00   8590
# 41383  1.094893e+04      91.241118 2014-01-19 00:59:04.074082+00:00  41383
# 774    4.758315e+07  396526.218818 2010-01-21 07:29:40.741805+00:00    774
#
# [31020 rows x 18 columns]

# %% [markdown]
# ## Run this loop

# %%
# Initialize lists to store distances
distances_morton2mycatalog = []
distances_anss2mycatalog = []

# Initialize lists to store matched and unmatched events
matched_events_mycatalog2morton = []
matched_times_morton2mycatalog = []
matched_events_morton2mycatalog = []
unmatched_times_morton2mycatalog = []
unmatched_events_morton2mycatalog = []
unmatched_events_mycatalog2morton_and_anss = []
matched_events_anss2mycatalog = []
matched_events_mycatalog2anss = []
unmatched_times_anss2mycatalog = []
unmatched_events_anss2mycatalog = []
matched_times_anss2mycatalog = []

time_threshold = 120  # in seconds
dist_threshold = 25  # in kilometers

lat_morton2mycatalog = []
lon_morton2mycatalog = []

lat_anss2mycatalog = []
lon_anss2mycatalog = []

# A set to keep track of matched indices in mycatalog
matched_indices_morton = set()
matched_indices_anss = set()
count_c = 0
count_d = 0

# Loop over events in Morton's catalog
for i in range(len(events_morton)):
    t11 = events_morton.iloc[i]['datetime']
    olat = events_morton.iloc[i]['LAT']
    olon = events_morton.iloc[i]['LON']

    condition = (mycatalog['datetime'] >= t11 - pd.Timedelta(seconds=time_threshold)) & \
                (mycatalog['datetime'] <= t11 + pd.Timedelta(seconds=time_threshold)) & \
                (degrees2kilometers(locations2degrees(olat, olon, mycatalog['latitude'], mycatalog['longitude'])) <= dist_threshold)
    matched_df = mycatalog.loc[condition]

    if len(matched_df) == 1:
        print('matched idx of Morton: ', i)
        count_c += 1
        matched_times_morton2mycatalog.append(t11)
        matched_events_morton2mycatalog.append(events_morton.iloc[i])
        lat_morton2mycatalog.append(events_morton.iloc[i]['LAT'])
        lon_morton2mycatalog.append(events_morton.iloc[i]['LON'])
        matched_events_mycatalog2morton.append(matched_df)
        matched_indices_morton.update(matched_df['idx'])
        distance = degrees2kilometers(locations2degrees(olat, olon, matched_df['latitude'].values[0], matched_df['longitude'].values[0]))
        distances_morton2mycatalog.append(distance)
    elif len(matched_df) > 1:
        print('matched idx of Morton: ', i)
        count_d += 1
        diffs = abs(matched_df['datetime'] - t11)
        closest_index = diffs.idxmin()
        closest_event = matched_df.loc[[closest_index]]
        matched_times_morton2mycatalog.append(t11)
        matched_events_morton2mycatalog.append(events_morton.iloc[i])
        lat_morton2mycatalog.append(events_morton.iloc[i]['LAT'])
        lon_morton2mycatalog.append(events_morton.iloc[i]['LON'])
        matched_events_mycatalog2morton.append(closest_event)
        matched_indices_morton.update(closest_event['idx'])
        distance = degrees2kilometers(locations2degrees(olat, olon, closest_event['latitude'].values[0], closest_event['longitude'].values[0]))
        distances_morton2mycatalog.append(distance)
    else:
        unmatched_times_morton2mycatalog.append(t11)
        unmatched_events_morton2mycatalog.append(events_morton.iloc[i])

# All events in mycatalog not matched with Morton's catalog are unmatched
unmatched_indices_morton = set(mycatalog.idx) - matched_indices_morton

count_a = 0
count_b = 0

# Loop over events in ANSS catalog
for i in range(len(events_anss)):
    t11 = events_anss.iloc[i]['datetime']
    olat = events_anss.iloc[i]['latitude']
    olon = events_anss.iloc[i]['longitude']

    condition = (mycatalog['datetime'] >= t11 - pd.Timedelta(seconds=time_threshold)) & \
                (mycatalog['datetime'] <= t11 + pd.Timedelta(seconds=time_threshold)) & \
                (degrees2kilometers(locations2degrees(olat, olon, mycatalog['latitude'], mycatalog['longitude'])) <= dist_threshold)
    matched_df = mycatalog.loc[condition]

    if len(matched_df) == 1:
        print('matched idx of ANSS: ', i)
        count_a += 1
        matched_times_anss2mycatalog.append(t11)
        matched_events_anss2mycatalog.append(events_anss.iloc[i])
        lat_anss2mycatalog.append(events_anss.iloc[i]['latitude'])
        lon_anss2mycatalog.append(events_anss.iloc[i]['longitude'])
        matched_events_mycatalog2anss.append(matched_df)
        matched_indices_anss.update(matched_df['idx'])
        distance = degrees2kilometers(locations2degrees(olat, olon, matched_df['latitude'].values[0], matched_df['longitude'].values[0]))
        distances_anss2mycatalog.append(distance)
    elif len(matched_df) > 1:
        print('matched idx of ANSS: ', i)
        count_b += 1
        diffs = abs(matched_df['datetime'] - t11)
        closest_index = diffs.idxmin()
        closest_event = matched_df.loc[[closest_index]]
        matched_times_anss2mycatalog.append(t11)
        matched_events_anss2mycatalog.append(events_anss.iloc[i])
        lat_anss2mycatalog.append(events_anss.iloc[i]['latitude'])
        lon_anss2mycatalog.append(events_anss.iloc[i]['longitude'])
        matched_events_mycatalog2anss.append(closest_event)
        matched_indices_anss.update(closest_event['idx'])
        distance = degrees2kilometers(locations2degrees(olat, olon, closest_event['latitude'].values[0], closest_event['longitude'].values[0]))
        distances_anss2mycatalog.append(distance)
    else:
        unmatched_times_anss2mycatalog.append(t11)
        unmatched_events_anss2mycatalog.append(events_anss.iloc[i])

# All events in mycatalog not matched with ANSS catalog are unmatched
unmatched_indices_anss = set(mycatalog.idx) - matched_indices_anss

unmatched_indices_morton_and_anss = unmatched_indices_morton.intersection(unmatched_indices_anss)
print(len(mycatalog), len(unmatched_indices_morton_and_anss))

unmatched_events_mycatalog2morton_and_anss = mycatalog.loc[mycatalog['idx'].isin(list(unmatched_indices_morton_and_anss))]

print(f"length of mycatalog: {len(mycatalog)}")
print(f"length of events_morton: {len(events_morton)}")
print(f"length of events_anss: {len(events_anss)}")
print(f"matched_indices_morton: {len(matched_indices_morton)}")
print(f"matched_indices_anss: {len(matched_indices_anss)}")
print(f"unmatched_indices_morton: {len(unmatched_indices_morton)}")
print(f"unmatched_indices_anss: {len(unmatched_indices_anss)}")
print(f"unmatched_indices_morton_and_anss (new events): {len(unmatched_indices_morton_and_anss)}")
# Out:
# matched idx of Morton:  0
# matched idx of Morton:  4
# matched idx of Morton:  5
# matched idx of Morton:  13
# matched idx of Morton:  14
# matched idx of Morton:  15
# matched idx of Morton:  16
# matched idx of Morton:  17
# matched idx of Morton:  18
# matched idx of Morton:  19
# matched idx of Morton:  20
# matched idx of Morton:  21
# matched idx of Morton:  22
# matched idx of Morton:  23
# matched idx of Morton:  24
# matched idx of Morton:  26
# matched idx of Morton:  28
# matched idx of Morton:  31
# matched idx of Morton:  32
# matched idx of Morton:  33
# matched idx of Morton:  35
# matched idx of Morton:  37
# matched idx of Morton:  38
# matched idx of Morton:  39
# matched idx of Morton:  41
# matched idx of Morton:  43
# matched idx of Morton:  44
# matched idx of Morton:  45
# matched idx of Morton:  48
# matched idx of Morton:  50
# matched idx of Morton:  54
# matched idx of Morton:  55
# matched idx of Morton:  56
# matched idx of Morton:  57
# matched idx of Morton:  59
# matched idx of Morton:  61
# matched idx of Morton:  62
# matched idx of Morton:  65
# matched idx of Morton:  66
# matched idx of Morton:  68
# matched idx of Morton:  69
# matched idx of Morton:  74
# matched idx of Morton:  77
# matched idx of Morton:  78
# matched idx of Morton:  79
# matched idx of Morton:  80
# matched idx of Morton:  81
# matched idx of Morton:  82
# matched idx of Morton:  87
# matched idx of Morton:  88
# matched idx of Morton:  93
# matched idx of Morton:  97
# matched idx of Morton:  98
# matched idx of Morton:  103
# matched idx of Morton:  105
# matched idx of Morton:  106
# matched idx of Morton:  107
# matched idx of Morton:  109
# matched idx of Morton:  111
# matched idx of Morton:  113
# matched idx of Morton:  114
# matched idx of Morton:  115
# matched idx of Morton:  116
# matched idx of Morton:  117
# matched idx of Morton:  118
# matched idx of Morton:  119
# matched idx of Morton:  123
# matched idx of Morton:  125
# matched idx of Morton:  129
# matched idx of Morton:  131
# matched idx of Morton:  134
# matched idx of Morton:  135
# matched idx of Morton:  136
# matched idx of Morton:  138
# matched idx of Morton:  139
# matched idx of Morton:  141
# matched idx of Morton:  146
# matched idx of Morton:  147
# matched idx of Morton:  149
# matched idx of Morton:  151
# matched idx of Morton:  152
# matched idx of Morton:  153
# matched idx of Morton:  155
# matched idx of Morton:  159
# matched idx of Morton:  160
# matched idx of Morton:  161
# matched idx of Morton:  162
# matched idx of Morton:  165
# matched idx of Morton:  167
# matched idx of Morton:  168
# matched idx of Morton:  171
# matched idx of Morton:  172
# matched idx of Morton:  173
# matched idx of Morton:  174
# matched idx of Morton:  177
# matched idx of Morton:  178
# matched idx of Morton:  179
# matched idx of Morton:  180
# matched idx of Morton:  183
# matched idx of Morton:  184
# matched idx of Morton:  185
# matched idx of Morton:  189
# matched idx of Morton:  193
# matched idx of Morton:  194
# matched idx of Morton:  195
# matched idx of Morton:  197
# matched idx of Morton:  200
# matched idx of Morton:  206
# matched idx of Morton:  208
# matched idx of Morton:  209
# matched idx of Morton:  210
# matched idx of Morton:  211
# matched idx of Morton:  212
# matched idx of Morton:  215
# matched idx of Morton:  218
# matched idx of Morton:  220
# matched idx of Morton:  221
# matched idx of Morton:  223
# matched idx of Morton:  224
# matched idx of Morton:  225
# matched idx of Morton:  226
# matched idx of Morton:  229
# matched idx of Morton:  230
# matched idx of Morton:  233
# matched idx of Morton:  236
# matched idx of Morton:  239
# matched idx of Morton:  240
# matched idx of Morton:  248
# matched idx of Morton:  249
# matched idx of Morton:  253
# matched idx of Morton:  254
# matched idx of Morton:  255
# matched idx of Morton:  257
# matched idx of Morton:  258
# matched idx of Morton:  260
# matched idx of Morton:  262
# matched idx of Morton:  271
# matched idx of Morton:  272
# matched idx of Morton:  273
# matched idx of Morton:  274
# matched idx of Morton:  275
# matched idx of Morton:  277
# matched idx of Morton:  278
# matched idx of Morton:  282
# matched idx of Morton:  283
# matched idx of Morton:  285
# matched idx of Morton:  286
# matched idx of Morton:  287
# matched idx of Morton:  288
# matched idx of Morton:  290
# matched idx of Morton:  291
# matched idx of Morton:  293
# matched idx of Morton:  294
# matched idx of Morton:  295
# matched idx of Morton:  296
# matched idx of Morton:  298
# matched idx of Morton:  300
# matched idx of Morton:  301
# matched idx of Morton:  302
# matched idx of Morton:  303
# matched idx of Morton:  304
# matched idx of Morton:  308
# matched idx of Morton:  309
# matched idx of Morton:  312
# matched idx of Morton:  313
# matched idx of Morton:  314
# matched idx of Morton:  316
# matched idx of Morton:  317
# matched idx of Morton:  318
# matched idx of Morton:  322
# matched idx of Morton:  324
# matched idx of Morton:  325
# matched idx of Morton:  326
# matched idx of Morton:  327
# matched idx of Morton:  328
# matched idx of Morton:  329
# matched idx of Morton:  331
# matched idx of Morton:  332
# matched idx of Morton:  335
# matched idx of Morton:  337
# matched idx of Morton:  341
# matched idx of Morton:  345
# matched idx of Morton:  346
# matched idx of Morton:  347
# matched idx of Morton:  349
# matched idx of Morton:  350
# matched idx of Morton:  351
# matched idx of Morton:  353
# matched idx of Morton:  356
# matched idx of Morton:  359
# matched idx of Morton:  362
# matched idx of Morton:  364
# matched idx of Morton:  365
# matched idx of Morton:  366
# matched idx of Morton:  368
# matched idx of Morton:  371
# matched idx of Morton:  372
# matched idx of Morton:  374
# matched idx of Morton:  375
# matched idx of Morton:  376
# matched idx of Morton:  379
# matched idx of Morton:  380
# matched idx of Morton:  381
# matched idx of Morton:  384
# matched idx of Morton:  385
# matched idx of Morton:  386
# matched idx of Morton:  387
# matched idx of Morton:  388
# matched idx of Morton:  390
# matched idx of Morton:  391
# matched idx of Morton:  392
# matched idx of Morton:  395
# matched idx of Morton:  402
# matched idx of Morton:  404
# matched idx of Morton:  405
# matched idx of Morton:  408
# matched idx of Morton:  412
# matched idx of Morton:  413
# matched idx of Morton:  414
# matched idx of Morton:  415
# matched idx of Morton:  416
# matched idx of Morton:  417
# matched idx of Morton:  418
# matched idx of Morton:  420
# matched idx of Morton:  421
# matched idx of Morton:  423
# matched idx of Morton:  424
# matched idx of Morton:  425
# matched idx of Morton:  426
# matched idx of Morton:  427
# matched idx of Morton:  428
# matched idx of Morton:  429
# matched idx of Morton:  431
# matched idx of Morton:  436
# matched idx of Morton:  437
# matched idx of Morton:  438
# matched idx of Morton:  439
# matched idx of Morton:  440
# matched idx of Morton:  444
# matched idx of Morton:  445
# matched idx of Morton:  447
# matched idx of Morton:  448
# matched idx of Morton:  450
# matched idx of Morton:  455
# matched idx of Morton:  457
# matched idx of Morton:  461
# matched idx of Morton:  462
# matched idx of Morton:  463
# matched idx of Morton:  464
# matched idx of Morton:  465
# matched idx of Morton:  467
# matched idx of Morton:  469
# matched idx of Morton:  470
# matched idx of Morton:  474
# matched idx of Morton:  475
# matched idx of Morton:  476
# matched idx of Morton:  479
# matched idx of Morton:  480
# matched idx of Morton:  482
# matched idx of Morton:  483
# matched idx of Morton:  484
# matched idx of Morton:  485
# matched idx of Morton:  486
# matched idx of Morton:  488
# matched idx of Morton:  490
# matched idx of Morton:  493
# matched idx of Morton:  495
# matched idx of Morton:  496
# matched idx of Morton:  499
# matched idx of Morton:  501
# matched idx of Morton:  502
# matched idx of Morton:  503
# matched idx of Morton:  504
# matched idx of Morton:  505
# matched idx of Morton:  506
# matched idx of Morton:  509
# matched idx of Morton:  510
# matched idx of Morton:  511
# matched idx of Morton:  512
# matched idx of Morton:  513
# matched idx of Morton:  521
# matched idx of Morton:  522
# matched idx of Morton:  523
# matched idx of Morton:  524
# matched idx of Morton:  525
# matched idx of Morton:  526
# matched idx of Morton:  529
# matched idx of Morton:  530
# matched idx of Morton:  531
# matched idx of Morton:  532
# matched idx of Morton:  533
# matched idx of Morton:  535
# matched idx of Morton:  537
# matched idx of Morton:  539
# matched idx of Morton:  540
# matched idx of Morton:  542
# matched idx of Morton:  543
# matched idx of Morton:  546
# matched idx of Morton:  547
# matched idx of Morton:  548
# matched idx of Morton:  549
# matched idx of Morton:  550
# matched idx of Morton:  551
# matched idx of Morton:  552
# matched idx of Morton:  553
# matched idx of Morton:  554
# matched idx of Morton:  555
# matched idx of Morton:  556
# matched idx of Morton:  557
# matched idx of Morton:  558
# matched idx of Morton:  559
# matched idx of Morton:  560
# matched idx of Morton:  561
# matched idx of Morton:  562
# matched idx of Morton:  563
# matched idx of Morton:  565
# matched idx of Morton:  566
# matched idx of Morton:  567
# matched idx of Morton:  569
# matched idx of Morton:  570
# matched idx of Morton:  572
# matched idx of Morton:  573
# matched idx of Morton:  574
# matched idx of Morton:  575
# matched idx of Morton:  576
# matched idx of Morton:  577
# matched idx of Morton:  578
# matched idx of Morton:  579
# matched idx of Morton:  580
# matched idx of Morton:  581
# matched idx of Morton:  582
# matched idx of Morton:  583
# matched idx of Morton:  584
# matched idx of Morton:  585
# matched idx of Morton:  586
# matched idx of Morton:  587
# matched idx of Morton:  588
# matched idx of Morton:  589
# matched idx of Morton:  590
# matched idx of Morton:  591
# matched idx of Morton:  592
# matched idx of Morton:  593
# matched idx of Morton:  595
# matched idx of Morton:  596
# matched idx of Morton:  598
# matched idx of Morton:  599
# matched idx of Morton:  600
# matched idx of Morton:  601
# matched idx of Morton:  603
# matched idx of Morton:  604
# matched idx of Morton:  605
# matched idx of Morton:  606
# matched idx of Morton:  608
# matched idx of Morton:  609
# matched idx of Morton:  610
# matched idx of Morton:  612
# matched idx of Morton:  613
# matched idx of Morton:  614
# matched idx of Morton:  615
# matched idx of Morton:  616
# matched idx of Morton:  617
# matched idx of Morton:  618
# matched idx of Morton:  619
# matched idx of Morton:  620
# matched idx of Morton:  621
# matched idx of Morton:  622
# matched idx of Morton:  623
# matched idx of Morton:  624
# matched idx of Morton:  625
# matched idx of Morton:  626
# matched idx of Morton:  627
# matched idx of Morton:  628
# matched idx of Morton:  629
# matched idx of Morton:  630
# matched idx of Morton:  631
# matched idx of Morton:  632
# matched idx of Morton:  633
# matched idx of Morton:  634
# matched idx of Morton:  635
# matched idx of Morton:  636
# matched idx of Morton:  637
# matched idx of Morton:  639
# matched idx of Morton:  640
# matched idx of Morton:  643
# matched idx of Morton:  645
# matched idx of Morton:  646
# matched idx of Morton:  647
# matched idx of Morton:  648
# matched idx of Morton:  649
# matched idx of Morton:  650
# matched idx of Morton:  651
# matched idx of Morton:  652
# matched idx of Morton:  653
# matched idx of Morton:  654
# matched idx of Morton:  655
# matched idx of Morton:  656
# matched idx of Morton:  657
# matched idx of Morton:  658
# matched idx of Morton:  659
# matched idx of Morton:  660
# matched idx of Morton:  663
# matched idx of Morton:  664
# matched idx of Morton:  665
# matched idx of Morton:  666
# matched idx of Morton:  667
# matched idx of Morton:  668
# matched idx of Morton:  669
# matched idx of Morton:  670
# matched idx of Morton:  671
# matched idx of Morton:  672
# matched idx of Morton:  673
# matched idx of Morton:  674
# matched idx of Morton:  675
# matched idx of Morton:  676
# matched idx of Morton:  678
# matched idx of Morton:  679
# matched idx of Morton:  681
# matched idx of Morton:  683
# matched idx of Morton:  684
# matched idx of Morton:  685
# matched idx of Morton:  686
# matched idx of Morton:  687
# matched idx of Morton:  688
# matched idx of Morton:  689
# matched idx of Morton:  690
# matched idx of Morton:  691
# matched idx of Morton:  692
# matched idx of Morton:  693
# matched idx of Morton:  694
# matched idx of Morton:  695
# matched idx of Morton:  696
# matched idx of Morton:  697
# matched idx of Morton:  698
# matched idx of Morton:  700
# matched idx of Morton:  701
# matched idx of Morton:  702
# matched idx of Morton:  703
# matched idx of Morton:  704
# matched idx of Morton:  705
# matched idx of Morton:  706
# matched idx of Morton:  707
# matched idx of Morton:  708
# matched idx of Morton:  709
# matched idx of Morton:  710
# matched idx of Morton:  711
# matched idx of Morton:  712
# matched idx of Morton:  713
# matched idx of Morton:  714
# matched idx of Morton:  715
# matched idx of Morton:  716
# matched idx of Morton:  717
# matched idx of Morton:  719
# matched idx of Morton:  720
# matched idx of Morton:  723
# matched idx of Morton:  724
# matched idx of Morton:  725
# matched idx of Morton:  726
# matched idx of Morton:  727
# matched idx of Morton:  728
# matched idx of Morton:  729
# matched idx of Morton:  730
# matched idx of Morton:  731
# matched idx of Morton:  732
# matched idx of Morton:  733
# matched idx of Morton:  734
# matched idx of Morton:  735
# matched idx of Morton:  736
# matched idx of Morton:  737
# matched idx of Morton:  738
# matched idx of Morton:  739
# matched idx of Morton:  740
# matched idx of Morton:  741
# matched idx of Morton:  742
# matched idx of Morton:  743
# matched idx of Morton:  744
# matched idx of Morton:  746
# matched idx of Morton:  747
# matched idx of Morton:  748
# matched idx of Morton:  750
# matched idx of Morton:  751
# matched idx of Morton:  754
# matched idx of Morton:  755
# matched idx of Morton:  757
# matched idx of Morton:  758
# matched idx of Morton:  759
# matched idx of Morton:  761
# matched idx of Morton:  762
# matched idx of Morton:  763
# matched idx of Morton:  764
# matched idx of Morton:  765
# matched idx of Morton:  766
# matched idx of Morton:  767
# matched idx of Morton:  768
# matched idx of Morton:  770
# matched idx of Morton:  771
# matched idx of Morton:  772
# matched idx of Morton:  773
# matched idx of Morton:  774
# matched idx of Morton:  775
# matched idx of Morton:  777
# matched idx of Morton:  778
# matched idx of Morton:  779
# matched idx of Morton:  780
# matched idx of Morton:  781
# matched idx of Morton:  782
# matched idx of Morton:  783
# matched idx of Morton:  784
# matched idx of Morton:  785
# matched idx of Morton:  786
# matched idx of Morton:  787
# matched idx of Morton:  788
# matched idx of Morton:  789
# matched idx of Morton:  790
# matched idx of Morton:  791
# matched idx of Morton:  792
# matched idx of Morton:  794
# matched idx of Morton:  795
# matched idx of Morton:  796
# matched idx of Morton:  798
# matched idx of Morton:  799
# matched idx of Morton:  800
# matched idx of Morton:  801
# matched idx of Morton:  802
# matched idx of Morton:  803
# matched idx of Morton:  804
# matched idx of Morton:  805
# matched idx of Morton:  806
# matched idx of Morton:  807
# matched idx of Morton:  809
# matched idx of Morton:  810
# matched idx of Morton:  811
# matched idx of Morton:  812
# matched idx of Morton:  813
# matched idx of Morton:  814
# matched idx of Morton:  815
# matched idx of Morton:  816
# matched idx of Morton:  817
# matched idx of Morton:  819
# matched idx of Morton:  820
# matched idx of Morton:  823
# matched idx of Morton:  825
# matched idx of Morton:  826
# matched idx of Morton:  827
# matched idx of Morton:  828
# matched idx of Morton:  829
# matched idx of Morton:  830
# matched idx of Morton:  831
# matched idx of Morton:  833
# matched idx of Morton:  836
# matched idx of Morton:  837
# matched idx of Morton:  838
# matched idx of Morton:  839
# matched idx of Morton:  840
# matched idx of Morton:  843
# matched idx of Morton:  844
# matched idx of Morton:  845
# matched idx of Morton:  846
# matched idx of Morton:  847
# matched idx of Morton:  848
# matched idx of Morton:  849
# matched idx of Morton:  852
# matched idx of Morton:  853
# matched idx of Morton:  855
# matched idx of Morton:  856
# matched idx of Morton:  857
# matched idx of Morton:  858
# matched idx of Morton:  859
# matched idx of Morton:  860
# matched idx of Morton:  861
# matched idx of Morton:  862
# matched idx of Morton:  864
# matched idx of Morton:  865
# matched idx of Morton:  866
# matched idx of Morton:  868
# matched idx of Morton:  869
# matched idx of Morton:  870
# matched idx of Morton:  871
# matched idx of Morton:  873
# matched idx of Morton:  874
# matched idx of Morton:  875
# matched idx of Morton:  876
# matched idx of Morton:  877
# matched idx of Morton:  878
# matched idx of Morton:  879
# matched idx of Morton:  880
# matched idx of Morton:  881
# matched idx of Morton:  884
# matched idx of Morton:  885
# matched idx of Morton:  886
# matched idx of Morton:  887
# matched idx of Morton:  888
# matched idx of Morton:  890
# matched idx of Morton:  891
# matched idx of Morton:  892
# matched idx of Morton:  893
# matched idx of Morton:  894
# matched idx of Morton:  895
# matched idx of Morton:  896
# matched idx of Morton:  897
# matched idx of Morton:  898
# matched idx of Morton:  899
# matched idx of Morton:  900
# matched idx of Morton:  901
# matched idx of Morton:  902
# matched idx of Morton:  904
# matched idx of Morton:  905
# matched idx of Morton:  906
# matched idx of Morton:  907
# matched idx of Morton:  908
# matched idx of Morton:  909
# matched idx of Morton:  910
# matched idx of Morton:  911
# matched idx of Morton:  912
# matched idx of Morton:  913
# matched idx of Morton:  915
# matched idx of Morton:  916
# matched idx of Morton:  917
# matched idx of Morton:  918
# matched idx of Morton:  919
# matched idx of Morton:  920
# matched idx of Morton:  921
# matched idx of Morton:  922
# matched idx of Morton:  923
# matched idx of Morton:  924
# matched idx of Morton:  925
# matched idx of Morton:  926
# matched idx of Morton:  927
# matched idx of Morton:  928
# matched idx of Morton:  929
# matched idx of Morton:  930
# matched idx of Morton:  931
# matched idx of Morton:  932
# matched idx of Morton:  933
# matched idx of Morton:  934
# matched idx of Morton:  935
# matched idx of Morton:  936
# matched idx of Morton:  937
# matched idx of Morton:  938
# matched idx of Morton:  939
# matched idx of Morton:  941
# matched idx of Morton:  942
# matched idx of Morton:  943
# matched idx of Morton:  944
# matched idx of Morton:  945
# matched idx of Morton:  947
# matched idx of Morton:  948
# matched idx of Morton:  949
# matched idx of Morton:  950
# matched idx of Morton:  951
# matched idx of Morton:  953
# matched idx of Morton:  954
# matched idx of Morton:  955
# matched idx of Morton:  956
# matched idx of Morton:  957
# matched idx of Morton:  958
# matched idx of Morton:  959
# matched idx of Morton:  961
# matched idx of Morton:  962
# matched idx of Morton:  963
# matched idx of Morton:  964
# matched idx of Morton:  965
# matched idx of Morton:  968
# matched idx of Morton:  969
# matched idx of Morton:  970
# matched idx of Morton:  972
# matched idx of Morton:  973
# matched idx of Morton:  974
# matched idx of Morton:  975
# matched idx of Morton:  976
# matched idx of Morton:  977
# matched idx of Morton:  978
# matched idx of Morton:  980
# matched idx of Morton:  982
# matched idx of Morton:  983
# matched idx of Morton:  984
# matched idx of Morton:  985
# matched idx of Morton:  986
# matched idx of Morton:  988
# matched idx of Morton:  992
# matched idx of Morton:  993
# matched idx of Morton:  994
# matched idx of Morton:  995
# matched idx of Morton:  996
# matched idx of Morton:  997
# matched idx of Morton:  998
# matched idx of Morton:  999
# matched idx of Morton:  1000
# matched idx of Morton:  1001
# matched idx of Morton:  1002
# matched idx of Morton:  1003
# matched idx of Morton:  1005
# matched idx of Morton:  1006
# matched idx of Morton:  1008
# matched idx of Morton:  1010
# matched idx of Morton:  1011
# matched idx of Morton:  1012
# matched idx of Morton:  1014
# matched idx of Morton:  1015
# matched idx of Morton:  1017
# matched idx of Morton:  1018
# matched idx of Morton:  1019
# matched idx of Morton:  1020
# matched idx of Morton:  1021
# matched idx of Morton:  1022
# matched idx of Morton:  1023
# matched idx of Morton:  1025
# matched idx of Morton:  1026
# matched idx of Morton:  1027
# matched idx of Morton:  1029
# matched idx of Morton:  1031
# matched idx of Morton:  1032
# matched idx of Morton:  1033
# matched idx of Morton:  1034
# matched idx of Morton:  1035
# matched idx of Morton:  1036
# matched idx of Morton:  1037
# matched idx of Morton:  1038
# matched idx of Morton:  1039
# matched idx of Morton:  1041
# matched idx of Morton:  1042
# matched idx of Morton:  1044
# matched idx of Morton:  1046
# matched idx of Morton:  1047
# matched idx of Morton:  1048
# matched idx of Morton:  1049
# matched idx of Morton:  1051
# matched idx of Morton:  1052
# matched idx of Morton:  1053
# matched idx of Morton:  1054
# matched idx of Morton:  1055
# matched idx of Morton:  1056
# matched idx of Morton:  1057
# matched idx of Morton:  1058
# matched idx of Morton:  1059
# matched idx of Morton:  1060
# matched idx of Morton:  1061
# matched idx of Morton:  1062
# matched idx of Morton:  1063
# matched idx of Morton:  1064
# matched idx of Morton:  1065
# matched idx of Morton:  1067
# matched idx of Morton:  1068
# matched idx of Morton:  1070
# matched idx of Morton:  1071
# matched idx of Morton:  1072
# matched idx of Morton:  1073
# matched idx of Morton:  1074
# matched idx of Morton:  1075
# matched idx of Morton:  1076
# matched idx of Morton:  1077
# matched idx of Morton:  1078
# matched idx of Morton:  1083
# matched idx of Morton:  1084
# matched idx of Morton:  1085
# matched idx of Morton:  1086
# matched idx of Morton:  1087
# matched idx of Morton:  1089
# matched idx of Morton:  1090
# matched idx of Morton:  1092
# matched idx of Morton:  1093
# matched idx of Morton:  1094
# matched idx of Morton:  1096
# matched idx of Morton:  1098
# matched idx of Morton:  1099
# matched idx of Morton:  1100
# matched idx of Morton:  1101
# matched idx of Morton:  1103
# matched idx of Morton:  1104
# matched idx of Morton:  1105
# matched idx of Morton:  1106
# matched idx of Morton:  1107
# matched idx of Morton:  1108
# matched idx of Morton:  1109
# matched idx of Morton:  1110
# matched idx of Morton:  1111
# matched idx of Morton:  1112
# matched idx of Morton:  1113
# matched idx of Morton:  1114
# matched idx of Morton:  1115
# matched idx of Morton:  1116
# matched idx of Morton:  1117
# matched idx of Morton:  1118
# matched idx of Morton:  1119
# matched idx of Morton:  1120
# matched idx of Morton:  1121
# matched idx of Morton:  1122
# matched idx of Morton:  1123
# matched idx of Morton:  1124
# matched idx of Morton:  1125
# matched idx of Morton:  1127
# matched idx of Morton:  1128
# matched idx of Morton:  1129
# matched idx of Morton:  1130
# matched idx of Morton:  1132
# matched idx of Morton:  1133
# matched idx of Morton:  1134
# matched idx of Morton:  1135
# matched idx of Morton:  1136
# matched idx of Morton:  1137
# matched idx of Morton:  1138
# matched idx of Morton:  1139
# matched idx of Morton:  1140
# matched idx of Morton:  1142
# matched idx of Morton:  1143
# matched idx of Morton:  1144
# matched idx of Morton:  1145
# matched idx of Morton:  1146
# matched idx of Morton:  1147
# matched idx of Morton:  1148
# matched idx of Morton:  1149
# matched idx of Morton:  1151
# matched idx of Morton:  1152
# matched idx of Morton:  1154
# matched idx of Morton:  1155
# matched idx of Morton:  1156
# matched idx of Morton:  1157
# matched idx of Morton:  1158
# matched idx of Morton:  1159
# matched idx of Morton:  1160
# matched idx of Morton:  1161
# matched idx of Morton:  1162
# matched idx of Morton:  1163
# matched idx of Morton:  1164
# matched idx of Morton:  1166
# matched idx of Morton:  1167
# matched idx of Morton:  1168
# matched idx of Morton:  1169
# matched idx of Morton:  1170
# matched idx of Morton:  1171
# matched idx of Morton:  1172
# matched idx of Morton:  1173
# matched idx of Morton:  1174
# matched idx of Morton:  1175
# matched idx of Morton:  1176
# matched idx of Morton:  1177
# matched idx of Morton:  1179
# matched idx of Morton:  1180
# matched idx of Morton:  1181
# matched idx of Morton:  1182
# matched idx of Morton:  1183
# matched idx of Morton:  1184
# matched idx of Morton:  1185
# matched idx of Morton:  1186
# matched idx of Morton:  1187
# matched idx of Morton:  1189
# matched idx of Morton:  1191
# matched idx of Morton:  1193
# matched idx of Morton:  1194
# matched idx of Morton:  1195
# matched idx of Morton:  1196
# matched idx of Morton:  1197
# matched idx of Morton:  1198
# matched idx of Morton:  1199
# matched idx of Morton:  1200
# matched idx of Morton:  1201
# matched idx of Morton:  1202
# matched idx of Morton:  1203
# matched idx of Morton:  1204
# matched idx of Morton:  1205
# matched idx of Morton:  1206
# matched idx of Morton:  1207
# matched idx of Morton:  1208
# matched idx of Morton:  1209
# matched idx of Morton:  1210
# matched idx of Morton:  1211
# matched idx of Morton:  1212
# matched idx of Morton:  1213
# matched idx of Morton:  1215
# matched idx of Morton:  1216
# matched idx of Morton:  1218
# matched idx of Morton:  1219
# matched idx of Morton:  1222
# matched idx of Morton:  1224
# matched idx of Morton:  1225
# matched idx of Morton:  1226
# matched idx of Morton:  1227
# matched idx of Morton:  1229
# matched idx of Morton:  1230
# matched idx of Morton:  1231
# matched idx of Morton:  1232
# matched idx of Morton:  1233
# matched idx of Morton:  1236
# matched idx of Morton:  1238
# matched idx of Morton:  1239
# matched idx of Morton:  1240
# matched idx of Morton:  1241
# matched idx of Morton:  1242
# matched idx of Morton:  1243
# matched idx of Morton:  1244
# matched idx of Morton:  1245
# matched idx of Morton:  1246
# matched idx of Morton:  1247
# matched idx of Morton:  1248
# matched idx of Morton:  1249
# matched idx of Morton:  1250
# matched idx of Morton:  1251
# matched idx of Morton:  1252
# matched idx of Morton:  1253
# matched idx of Morton:  1254
# matched idx of Morton:  1256
# matched idx of Morton:  1257
# matched idx of Morton:  1258
# matched idx of Morton:  1259
# matched idx of Morton:  1260
# matched idx of Morton:  1261
# matched idx of Morton:  1262
# matched idx of Morton:  1263
# matched idx of Morton:  1265
# matched idx of Morton:  1266
# matched idx of Morton:  1267
# matched idx of Morton:  1268
# matched idx of Morton:  1269
# matched idx of Morton:  1270
# matched idx of Morton:  1271
# matched idx of Morton:  1272
# matched idx of Morton:  1273
# matched idx of Morton:  1274
# matched idx of Morton:  1275
# matched idx of Morton:  1276
# matched idx of Morton:  1277
# matched idx of Morton:  1278
# matched idx of Morton:  1279
# matched idx of Morton:  1281
# matched idx of Morton:  1282
# matched idx of Morton:  1283
# matched idx of Morton:  1284
# matched idx of Morton:  1285
# matched idx of Morton:  1286
# matched idx of Morton:  1287
# matched idx of Morton:  1288
# matched idx of Morton:  1289
# matched idx of Morton:  1290
# matched idx of Morton:  1291
# matched idx of Morton:  1293
# matched idx of Morton:  1294
# matched idx of Morton:  1295
# matched idx of Morton:  1296
# matched idx of Morton:  1297
# matched idx of Morton:  1298
# matched idx of Morton:  1299
# matched idx of Morton:  1300
# matched idx of Morton:  1301
# matched idx of Morton:  1302
# matched idx of Morton:  1303
# matched idx of Morton:  1305
# matched idx of Morton:  1306
# matched idx of Morton:  1307
# matched idx of Morton:  1308
# matched idx of Morton:  1309
# matched idx of Morton:  1311
# matched idx of Morton:  1313
# matched idx of Morton:  1314
# matched idx of Morton:  1315
# matched idx of Morton:  1316
# matched idx of Morton:  1317
# matched idx of Morton:  1319
# matched idx of Morton:  1320
# matched idx of Morton:  1321
# matched idx of Morton:  1322
# matched idx of Morton:  1323
# matched idx of Morton:  1324
# matched idx of Morton:  1326
# matched idx of Morton:  1328
# matched idx of Morton:  1329
# matched idx of Morton:  1331
# matched idx of Morton:  1332
# matched idx of Morton:  1334
# matched idx of Morton:  1335
# matched idx of Morton:  1336
# matched idx of Morton:  1337
# matched idx of Morton:  1339
# matched idx of Morton:  1340
# matched idx of Morton:  1341
# matched idx of Morton:  1342
# matched idx of Morton:  1343
# matched idx of Morton:  1345
# matched idx of Morton:  1346
# matched idx of Morton:  1347
# matched idx of Morton:  1348
# matched idx of Morton:  1349
# matched idx of Morton:  1351
# matched idx of Morton:  1352
# matched idx of Morton:  1353
# matched idx of Morton:  1354
# matched idx of Morton:  1355
# matched idx of Morton:  1356
# matched idx of Morton:  1357
# matched idx of Morton:  1358
# matched idx of Morton:  1359
# matched idx of Morton:  1487
# matched idx of Morton:  1488
# matched idx of Morton:  1489
# matched idx of Morton:  1490
# matched idx of Morton:  1492
# matched idx of Morton:  1493
# matched idx of Morton:  1494
# matched idx of Morton:  1495
# matched idx of Morton:  1496
# matched idx of Morton:  1498
# matched idx of Morton:  1499
# matched idx of Morton:  1502
# matched idx of Morton:  1503
# matched idx of Morton:  1504
# matched idx of Morton:  1505
# matched idx of Morton:  1506
# matched idx of Morton:  1507
# matched idx of Morton:  1508
# matched idx of Morton:  1510
# matched idx of Morton:  1512
# matched idx of Morton:  1514
# matched idx of Morton:  1515
# matched idx of Morton:  1516
# matched idx of Morton:  1517
# matched idx of Morton:  1518
# matched idx of Morton:  1519
# matched idx of Morton:  1520
# matched idx of Morton:  1521
# matched idx of Morton:  1522
# matched idx of Morton:  1524
# matched idx of Morton:  1528
# matched idx of Morton:  1530
# matched idx of Morton:  1531
# matched idx of Morton:  1532
# matched idx of Morton:  1533
# matched idx of Morton:  1534
# matched idx of Morton:  1535
# matched idx of Morton:  1537
# matched idx of Morton:  1539
# matched idx of Morton:  1540
# matched idx of Morton:  1544
# matched idx of Morton:  1545
# matched idx of Morton:  1547
# matched idx of Morton:  1549
# matched idx of Morton:  1550
# matched idx of Morton:  1551
# matched idx of Morton:  1552
# matched idx of Morton:  1554
# matched idx of Morton:  1555
# matched idx of Morton:  1556
# matched idx of Morton:  1557
# matched idx of Morton:  1558
# matched idx of Morton:  1560
# matched idx of Morton:  1562
# matched idx of Morton:  1563
# matched idx of Morton:  1564
# matched idx of Morton:  1565
# matched idx of Morton:  1566
# matched idx of Morton:  1567
# matched idx of Morton:  1570
# matched idx of Morton:  1571
# matched idx of Morton:  1572
# matched idx of Morton:  1576
# matched idx of Morton:  1577
# matched idx of Morton:  1578
# matched idx of Morton:  1580
# matched idx of Morton:  1581
# matched idx of Morton:  1582
# matched idx of Morton:  1584
# matched idx of Morton:  1585
# matched idx of Morton:  1586
# matched idx of Morton:  1588
# matched idx of Morton:  1589
# matched idx of Morton:  1590
# matched idx of Morton:  1592
# matched idx of Morton:  1593
# matched idx of Morton:  1594
# matched idx of Morton:  1595
# matched idx of Morton:  1596
# matched idx of Morton:  1597
# matched idx of Morton:  1599
# matched idx of Morton:  1600
# matched idx of Morton:  1601
# matched idx of Morton:  1602
# matched idx of Morton:  1604
# matched idx of Morton:  1606
# matched idx of Morton:  1607
# matched idx of Morton:  1608
# matched idx of Morton:  1612
# matched idx of Morton:  1614
# matched idx of Morton:  1616
# matched idx of Morton:  1619
# matched idx of Morton:  1621
# matched idx of Morton:  1623
# matched idx of Morton:  1625
# matched idx of Morton:  1629
# matched idx of Morton:  1631
# matched idx of Morton:  1633
# matched idx of Morton:  1634
# matched idx of Morton:  1637
# matched idx of Morton:  1639
# matched idx of Morton:  1640
# matched idx of Morton:  1641
# matched idx of Morton:  1642
# matched idx of Morton:  1644
# matched idx of Morton:  1645
# matched idx of Morton:  1647
# matched idx of Morton:  1648
# matched idx of Morton:  1651
# matched idx of Morton:  1879
# matched idx of Morton:  1884
# matched idx of Morton:  1885
# matched idx of Morton:  1887
# matched idx of Morton:  1894
# matched idx of Morton:  1895
# matched idx of Morton:  1898
# matched idx of Morton:  1899
# matched idx of Morton:  1900
# matched idx of Morton:  1902
# matched idx of Morton:  1903
# matched idx of Morton:  1905
# matched idx of Morton:  1907
# matched idx of Morton:  1910
# matched idx of Morton:  1911
# matched idx of Morton:  1912
# matched idx of Morton:  1913
# matched idx of Morton:  1914
# matched idx of Morton:  1915
# matched idx of Morton:  1916
# matched idx of Morton:  1918
# matched idx of Morton:  1919
# matched idx of Morton:  1920
# matched idx of Morton:  1921
# matched idx of Morton:  1922
# matched idx of Morton:  1923
# matched idx of Morton:  1924
# matched idx of Morton:  1925
# matched idx of Morton:  1926
# matched idx of Morton:  1927
# matched idx of Morton:  1928
# matched idx of Morton:  1931
# matched idx of Morton:  1932
# matched idx of Morton:  1933
# matched idx of Morton:  1934
# matched idx of Morton:  1935
# matched idx of Morton:  1936
# matched idx of Morton:  1937
# matched idx of Morton:  1938
# matched idx of Morton:  1939
# matched idx of Morton:  1940
# matched idx of Morton:  1941
# matched idx of Morton:  1942
# matched idx of Morton:  1943
# matched idx of Morton:  1944
# matched idx of Morton:  1945
# matched idx of Morton:  1946
# matched idx of Morton:  1947
# matched idx of Morton:  1948
# matched idx of Morton:  1949
# matched idx of Morton:  1950
# matched idx of Morton:  1951
# matched idx of Morton:  1952
# matched idx of Morton:  1953
# matched idx of Morton:  1954
# matched idx of Morton:  1955
# matched idx of Morton:  1956
# matched idx of Morton:  1957
# matched idx of Morton:  1959
# matched idx of Morton:  1960
# matched idx of Morton:  1961
# matched idx of Morton:  1962
# matched idx of Morton:  1963
# matched idx of Morton:  1964
# matched idx of Morton:  1965
# matched idx of Morton:  1966
# matched idx of Morton:  1967
# matched idx of Morton:  1968
# matched idx of Morton:  1969
# matched idx of Morton:  1971
# matched idx of Morton:  1972
# matched idx of Morton:  1973
# matched idx of Morton:  1974
# matched idx of Morton:  1975
# matched idx of Morton:  1976
# matched idx of Morton:  1977
# matched idx of Morton:  1978
# matched idx of Morton:  1979
# matched idx of Morton:  1980
# matched idx of Morton:  1981
# matched idx of Morton:  1983
# matched idx of Morton:  1985
# matched idx of Morton:  1986
# matched idx of Morton:  1988
# matched idx of Morton:  1989
# matched idx of Morton:  1990
# matched idx of Morton:  1991
# matched idx of Morton:  1992
# matched idx of Morton:  1993
# matched idx of Morton:  1995
# matched idx of Morton:  1996
# matched idx of Morton:  1997
# matched idx of Morton:  1998
# matched idx of Morton:  1999
# matched idx of Morton:  2000
# matched idx of Morton:  2001
# matched idx of Morton:  2002
# matched idx of Morton:  2003
# matched idx of Morton:  2004
# matched idx of Morton:  2005
# matched idx of Morton:  2006
# matched idx of Morton:  2007
# matched idx of Morton:  2008
# matched idx of Morton:  2009
# matched idx of Morton:  2010
# matched idx of Morton:  2011
# matched idx of Morton:  2012
# matched idx of Morton:  2013
# matched idx of Morton:  2014
# matched idx of ANSS:  139168
# matched idx of ANSS:  139177
# matched idx of ANSS:  139186
# matched idx of ANSS:  139189
# matched idx of ANSS:  139206
# matched idx of ANSS:  139227
# matched idx of ANSS:  139281
# matched idx of ANSS:  139286
# matched idx of ANSS:  139294
# matched idx of ANSS:  139297
# matched idx of ANSS:  139302
# matched idx of ANSS:  139306
# matched idx of ANSS:  139337
# matched idx of ANSS:  139341
# matched idx of ANSS:  139372
# matched idx of ANSS:  139385
# matched idx of ANSS:  139416
# matched idx of ANSS:  139433
# matched idx of ANSS:  139438
# matched idx of ANSS:  139456
# matched idx of ANSS:  139486
# matched idx of ANSS:  139519
# matched idx of ANSS:  139528
# matched idx of ANSS:  139532
# matched idx of ANSS:  139550
# matched idx of ANSS:  139552
# matched idx of ANSS:  139553
# matched idx of ANSS:  139579
# matched idx of ANSS:  139587
# matched idx of ANSS:  139641
# matched idx of ANSS:  139670
# matched idx of ANSS:  139675
# matched idx of ANSS:  139678
# matched idx of ANSS:  139703
# matched idx of ANSS:  139723
# matched idx of ANSS:  139737
# matched idx of ANSS:  139745
# matched idx of ANSS:  139782
# matched idx of ANSS:  139803
# matched idx of ANSS:  139808
# matched idx of ANSS:  139844
# matched idx of ANSS:  139862
# matched idx of ANSS:  139873
# matched idx of ANSS:  139877
# matched idx of ANSS:  139947
# matched idx of ANSS:  139991
# matched idx of ANSS:  140020
# matched idx of ANSS:  140033
# matched idx of ANSS:  140048
# matched idx of ANSS:  140104
# matched idx of ANSS:  140107
# matched idx of ANSS:  140108
# matched idx of ANSS:  140112
# matched idx of ANSS:  140129
# matched idx of ANSS:  140152
# matched idx of ANSS:  140180
# matched idx of ANSS:  140182
# matched idx of ANSS:  140192
# matched idx of ANSS:  140196
# matched idx of ANSS:  140216
# matched idx of ANSS:  140241
# matched idx of ANSS:  140251
# matched idx of ANSS:  140263
# matched idx of ANSS:  140286
# matched idx of ANSS:  140294
# matched idx of ANSS:  140296
# matched idx of ANSS:  140319
# matched idx of ANSS:  140337
# matched idx of ANSS:  140345
# matched idx of ANSS:  140366
# matched idx of ANSS:  140372
# matched idx of ANSS:  140379
# matched idx of ANSS:  140385
# matched idx of ANSS:  140401
# 31020 20396
# length of mycatalog: 31020
# length of events_morton: 5282
# length of events_anss: 151790
# matched_indices_morton: 3095
# matched_indices_anss: 8393
# unmatched_indices_morton: 27925
# unmatched_indices_anss: 22627
# unmatched_indices_morton_and_anss (new events): 20396

# %%
# new concat code
# Concatenate and clean up dataframes
if len(matched_events_mycatalog2morton)>0:
    matched_events_mycatalog2morton = pd.concat(matched_events_mycatalog2morton).reset_index(drop=True)
    matched_times_mycatalog2morton = matched_events_mycatalog2morton['datetime']
    lat_mycatalog2morton = matched_events_mycatalog2morton['latitude']
    lon_mycatalog2morton = matched_events_mycatalog2morton['longitude']

if len(matched_events_morton2mycatalog)>0:   
    matched_events_morton2mycatalog = pd.DataFrame(matched_events_morton2mycatalog).reset_index(drop=True)
    
if len(unmatched_events_anss2mycatalog)>0:
    unmatched_events_anss2mycatalog = pd.DataFrame(unmatched_events_anss2mycatalog).reset_index(drop=True)
    
if len(unmatched_events_morton2mycatalog)>0:
    unmatched_events_morton2mycatalog = pd.DataFrame(unmatched_events_morton2mycatalog).reset_index(drop=True)

# if len(unmatched_events_mycatalog2morton_and_anss) > 0:
#     unmatched_events_mycatalog2morton_and_anss = unmatched_events_mycatalog2morton_and_anss.reset_index(drop=True)

if len(matched_events_mycatalog2anss)>0:
    matched_events_mycatalog2anss = pd.concat(matched_events_mycatalog2anss).reset_index(drop=True)
    matched_times_mycatalog2anss = matched_events_mycatalog2anss['datetime']
    lat_mycatalog2anss = matched_events_mycatalog2anss['latitude']
    lon_mycatalog2anss = matched_events_mycatalog2anss['longitude']

if len(matched_events_anss2mycatalog)>0:   
    matched_events_anss2mycatalog = pd.DataFrame(matched_events_anss2mycatalog).reset_index(drop=True)
    matched_times_anss2mycatalog = matched_events_anss2mycatalog['datetime']

print(f"length of mycatalog:{len(mycatalog)}")
print(f"length of events_morton:{len(events_morton)}")
print(f"length of events_anss:{len(events_anss)}")
print(f"matched_events_mycatalog2morton:{len(matched_events_mycatalog2morton)}")
print(f"matched_events_morton2mycatalog:{len(matched_events_morton2mycatalog)}")
print(f"unmatched_events_anss2mycatalog:{len(unmatched_events_anss2mycatalog)}")
print(f"unmatched_events_morton2mycatalog:{len(unmatched_events_morton2mycatalog)}")
print(f"unmatched_events_mycatalog2morton_and_anss (new events):{len(unmatched_events_mycatalog2morton_and_anss)}")
print(f"matched_events_mycatalog2anss:{len(matched_events_mycatalog2anss)}")
print(f"matched_events_anss2mycatalog:{len(matched_events_anss2mycatalog)}")
# Out:
# length of mycatalog:31020
# length of events_morton:5282
# length of events_anss:151790
# matched_events_mycatalog2morton:3109
# matched_events_morton2mycatalog:3109
# unmatched_events_anss2mycatalog:143274
# unmatched_events_morton2mycatalog:2173
# unmatched_events_mycatalog2morton_and_anss (new events):20396
# matched_events_mycatalog2anss:8516
# matched_events_anss2mycatalog:8516

# %%
# Save these three catalogs to csv files
year = 'all_regions'
matched_events_mycatalog2morton.to_csv(f'/wd1/hbito_data/data/datasets_{year}/matched_events_with_morton_mycatalog_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv')
matched_events_anss2mycatalog.to_csv(f'/wd1/hbito_data/data/datasets_{year}/matched_events_with_mycatalog_anss_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv')
matched_events_morton2mycatalog.to_csv(f'/wd1/hbito_data/data/datasets_{year}/matched_events_with_mycatalog_morton_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv')
unmatched_events_mycatalog2morton_and_anss.to_csv(f'/wd1/hbito_data/data/datasets_{year}/new_events_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv')
matched_events_mycatalog2anss.to_csv(f'/wd1/hbito_data/data/datasets_{year}/matched_events_with_anss_mycatalog_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv')
unmatched_events_morton2mycatalog.to_csv(f'/wd1/hbito_data/data/datasets_{year}/missing_events_from_mycatalog_morton_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv')
unmatched_events_anss2mycatalog.to_csv(f'/wd1/hbito_data/data/datasets_{year}/missing_events_from_mycatalog_anss_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv')
