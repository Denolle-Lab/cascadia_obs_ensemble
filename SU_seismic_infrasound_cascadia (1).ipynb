# %% [markdown]
# # Surface Event Analysis with seismic and infrasound
#
# This notebooks focuses on data from Mt Rainier by plotting the SU events and the possible infrasound records.
#
#
# Updated 08/17/2023
# Marine Denolle
# (mdenolle@uw.edu)

# %%
conda create --name myenv
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/hbito/.conda/envs/myenv
#
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seisbench
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seisbench in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (0.4.1)
# Requirement already satisfied: scipy>=1.5 in /home/hbito/.local/lib/python3.8/site-packages (from seisbench) (1.10.1)
# Requirement already satisfied: h5py>=3.1 in /home/hbito/.local/lib/python3.8/site-packages (from seisbench) (3.10.0)
# Requirement already satisfied: pandas>=1.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from seisbench) (1.5.3)
# Requirement already satisfied: obspy>=1.3.1 in /home/hbito/.local/lib/python3.8/site-packages (from seisbench) (1.3.1)
# Requirement already satisfied: torch>=1.10.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from seisbench) (2.0.1)
# Requirement already satisfied: numpy>=1.21.6 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from seisbench) (1.23.1)
# Requirement already satisfied: nest-asyncio>=1.5.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from seisbench) (1.5.4)
# Requirement already satisfied: tqdm>=4.52 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from seisbench) (4.64.0)
# Requirement already satisfied: decorator in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.3.1->seisbench) (5.1.1)
# Requirement already satisfied: matplotlib>=3.2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.3.1->seisbench) (3.7.2)
# Requirement already satisfied: sqlalchemy in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.3.1->seisbench) (1.4.40)
# Requirement already satisfied: lxml in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.3.1->seisbench) (4.9.2)
# Requirement already satisfied: setuptools in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.3.1->seisbench) (61.2.0)
# Requirement already satisfied: requests in /home/hbito/.local/lib/python3.8/site-packages (from obspy>=1.3.1->seisbench) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from pandas>=1.1->seisbench) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from pandas>=1.1->seisbench) (2022.7.1)
# Requirement already satisfied: triton==2.0.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (2.0.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/hbito/.local/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (4.5.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (10.9.0.58)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (11.4.0.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (11.7.101)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (11.7.91)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (10.2.10.91)
# Requirement already satisfied: jinja2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (3.1.2)
# Requirement already satisfied: filelock in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (3.12.2)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (11.10.3.66)
# Requirement already satisfied: sympy in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (1.12)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (11.7.99)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (11.7.4.91)
# Requirement already satisfied: networkx in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (2.8.6)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->seisbench) (2.14.3)
# Requirement already satisfied: wheel in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->seisbench) (0.37.1)
# Requirement already satisfied: lit in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.10.0->seisbench) (16.0.6)
# Requirement already satisfied: cmake in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.10.0->seisbench) (3.26.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (6.0.0)
# Requirement already satisfied: cycler>=0.10 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (4.34.4)
# Requirement already satisfied: six>=1.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.1->seisbench) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jinja2->torch>=1.10.0->seisbench) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.3.1->seisbench) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.3.1->seisbench) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.3.1->seisbench) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.3.1->seisbench) (1.26.11)
# Requirement already satisfied: greenlet!=0.4.17 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from sqlalchemy->obspy>=1.3.1->seisbench) (1.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from sympy->torch>=1.10.0->seisbench) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.0->obspy>=1.3.1->seisbench) (3.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter mpi4py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in /home/hbito/.local/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: mpi4py in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/mpi4py-3.1.4-py3.8-linux-x86_64.egg (3.1.4)
# Requirement already satisfied: qtconsole in /home/hbito/.local/lib/python3.8/site-packages (from jupyter) (5.5.0)
# Requirement already satisfied: ipywidgets in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyter) (8.1.0)
# Requirement already satisfied: jupyter-console in /home/hbito/.local/lib/python3.8/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: ipykernel in /home/hbito/.local/lib/python3.8/site-packages (from jupyter) (6.26.0)
# Requirement already satisfied: notebook in /home/hbito/.local/lib/python3.8/site-packages (from jupyter) (7.0.6)
# Requirement already satisfied: nbconvert in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyter) (7.7.3)
# Requirement already satisfied: packaging in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: psutil in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: ipython>=7.23.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (8.0.1)
# Requirement already satisfied: pyzmq>=20 in /home/hbito/.local/lib/python3.8/site-packages (from ipykernel->jupyter) (25.1.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/hbito/.local/lib/python3.8/site-packages (from ipykernel->jupyter) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/hbito/.local/lib/python3.8/site-packages (from ipykernel->jupyter) (7.4.9)
# Requirement already satisfied: comm>=0.1.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: nest-asyncio in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipykernel->jupyter) (1.5.4)
# Requirement already satisfied: tornado>=6.1 in /home/hbito/.local/lib/python3.8/site-packages (from ipykernel->jupyter) (6.3.3)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipywidgets->jupyter) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipywidgets->jupyter) (3.0.8)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-console->jupyter) (3.0.39)
# Requirement already satisfied: pygments in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyter-console->jupyter) (2.14.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (4.12.0)
# Requirement already satisfied: jinja2>=3.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (6.0.0)
# Requirement already satisfied: tinycss2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: jupyterlab-pygments in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: nbformat>=5.7 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: defusedxml in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (3.0.1)
# Requirement already satisfied: markupsafe>=2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbconvert->jupyter) (2.1.1)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /home/hbito/.local/lib/python3.8/site-packages (from notebook->jupyter) (4.0.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/hbito/.local/lib/python3.8/site-packages (from notebook->jupyter) (0.2.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/hbito/.local/lib/python3.8/site-packages (from notebook->jupyter) (2.25.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/hbito/.local/lib/python3.8/site-packages (from notebook->jupyter) (2.9.1)
# Requirement already satisfied: qtpy>=2.4.0 in /home/hbito/.local/lib/python3.8/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter) (3.8.1)
# Requirement already satisfied: decorator in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: stack-data in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pickleshare in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: black in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (22.1.0)
# Requirement already satisfied: jedi>=0.16 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (61.2.0)
# Requirement already satisfied: backcall in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: entrypoints in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (2.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.0.0)
# Requirement already satisfied: overrides in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.4.0)
# Requirement already satisfied: jupyter-server-terminals in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.4.4)
# Requirement already satisfied: prometheus-client in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.0)
# Requirement already satisfied: argon2-cffi in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.2)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.8.0)
# Requirement already satisfied: websocket-client in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.6.4)
# Requirement already satisfied: importlib-resources>=1.4 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (6.0.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/hbito/.local/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.2.0)
# Requirement already satisfied: tomli in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.1)
# Requirement already satisfied: async-lru>=1.0.0 in /home/hbito/.local/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.4)
# Requirement already satisfied: babel>=2.10 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.19.0)
# Requirement already satisfied: json5>=0.9.0 in /home/hbito/.local/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.14)
# Requirement already satisfied: requests>=2.31 in /home/hbito/.local/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Requirement already satisfied: fastjsonschema in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.18.0)
# Requirement already satisfied: wcwidth in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.4.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/hbito/.local/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.1.3)
# Requirement already satisfied: idna>=2.8 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /home/hbito/.local/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/hbito/.local/lib/python3.8/site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.2->notebook->jupyter) (4.5.0)
# Requirement already satisfied: pytz>=2015.7 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2022.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.30.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.1.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.10)
# Requirement already satisfied: pyyaml>=5.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0)
# Requirement already satisfied: rfc3339-validator in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/hbito/.local/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/hbito/.local/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (0.4.3)
# Requirement already satisfied: pathspec>=0.9.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (0.9.0)
# Requirement already satisfied: click>=8.0.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from black->ipython>=7.23.1->ipykernel->jupyter) (8.0.3)
# Requirement already satisfied: executing in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.2)
# Requirement already satisfied: pure-eval in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: asttokens in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: webcolors>=1.11 in /home/hbito/.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.13)
# Requirement already satisfied: uri-template in /home/hbito/.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/hbito/.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.4)
# Requirement already satisfied: isoduration in /home/hbito/.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (20.11.0)
# Requirement already satisfied: fqdn in /home/hbito/.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.15.1)
# Requirement already satisfied: pycparser in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ELEP==0.0.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ELEP==0.0.2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (0.0.2)
# Requirement already satisfied: obspy>=1.2 in /home/hbito/.local/lib/python3.8/site-packages (from ELEP==0.0.2) (1.3.1)
# Requirement already satisfied: numpy>=1.21.6 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ELEP==0.0.2) (1.23.1)
# Requirement already satisfied: pandas>=1.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ELEP==0.0.2) (1.5.3)
# Requirement already satisfied: scipy>=1.5 in /home/hbito/.local/lib/python3.8/site-packages (from ELEP==0.0.2) (1.10.1)
# Requirement already satisfied: tqdm>=4.52 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ELEP==0.0.2) (4.64.0)
# Requirement already satisfied: nest-asyncio>=1.5.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ELEP==0.0.2) (1.5.4)
# Requirement already satisfied: torch>=1.10.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from ELEP==0.0.2) (2.0.1)
# Requirement already satisfied: h5py>=3.1 in /home/hbito/.local/lib/python3.8/site-packages (from ELEP==0.0.2) (3.10.0)
# Requirement already satisfied: sqlalchemy in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.2->ELEP==0.0.2) (1.4.40)
# Requirement already satisfied: lxml in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.2->ELEP==0.0.2) (4.9.2)
# Requirement already satisfied: decorator in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.2->ELEP==0.0.2) (5.1.1)
# Requirement already satisfied: requests in /home/hbito/.local/lib/python3.8/site-packages (from obspy>=1.2->ELEP==0.0.2) (2.31.0)
# Requirement already satisfied: matplotlib>=3.2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.2->ELEP==0.0.2) (3.7.2)
# Requirement already satisfied: setuptools in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from obspy>=1.2->ELEP==0.0.2) (61.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from pandas>=1.1->ELEP==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from pandas>=1.1->ELEP==0.0.2) (2022.7.1)
# Requirement already satisfied: typing-extensions in /home/hbito/.local/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (4.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (11.10.3.66)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (11.7.4.91)
# Requirement already satisfied: sympy in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (1.12)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (2.14.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (8.5.0.96)
# Requirement already satisfied: jinja2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (3.1.2)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (11.7.91)
# Requirement already satisfied: filelock in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (3.12.2)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (11.4.0.1)
# Requirement already satisfied: triton==2.0.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (2.0.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (10.2.10.91)
# Requirement already satisfied: networkx in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from torch>=1.10.0->ELEP==0.0.2) (2.8.6)
# Requirement already satisfied: wheel in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->ELEP==0.0.2) (0.37.1)
# Requirement already satisfied: cmake in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.10.0->ELEP==0.0.2) (3.26.4)
# Requirement already satisfied: lit in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.10.0->ELEP==0.0.2) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (4.34.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (6.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (23.0)
# Requirement already satisfied: cycler>=0.10 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (0.11.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (9.3.0)
# Requirement already satisfied: six>=1.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.1->ELEP==0.0.2) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from jinja2->torch>=1.10.0->ELEP==0.0.2) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.2->ELEP==0.0.2) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.2->ELEP==0.0.2) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.2->ELEP==0.0.2) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from requests->obspy>=1.2->ELEP==0.0.2) (1.26.11)
# Requirement already satisfied: greenlet!=0.4.17 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from sqlalchemy->obspy>=1.2->ELEP==0.0.2) (1.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from sympy->torch>=1.10.0->ELEP==0.0.2) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.0->obspy>=1.2->ELEP==0.0.2) (3.8.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import sys
# sys.path.append('/data/wsd01/pnwstore/')
import matplotlib.pyplot as plt
# from matplotlib.pyplot import Figure
import numpy as np
import pandas as pd
import obspy
from obspy.core import UTCDateTime
from obspy.clients.fdsn.client import Client
import scipy
from scipy import optimize
from scipy.optimize import curve_fit
from geopy import distance
from datetime import datetime
import rasterio as rio
import torch
plt.rcParams.update({'font.size': 10})
from utils import *


import seisbench.models as sbm
device = torch.device("cpu")

from ELEP.elep.ensemble_statistics import ensemble_statistics
from ELEP.elep.ensemble_coherence import ensemble_semblance 
from ELEP.elep.ensemble_learners import ensemble_regressor_cnn
from mbf_elep_func import apply_mbf
from ELEP.elep import mbf, mbf_utils
from ELEP.elep import trigger_func
from ELEP.elep.trigger_func import picks_summary_simple

from ELEP.elep.mbf_utils import make_LogFq, make_LinFq, rec_filter_coeff, create_obspy_trace
from ELEP.elep.mbf import MB_filter as MBF

# %% [markdown]
# Parameters

# %%
# define clients to download the station data
# client = WaveformClient() # we ignore PNWdatastore for now
client2 = Client('IRIS')

t_before = 15 #number of seconds before pick time
# t_after = 15 #number of seconds after pick time
t_before_raw = 1200 #number of seconds before pick time before removing instrumental response
# t_after_raw = 1200 #number of seconds after pick time before removing instrumental response
t_around = 10
fs = 40 #sampling rate that all waveforms are resampled to
window = 150 #window length of the signal (this will help with phase picking with EqT next). 
# Use 150 seconds @ 40 Hz gives 6001 points. 
pr = 98 #percentile
thr = 5 #SNR threshold
station_distance_threshold = 25
pi = np.pi
v_s = 1000 #shear wave velocity at the surface

# range of dates that we are looking at
t_beginning = UTCDateTime(2001,1,1,0,0,0) 
t_end = UTCDateTime(2023,8,2,23,59)
twin=6000

smooth_length = 5 # constant for smoothing the waveform envelopes
low_cut = 1 #low frequency threshold
high_cut = 12 #high frequency threshold
az_thr = 1000 #threshold of distance in meters from source location
step = 100 #step every 100 m
t_step = 1 #step every second
ratio = 5.6915196 #used to define the grid 
colors = list(plt.cm.tab10(np.arange(10)))*3
radius = 6371e3 # radius of the earth

# %% [markdown]
# ## Download eqT models

# %%
import os
# os.makedirs("/Users/marinedenolle/.seisbench/models/v3/eqtransformer",

# %%
# !wget https://github.com/congcy/ELEP/raw/main/docs/tutorials/data/pnw.pt.v1 -O ~/.seisbench/models/v3/eqtransformer/pnw.pt.v1
# !wget https://github.com/congcy/ELEP/raw/main/docs/tutorials/data/pnw.json.v1 -O ~/.seisbench/models/v3/eqtransformer/pnw.json.v1
# Out:
# --2023-11-19 22:18:43--  https://github.com/congcy/ELEP/raw/main/docs/tutorials/data/pnw.pt.v1
# Resolving github.com (github.com)... 20.29.134.23
# Connecting to github.com (github.com)|20.29.134.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/congcy/ELEP/main/docs/tutorials/data/pnw.pt.v1 [following]
# --2023-11-19 22:18:44--  https://raw.githubusercontent.com/congcy/ELEP/main/docs/tutorials/data/pnw.pt.v1
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1592020 (1.5M) [application/octet-stream]
# Saving to: ‘/home/hbito/.seisbench/models/v3/eqtransformer/pnw.pt.v1’
#
# /home/hbito/.seisbe 100%[===================>]   1.52M  9.34MB/s    in 0.2s
#
# 2023-11-19 22:18:44 (9.34 MB/s) - ‘/home/hbito/.seisbench/models/v3/eqtransformer/pnw.pt.v1’ saved [1592020/1592020]
#
# --2023-11-19 22:18:44--  https://github.com/congcy/ELEP/raw/main/docs/tutorials/data/pnw.json.v1
# Resolving github.com (github.com)... 20.29.134.23
# Connecting to github.com (github.com)|20.29.134.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/congcy/ELEP/main/docs/tutorials/data/pnw.json.v1 [following]
# --2023-11-19 22:18:45--  https://raw.githubusercontent.com/congcy/ELEP/main/docs/tutorials/data/pnw.json.v1
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘/home/hbito/.seisbench/models/v3/eqtransformer/pnw.json.v1’
#
# /home/hbito/.seisbe 100%[===================>]     599  --.-KB/s    in 0s
#
# 2023-11-19 22:18:45 (87.0 MB/s) - ‘/home/hbito/.seisbench/models/v3/eqtransformer/pnw.json.v1’ saved [599/599]

# %%
# ML picker parameters
paras_semblance = {'dt':0.025, 'semblance_order':4, 'window_flag':True, 
                   'semblance_win':0.5, 'weight_flag':'max'}
p_thrd, s_thrd = 0.01, 0.05

# %%
# download models
pretrain_list = ["pnw","ethz","instance","scedc","stead","geofon","neic"]
pn_pnw_model = sbm.EQTransformer.from_pretrained('pnw')
pn_ethz_model = sbm.EQTransformer.from_pretrained("ethz")
pn_instance_model = sbm.EQTransformer.from_pretrained("instance")
pn_scedc_model = sbm.EQTransformer.from_pretrained("scedc")
pn_stead_model = sbm.EQTransformer.from_pretrained("stead")
pn_geofon_model = sbm.EQTransformer.from_pretrained("geofon")
pn_neic_model = sbm.EQTransformer.from_pretrained("neic")

list_models = [pn_pnw_model,pn_ethz_model,pn_scedc_model,pn_neic_model,pn_geofon_model,pn_stead_model,pn_instance_model]

# %%
pn_pnw_model.to(device);
pn_ethz_model.to(device);
pn_scedc_model.to(device);
pn_neic_model.to(device);
pn_geofon_model.to(device);
pn_stead_model.to(device);
pn_instance_model.to(device);

# %% [markdown]
# ### 1. Volcano Data (network and station, labeled with volcano name)

# %%
#this data includes all stations within 50km of each volcano and the lat, lon, elev of each station
df = pd.read_csv('../data/station/Volcano_Metadata_50km.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [36], in <module>
#       1 #this data includes all stations within 50km of each volcano and the lat, lon, elev of each station
# ----> 2 df = pd.read_csv('../data/station/Volcano_Metadata_50km.csv')
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/station/Volcano_Metadata_50km.csv'

# %%
# center latitude, center longitude, elevation(m), left_trim, right_trim, bottom_trim, top_trim 
volc_lat_lon = {}
volc_lat_lon['Mt_Rainier'] = [46.8528857, -121.7603744, 4392.5, 10000, 3000, 15000, 7000]
volc_lat_lon['Mt_Adams'] = [46.202621, -121.4906384, 3743.2, 5000, 3000, 4000, 2000]
volc_lat_lon['Mt_Baker'] = [48.7773426,  -121.8132008, 3287.6, 0, 0, 0, 2000]
# change the lat and lon of mt st helens to the middle of the dome instead of the highest point
volc_lat_lon['Mt_St_Helens'] =[46.200472222222224,-122.18883611111112,2549, 10000, 10000, 17000, 15000] #[46.1912, -122.1944, 2549]
volc_lat_lon['Glacier_Peak'] = [48.1112273, -121.1139922, 3213, 14000, 10000, 8000, 10000]
volc_lat_lon['Mt_Hood']=[45.373221, -121.696509, 3428.7, 18000, 50000, 35000, 65000]

# %% [markdown]
# ### 3. Surface Event Data from PNSN
#
# Read files straight from PNSN data base. Extract station and network code, phase pick time (seen as start_time). this should be converted to pick_time0.

# %%
f1 = pd.read_csv("../data/events/su_picks.txt",sep="|")
f1.head()
print(f1.keys())

# %%
# clean up the spaces in the file
format='%Y/%m/%d %H:%M:%S'
test=f1["date"].values.tolist()
start_time_temp = [  datetime.strptime(x.strip(),'%Y/%m/%d %H:%M:%S') for x in f1["date"].values.tolist()]
# # Ignore events prior to t_beginning
ik=np.where(np.array(start_time_temp)>datetime(2001,1,1))[0][0]

# select only net, sta, evid, startime for event past the start date.

start_time = start_time_temp[ik:]
net=[ x.strip() for x in f1["net"].values.tolist()][ik:]
sta=[ x.strip() for x in f1["sta"].values.tolist()][ik:]
evt_id=[ x for x in f1["orid"].values.tolist()][ik:]
all_stas=set(sta)


f2=pd.DataFrame({"date":start_time,"net":net,"sta":sta,"evt_id":evt_id})
f2.head()

# %% [markdown]
# ## Ensemble picking

# %%
fqmin = low_cut
fqmax = high_cut
dt = 0.025; fs = 40
nfqs = 10
nt = 6000; nc = 3
fq_list = make_LogFq(fqmin, fqmax, dt, nfqs)
coeff_HP, coeff_LP = rec_filter_coeff(fq_list, dt)
MBF_paras = {'f_min':fqmin, 'f_max':fqmax, 'nfqs':nfqs, 'frequencies':fq_list, 'CN_HP':coeff_HP, 'CN_LP':coeff_LP, \
    'dt':dt, 'fs':fs, 'nt':nt, 'nc':nc, 'npoles': 2}

# %%
# list of infrasound stations in Mt Rainier
df_infra = pd.read_csv("../data/station/MtRainier-infra-stations.txt",sep="|")
print(df_infra.head())
df_infra["Station"]

# %% [markdown]
# ## Full stack:
#
# 1. Downdload waveforms (filtering and SNR measurements, duration measurements, envelope). Note that we download infrasound for fun.
# 3. Phase picking (transfer learned, semblance, and envelope)
# 4. plotting

# %%
from matplotlib.backends.backend_pdf import PdfPages
pdf = PdfPages('../plots/SeisInfra_MtRainier.pdf')
nfigure=0
for n in range(len(evt_id)): 
    if start_time[n]<datetime(2021,1,1):continue  
    event_ID = str(evt_id[n])
    otime = UTCDateTime(start_time[n])
    networks=net[n]
    stations=sta[n]
    print(net[n],sta[n])
    if sta[n]=="LON" or sta[n]=="LO2": continue
    try:
        associated_volcano = df[df['Station']== sta[n]]['Volcano_Name'].values[0]
    except:
        pass
    if associated_volcano!="Mt_Rainier":continue            
    # get info for stations within 50km of volcano that event ocurred at
    stations = df[df['Volcano_Name'] == associated_volcano]['Station'].values.tolist()
    networks = df[df['Volcano_Name'] == associated_volcano]['Network'].values.tolist()
    latitudes = df[df['Volcano_Name'] == associated_volcano]['Latitude'].values.tolist()
    longitudes = df[df['Volcano_Name'] == associated_volcano]['Longitude'].values.tolist()
    elevations = df[df['Volcano_Name']== associated_volcano]['Elevation'].values.tolist()

    #################### WAVEFORM DOWNLOAD #######################
        #Download all waveforms for that event based on stations and times
    # try:
    bulk=[]
    for m in range(0, len(networks)):
        bulk.append([networks[m], stations[m], '*', '*H*', otime-t_before_raw, otime+t_before_raw])
    st = client2.get_waveforms_bulk(bulk)

    bulk2=[]
    for m in range(0, len(df_infra["Station"])):
        bulk2.append(["CC", df_infra["Station"][m], '01', 'BDF', otime-t_before_raw, otime+t_before_raw])
    infra = client2.get_waveforms_bulk(bulk2)
    #remove unwanted data
    for tr in st:
        cha = tr.stats.channel
        try:
            if len(tr.data)/tr.stats.sampling_rate < 239.9:
                st.remove(tr)
        except:
            pass

    #resampling the data to 40Hz for each trace
    st = resample(st,fs) 
    infra = resample(infra,fs) 

    # #Plotting all traces for one event with channel z, SNR>10, and bandpasses between 2-12Hz
    evt_data = obspy.Stream()
    evt_infradata = obspy.Stream()
    SNR,SNR_weight, no_weight,stas,nets,max_amp_times,durations,data_env_dict,t_diff = [],[],[],[],[],[],[],{},{}
    nfigure+=1
    if nfigure<50:
        fig = plt.figure(figsize = (11,8), dpi=400)
        fig.suptitle(str(otime)+" "+associated_volcano)
        plt.rcParams.update({'font.size': 14})
        ax = plt.subplot(1,1,1)
        iplot = 0
    zz = st.select(component="Z")
    for i,ii in enumerate(zz):
        network = ii.stats.network
        station = ii.stats.station
        ii.detrend(type = 'demean')
        ii.filter('bandpass',freqmin=low_cut,freqmax=high_cut,corners=2,zerophase=True)
        signal_window = ii.copy()
        noise_window = ii.copy()
        signal_window.trim(otime - t_before, otime - t_before + window) # trim the signal at the first pick time of the PNSN data, with loose 40s before
        noise_window.trim(otime - window -t_before, otime - t_before) # noise window of the same length
        if not len(signal_window.data) or not len(signal_window.data): continue
        snr = (20 * np.log(np.percentile(np.abs(signal_window.data),pr) 
                        / np.percentile(np.abs(noise_window.data),pr))/np.log(10))
        max_amp_time = np.argmax(noise_window.data)/fs
        if snr<thr: 
            st.remove(ii)
            continue
        evt_data.append(signal_window)
        stas.append(ii.stats.station)
        t = signal_window.times()
        if nfigure<50:
            ax.plot(t-t_before,signal_window.data/np.max(np.abs(signal_window.data))+iplot*1.5)
            ax.set_xlabel('time (seconds)')
            ax.set_xlim((-t_before,100))
            ax.set_yticks([])
            plt.text(80, iplot*1.5, station)
            iplot += 1

    sta_available,ind = np.unique(np.array(stas),return_index=True)
    sta_available=sta_available[np.argsort(ind)]
    if len(sta_available)==0:continue
#       Plot the infrasound as well

    evt_infradata = obspy.Stream()
    stas_infra=[]
    for i,ii in enumerate(infra):
        ii.filter('bandpass',freqmin=low_cut,freqmax=high_cut-5,corners=2,zerophase=True)
        signal_window = ii.copy()
        signal_window.trim(otime - t_before, otime - t_before  + window) # trim the signal at the first pick time of the PNSN data, with loose 40s before
        if not len(signal_window.data): continue
        t1 = signal_window.times()
        if nfigure<50:
            ax.plot(t1-t_before,signal_window.data/np.max(np.abs(signal_window.data))+iplot*1.5,color='0.8',linewidth=0.8)
            ax.text(80, iplot*1.5, signal_window.stats.station)
            iplot+=1
            ax.set_xlim((-t_before,100))
        evt_infradata.append(signal_window)
        stas_infra.append(ii.stats.station)

    sta_infra_available,ind = np.unique(np.array(stas_infra),return_index=True)
    sta_infra_available=sta_infra_available[np.argsort(ind)]
    if len(sta_infra_available)==0:continue

    # PHASE PICKING
        # test the new function
    smb_peak,smb_peak_mbf = apply_mbf(evt_data, sta_available, \
            list_models, MBF_paras, paras_semblance, t_before,t_around)
    smb_peak_infra,smb_peak_mbf_infra = apply_mbf(evt_infradata, sta_infra_available, \
            list_models, MBF_paras, paras_semblance, t_before+40,t_around+40)

    print("reference time: ",otime)
    print("relative picks from seismometers")
    print(sta_available)
    print(smb_peak_mbf)
    print("relative picks from infrasound")
    print(sta_infra_available)
    print(smb_peak_mbf_infra)

    if nfigure<50:
        iplot=0
        for i in range(len(sta_available)):
            ax.vlines(smb_peak_mbf[i], ymin = iplot*1.5-.5, ymax = iplot*1.5+.5, color = 'r')
            iplot+=1
        for i in range(len(sta_infra_available)):
            if np.abs(smb_peak_mbf_infra[i])>0.5:
                ax.vlines(smb_peak_mbf_infra[i]+40, ymin = iplot*1.5-.5, ymax = iplot*1.5+.5, color = 'r')
            iplot+=1

        plt.grid(True)
        pdf.savefig(fig)
        print("Plotted")
        fig.savefig('../plots/waveforms_seismic_infrasound_'+event_ID+associated_volcano+'.png')
        plt.show()
        del fig
        nfigure+=1

    if nfigure==50 :pdf.close()


    

# except:
#     pass

# %%
print(t_before,t_around)
print(t_before+40,t_around+60)
