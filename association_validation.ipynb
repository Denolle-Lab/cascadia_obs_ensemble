# %% [markdown]
# ## Match the events found by Pyocto with other catalogs
#
# Get the events from the USGS, Stone and Morton's papers and compare with the events from our association

# %% [markdown]
# ### Comparing with the USGS catalog

# %%
import pandas as pd
import numpy as np
from obspy.clients.fdsn import Client
from pnwstore.mseed import WaveformClient
from datetime import datetime

# %%
# Load all the pick assignments 
all_pick_assignments = pd.read_csv('all_pick_assignments.csv')

# %%
# Load the USGS catalog
client = Client("USGS")
client_waveforms = WaveformClient()
events_USGS = client.get_events(starttime = UTCDateTime("2012-10-14T00:00:00.000000"),
                  endtime   = UTCDateTime("2012-10-14T23:59:59.999999"),
                  minlatitude = 40, maxlatitude = 44, 
                  minlongitude = -125, maxlongitude = -120)
events_USGS
# Out:
# 2 Event(s) in Catalog:
# 2012-10-14T03:08:01.290000Z | +40.721, -124.210 | 1.74 md | manual
# 2012-10-14T02:39:45.510000Z | +40.301, -124.416 | 1.49 md | manual

# %%
# Convert the time series in all_pick_assignments to 

all_pick_assignments['time'] = pd.to_datetime(all_pick_assignments['time'])

# %%
# Convert the 
USGS_pick_time1 = events_USGS[0].origins[0].time.datetime
USGS_pick_time2 = events_USGS[1].origins[0].time.datetime

# %%
USGS_pick_timestamp1 = pd.to_datetime(USGS_pick_time1, utc=True)
USGS_pick_timestamp2 = pd.to_datetime(USGS_pick_time2, utc=True)

# %%
assignments_USGS_time1 = all_pick_assignments.loc[(all_pick_assignments['time'] > USGS_pick_timestamp1 - pd.Timedelta(5, "seconds")) & (all_pick_assignments['time'] < USGS_pick_timestamp1 + pd.Timedelta(5, "seconds")) ]
assignments_USGS_time1
# Out:
#     Unnamed: 0  idx                             time          x           y  \
# 9            9    2 2012-10-14 03:08:04.522444+00:00  12.259024 -107.072404
# 10          10    2 2012-10-14 03:08:04.522444+00:00  12.259024 -107.072404
# 11          11    2 2012-10-14 03:08:04.522444+00:00  12.259024 -107.072404
# 12          12    2 2012-10-14 03:08:04.522444+00:00  12.259024 -107.072404
# 13          13    2 2012-10-14 03:08:04.522444+00:00  12.259024 -107.072404
# 14          14    2 2012-10-14 03:08:04.522444+00:00  12.259024 -107.072404
# 15          15    2 2012-10-14 03:08:04.522444+00:00  12.259024 -107.072404
#
#             z  picks   latitude   longitude      depth  event_idx  pick_idx  \
# 9   49.609375      7  40.785806 -124.604763  49.609375          2      1456
# 10  49.609375      7  40.785806 -124.604763  49.609375          2       192
# 11  49.609375      7  40.785806 -124.604763  49.609375          2      1599
# 12  49.609375      7  40.785806 -124.604763  49.609375          2       288
# 13  49.609375      7  40.785806 -124.604763  49.609375          2      1630
# 14  49.609375      7  40.785806 -124.604763  49.609375          2      1256
# 15  49.609375      7  40.785806 -124.604763  49.609375          2      2002
#
#     residual station phase     time_pick
# 9   0.293201   FS09B     S  1.350184e+09
# 10 -1.275212    G10B     P  1.350184e+09
# 11  0.826728    G10B     S  1.350184e+09
# 12 -0.841498    G19B     P  1.350184e+09
# 13  0.238312    G19B     S  1.350184e+09
# 14  0.128741    M14B     P  1.350184e+09
# 15  0.629728    M14B     S  1.350184e+09

# %%
assignments_USGS_time2 = all_pick_assignments.loc[(all_pick_assignments['time'] > USGS_pick_timestamp2 - pd.Timedelta(5, "seconds")) & (all_pick_assignments['time'] < USGS_pick_timestamp2 + pd.Timedelta(5, "seconds")) ]
assignments_USGS_time2
# Out:
#    Unnamed: 0  idx                             time          x           y  \
# 4           4    1 2012-10-14 02:39:44.924554+00:00  26.269336 -128.412984
# 5           5    1 2012-10-14 02:39:44.924554+00:00  26.269336 -128.412984
# 6           6    1 2012-10-14 02:39:44.924554+00:00  26.269336 -128.412984
# 7           7    1 2012-10-14 02:39:44.924554+00:00  26.269336 -128.412984
# 8           8    1 2012-10-14 02:39:44.924554+00:00  26.269336 -128.412984
#
#            z  picks   latitude   longitude      depth  event_idx  pick_idx  \
# 4  40.234375      5  40.593306 -124.439672  40.234375          1        12
# 5  40.234375      5  40.593306 -124.439672  40.234375          1      1455
# 6  40.234375      5  40.593306 -124.439672  40.234375          1       190
# 7  40.234375      5  40.593306 -124.439672  40.234375          1      1597
# 8  40.234375      5  40.593306 -124.439672  40.234375          1       286
#
#    residual station phase     time_pick
# 4  0.377781   FS09B     P  1.350182e+09
# 5 -0.171493   FS09B     S  1.350182e+09
# 6 -0.436940    G10B     P  1.350182e+09
# 7  0.220285    G10B     S  1.350182e+09
# 8  0.010367    G19B     P  1.350182e+09

# %%
type(USGS_pick_timestamp1)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(USGS_pick_time1)
# Out:
# datetime.datetime

# %% [markdown]
# ### Comparing to Stone's Catalog

# %%
# Load Stone's catalog
events_cascadia = pd.read_csv('jgrb52524-sup-0002-2017jb014966-ds01.csv')
events_jdf = pd.read_csv('jgrb52524-sup-0003-2017jb014966-ds02.csv')

# %%
events_cascadia[0:5]
# Out:
#      yyyy/mm/dd    hh:MM:ss.ff   Latitude   Longitude  Depth (km)  Magnitude  \
# 0  '2011/10/21'  '10:58:59.67'  47.869000 -124.261333       35.90       1.10
# 1  '2011/11/16'  '20:10:51.77'  48.775500 -124.967667       21.03       2.44
# 2  '2011/11/28'  '00:27:12.78'  44.432500 -124.501167       22.10       1.65
# 3  '2011/12/05'  '14:39:07.32'  48.008000 -124.310000       33.67       2.67
# 4  '2011/12/20'  '00:00:21.16'  44.672333 -124.292000       18.41       1.93
#
#    # Nonzero Phase Arrivals  RMS (s)  Max Azimuthal Gap  \
# 0                        13     0.26                142
# 1                        12     0.57                201
# 2                        20     0.28                 95
# 3                         6     0.07                154
# 4                        23     0.40                106
#
#    Distance to nearest station (km)  horizontal med. st. err.  \
# 0                              12.3                       1.2
# 1                              45.3                       3.8
# 2                              10.6                       0.6
# 3                              10.5                       1.6
# 4                              20.2                       0.5
#
#    vertical med. st. err.  depth fixed? (1=yes)  deployment year  \
# 0                     1.3                     0                1
# 1                    23.3                     0                1
# 2                     0.7                     0                1
# 3                     1.2                     0                1
# 4                     0.6                     0                1
#
#    Land Network ID (CNSN=1) Land Network Notes                       time
# 0                         0          '-'   NaN  '2011/10/21''10:58:59.67'
# 1                  10830998       'PNSN'   NaN  '2011/11/16''20:10:51.77'
# 2                         0          '-'   NaN  '2011/11/28''00:27:12.78'
# 3                         0          '-'   NaN  '2011/12/05''14:39:07.32'
# 4                  10832893       'PNSN'   NaN  '2011/12/20''00:00:21.16'

# %%
events_jdf[0:5]
# Out:
#    Time (epoch)  Longitude  Latitude  Depth (km)  RMS (s)  CI Year
# 0    1319372776  -128.5916   44.1944     25.0802   0.8778        1
# 1    1319592376  -126.6822   43.5670      0.0000   0.5846        1
# 2    1320368639  -127.3553   43.8455      0.0000   0.4044        1
# 3    1320610871  -127.9540   43.8234      0.0000   0.4410        1
# 4    1320616859  -127.4139   44.4245      7.4284   0.3948        1

# %%
#
events_jdf['datetime'] = events_jdf.apply(lambda a: datetime.fromtimestamp(a['Time (epoch)']), axis = 1)

# %%
events_jdf['datetime'] = pd.to_datetime(events_jdf['datetime'])

# %%
# Check the type of the time object
pd.to_datetime(events_jdf['datetime'][0]))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Define the time just for testing the next cell
time = pd.to_datetime('2012-10-14 00:00:00.000000Z', utc=True)

# %%
events_jdf_20121014 = events_jdf.loc[events_jdf['datetime'] <  pd.to_datetime("10/14/2012  9:09:37 PM", utc=True)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:582, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     581 try:
# --> 582     self._check_compatible_with(other)
#     583 except (TypeError, IncompatibleFrequency) as err:
#     584     # e.g. tzawareness mismatch
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:461, in DatetimeArray._check_compatible_with(self, other, setitem)
#     460     return
# --> 461 self._assert_tzawareness_compat(other)
#     462 if setitem:
#     463     # Stricter check for setitem vs comparison methods
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:694, in DatetimeArray._assert_tzawareness_compat(self, other)
#     693     if other_tz is not None:
# --> 694         raise TypeError(
#     695             "Cannot compare tz-naive and tz-aware datetime-like objects."
#     696         )
#     697 elif other_tz is None:
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects.
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:1054, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1053 try:
# -> 1054     other = self._validate_comparison_value(other)
#    1055 except InvalidComparison:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:585, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     583     except (TypeError, IncompatibleFrequency) as err:
#     584         # e.g. tzawareness mismatch
# --> 585         raise InvalidComparison(other) from err
#     587 elif not is_list_like(other):
#
# InvalidComparison: 2012-10-14 21:09:37+00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [272], in <module>
# ----> 1 events_jdf_20121014 = events_jdf.loc[events_jdf['datetime'] <  pd.to_datetime("10/14/2012  9:09:37 PM", utc=True)]
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:273, in comparison_op(left, right, op)
#     264         raise ValueError(
#     265             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     266         )
#     268 if should_extension_dispatch(lvalues, rvalues) or (
#     269     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     270     and not is_object_dtype(lvalues.dtype)
#     271 ):
#     272     # Call the method on lvalues
# --> 273     res_values = op(lvalues, rvalues)
#     275 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     276     # numpy does not like comparisons vs None
#     277     if op is operator.ne:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:1056, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1054     other = self._validate_comparison_value(other)
#    1055 except InvalidComparison:
# -> 1056     return invalid_comparison(self, other, op)
#    1058 dtype = getattr(other, "dtype", None)
#    1059 if is_object_dtype(dtype):
#    1060     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#    1061     #  comparison otherwise it would fail to raise when
#    1062     #  comparing tz-aware and tz-naive
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/ops/invalid.py:36, in invalid_comparison(left, right, op)
#      34 else:
#      35     typ = type(right).__name__
# ---> 36     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      37 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and Timestamp

# %%
events_cascadia_20121014 = events_cascadia.loc[(pd.to_datetime(events_cascadia['time']) > pd.to_datetime('2012-10-14 00:00:00', utc=True)) & (pd.to_datetime(events_cascadia['time']) < pd.to_datetime('2012-10-15 00:00:00', utc=True))]

# %%
events_cascadia['time']= events_cascadia['yyyy/mm/dd'].str.cat(events_cascadia['hh:MM:ss.ff'])

# %%
events_cascadia_20121014 = events_cascadia.loc[(pd.to_datetime(events_cascadia['time']) > pd.to_datetime('2012-10-14 00:00:00', utc=True)) & (pd.to_datetime(events_cascadia['time']) < pd.to_datetime('2012-10-15 00:00:00', utc=True))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: '1902/01/31''46:57:50.28'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "'1902/01/31''46:57:50.28'" at position 131
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Input In [211], in <module>
# ----> 1 events_cascadia_20121014 = events_cascadia.loc[(pd.to_datetime(events_cascadia['time']) > pd.to_datetime('2012-10-14 00:00:00', utc=True)) & (pd.to_datetime(events_cascadia['time']) < pd.to_datetime('2012-10-15 00:00:00', utc=True))]
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: '1902/01/31''46:57:50.28' present at position 131

# %%
events_cascadia_20121014 = events_cascadia.loc[(pd.to_datetime(events_cascadia['time']) > pd.to_datetime('2012-10-14 00:00:00', utc=True))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: '1902/01/31''46:57:50.28'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "'1902/01/31''46:57:50.28'" at position 131
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Input In [213], in <module>
# ----> 1 events_cascadia_20121014 = events_cascadia.loc[(pd.to_datetime(events_cascadia['time']) > pd.to_datetime('2012-10-14 00:00:00', utc=True))]
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: '1902/01/31''46:57:50.28' present at position 131

# %%
pd.to_datetime(events_cascadia['time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: '1902/01/31''46:57:50.28'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "'1902/01/31''46:57:50.28'" at position 131
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Input In [218], in <module>
# ----> 1 pd.to_datetime(events_cascadia['time'])
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: '1902/01/31''46:57:50.28' present at position 131

# %%
events_cascadia['time'][131]
# Out:
# "'1902/01/31''46:57:50.28'"

# %%
events_jdf['Time (epoch)'] = pd.to_datetime(events_jdf['Time (epoch)'])
events_jdf['Time (epoch)']
# Out:
# 0     1970-01-01 00:00:01.319372776
# 1     1970-01-01 00:00:01.319592376
# 2     1970-01-01 00:00:01.320368639
# 3     1970-01-01 00:00:01.320610871
# 4     1970-01-01 00:00:01.320616859
#                    ...
# 435   1970-01-01 00:00:01.411301721
# 436   1970-01-01 00:00:01.415354286
# 437   1970-01-01 00:00:01.415608558
# 438   1970-01-01 00:00:01.412975672
# 439   1970-01-01 00:00:01.413879766
# Name: Time (epoch), Length: 440, dtype: datetime64[ns]

# %%
time = pd.to_datetime(events_cascadia['time'][0])

# %%
type(time)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ### Comparing to Morton's Catalog

# %%
# Read Morton's catalog
events_morton = pd.read_csv('ds01.csv')

# %%
events_morton[0:5]
# Out:
#    CI YEAR       TSTRING    YEAR  MONTH   DAY  HOUR  MINUTE  SECOND      LAT  \
# 0      1.0  2.011073e+13  2011.0    7.0  26.0   1.0     2.0    7.37  47.3217
# 1      1.0  2.011073e+13  2011.0    7.0  26.0   1.0     2.0    7.72  44.2888
# 2      1.0  2.011073e+13  2011.0    7.0  26.0   1.0     2.0    8.56  44.3017
# 3      1.0  2.011073e+13  2011.0    7.0  26.0   7.0    31.0    2.17  48.2635
# 4      1.0  2.011073e+13  2011.0    7.0  26.0   9.0    50.0   27.63  48.3032
#
#         LON  ...  max az gap  dist to nearest stn  tt RMS   ERH   ERZ  STRIKE  \
# 0 -123.2708  ...       166.0                 27.4    0.19   0.8   1.2     NaN
# 1 -124.3340  ...       332.0                163.8    0.06  13.1   3.2     NaN
# 2 -124.3180  ...       316.0                131.1    0.50  35.4  22.2     NaN
# 3 -124.9298  ...       205.0                 44.4    0.77   3.5   6.4     NaN
# 4 -124.9157  ...       199.0                 46.1    0.94   4.0   6.9     NaN
#
#    DIP  RAKE  PLATE DESIGNATION  TEMPLATE EVENT?
# 0  NaN   NaN          Interface          Catalog
# 1  NaN   NaN        Upper Plate              NaN
# 2  NaN   NaN        Upper Plate              NaN
# 3  NaN   NaN        Upper Plate              NaN
# 4  NaN   NaN        Upper Plate                T
#
# [5 rows x 23 columns]

# %%
events_morton['datetime'] = events_morton.apply(lambda a: datetime.fromtimestamp(a['TSTRING']), axis = 1)
events_morton
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [238], in <module>
# ----> 1 events_morton['datetime'] = events_morton.apply(lambda a: datetime.fromtimestamp(a['TSTRING']), axis = 1)
#       2 events_morton
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Input In [238], in <lambda>(a)
# ----> 1 events_morton['datetime'] = events_morton.apply(lambda a: datetime.fromtimestamp(a['TSTRING']), axis = 1)
#       2 events_morton
#
# ValueError: year 639253 is out of range

# %%
events_morton
# Out:
#       CI YEAR       TSTRING    YEAR  MONTH   DAY  HOUR  MINUTE  SECOND  \
# 0         1.0  2.011073e+13  2011.0    7.0  26.0   1.0     2.0    7.37
# 1         1.0  2.011073e+13  2011.0    7.0  26.0   1.0     2.0    7.72
# 2         1.0  2.011073e+13  2011.0    7.0  26.0   1.0     2.0    8.56
# 3         1.0  2.011073e+13  2011.0    7.0  26.0   7.0    31.0    2.17
# 4         1.0  2.011073e+13  2011.0    7.0  26.0   9.0    50.0   27.63
# ...       ...           ...     ...    ...   ...   ...     ...     ...
# 5290      NaN           NaN     NaN    NaN   NaN   NaN     NaN     NaN
# 5291      NaN           NaN     NaN    NaN   NaN   NaN     NaN     NaN
# 5292      NaN           NaN     NaN    NaN   NaN   NaN     NaN     NaN
# 5293      NaN           NaN     NaN    NaN   NaN   NaN     NaN     NaN
# 5294      NaN           NaN     NaN    NaN   NaN   NaN     NaN     NaN
#
#           LAT       LON  ...  dist to nearest stn  tt RMS   ERH   ERZ  STRIKE  \
# 0     47.3217 -123.2708  ...                 27.4    0.19   0.8   1.2     NaN
# 1     44.2888 -124.3340  ...                163.8    0.06  13.1   3.2     NaN
# 2     44.3017 -124.3180  ...                131.1    0.50  35.4  22.2     NaN
# 3     48.2635 -124.9298  ...                 44.4    0.77   3.5   6.4     NaN
# 4     48.3032 -124.9157  ...                 46.1    0.94   4.0   6.9     NaN
# ...       ...       ...  ...                  ...     ...   ...   ...     ...
# 5290      NaN       NaN  ...                  NaN     NaN   NaN   NaN     NaN
# 5291      NaN       NaN  ...                  NaN     NaN   NaN   NaN     NaN
# 5292      NaN       NaN  ...                  NaN     NaN   NaN   NaN     NaN
# 5293      NaN       NaN  ...                  NaN     NaN   NaN   NaN     NaN
# 5294      NaN       NaN  ...                  NaN     NaN   NaN   NaN     NaN
#
#       DIP  RAKE  PLATE DESIGNATION  TEMPLATE EVENT?  \
# 0     NaN   NaN          Interface          Catalog
# 1     NaN   NaN        Upper Plate              NaN
# 2     NaN   NaN        Upper Plate              NaN
# 3     NaN   NaN        Upper Plate              NaN
# 4     NaN   NaN        Upper Plate                T
# ...   ...   ...                ...              ...
# 5290  NaN   NaN                NaN              NaN
# 5291  NaN   NaN                NaN              NaN
# 5292  NaN   NaN                NaN              NaN
# 5293  NaN   NaN                NaN              NaN
# 5294  NaN   NaN                NaN              NaN
#
#                           datetime
# 0    1970-01-01 05:35:10.726010207
# 1    1970-01-01 05:35:10.726010207
# 2    1970-01-01 05:35:10.726010208
# 3    1970-01-01 05:35:10.726073102
# 4    1970-01-01 05:35:10.726095027
# ...                            ...
# 5290                           NaT
# 5291                           NaT
# 5292                           NaT
# 5293                           NaT
# 5294                           NaT
#
# [5295 rows x 24 columns]
