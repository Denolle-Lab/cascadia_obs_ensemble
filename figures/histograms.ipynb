# %% [markdown]
# # Make tables for the paper

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
method = 'reloc'
year = 'all_regions'
version = 'ver3'
# Load the catalogs 
df = pd.read_csv('../data/datasets_all_regions/origin_2010_2015_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv',index_col=0)

matched_events_mycatalog2morton= pd.read_csv(f'../data/datasets_{year}/matched_events_with_morton_mycatalog_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
unmatched_events_mycatalog2morton_and_anss= pd.read_csv(f'../data/datasets_{year}/new_events_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
# new_events_filtered = pd.read_csv(f'../data/datasets_{year}/new_events_filtered_{year}.csv')
unmatched_events_morton2mycatalog= pd.read_csv(f'../data/datasets_{year}/missing_events_from_mycatalog_morton_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
matched_events_morton2mycatalog= pd.read_csv(f'../data/datasets_{year}/matched_events_with_mycatalog_morton_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
unmatched_events_anss2mycatalog = pd.read_csv(f'../data/datasets_{year}/missing_events_from_mycatalog_anss_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
matched_events_mycatalog2anss= pd.read_csv(f'../data/datasets_{year}/matched_events_with_anss_mycatalog_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
matched_events_anss2mycatalog= pd.read_csv(f'../data/datasets_{year}/matched_events_with_mycatalog_anss_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')

# %%
print('matched_events_mycatalog2morton',len(matched_events_mycatalog2morton))
print('un')
# Out:
# matched_events_mycatalog2morton 3109

# %% [markdown]
# ## Make histograms for the matching events

# %% [markdown]
# ### Number of P and S picks

# %%
bins = np.linspace(df['nass'].min(), df['nass'].max(), 100)

plt.figure()
plt.hist(df['nass'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['nass'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['nass'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P and S Picks')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_nass_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.png')

# %%
bins = np.linspace(df['nass'].min(), df['nass'].max(), 100)

plt.figure()
plt.hist(df['nass'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['nass'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['nass'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P and S Picks')
plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_nass_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %% [markdown]
# ### Number of P picks

# %%
bins = np.linspace(df['p_picks'].min(), df['p_picks'].max(), 100)

plt.figure()
plt.hist(df['p_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['p_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['p_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P Picks')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_p_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_.png')

# %%
bins = np.linspace(df['p_picks'].min(), df['p_picks'].max(), 100)

plt.figure()
plt.hist(df['p_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['p_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['p_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P Picks')
plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_p_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %% [markdown]
# ### Number of S picks

# %%
bins = np.linspace(df['s_picks'].min(), df['s_picks'].max(), 100)

plt.figure()
plt.hist(df['s_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['s_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['s_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of S Picks')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_s_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_.png')

# %%
bins = np.linspace(df['s_picks'].min(), df['s_picks'].max(), 100)

plt.figure()
plt.hist(df['s_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['s_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['s_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of S Picks')
plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_s_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %% [markdown]
# ### RMS

# %%
bins = np.linspace(df['rms'].min(), df['rms'].max(), 100)

plt.figure()
plt.hist(df['rms'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['rms'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['rms'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('RMS')
# plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_rms_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.png')

# %%
bins = np.linspace(df['rms'].min(), df['rms'].max(), 100)

plt.figure()
plt.hist(df['rms'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['rms'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['rms'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('RMS')
plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_rms_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %% [markdown]
# ## Make histograms for the unmatching events

# %% [markdown]
# ### Make dataframes for the unmatching events

# %%
unmatched_events_mycatalog2morton = df[~df['orid'].isin(matched_events_mycatalog2morton['orid'].drop_duplicates())]
unmatched_events_mycatalog2anss = df[~df['orid'].isin(matched_events_mycatalog2anss['orid'].drop_duplicates())]

# %%
len(unmatched_events_mycatalog2morton)
# Out:
# 27925

# %%
len(matched_events_mycatalog2morton['orid'].drop_duplicates())
# Out:
# 3095

# %%
len(matched_events_mycatalog2morton['orid'])
# Out:
# 3109

# %%
len(unmatched_events_mycatalog2morton)+len(matched_events_mycatalog2morton.drop_duplicates(subset='orid'))
# Out:
# 31020

# %%
len(unmatched_events_mycatalog2morton)
# Out:
# 27925

# %%
len(matched_events_mycatalog2morton)
# Out:
# 3109

# %%
len(df)
# Out:
# 31020

# %%
duplicates = df[df['orid'].duplicated(keep=False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [lat, lon, depth, time, orid, nass, p_picks, s_picks, rms, nsphz, gap, algorithm, id_Morton, dist, dt, NonDimDist]
# Index: []

# %%
duplicates = matched_events_mycatalog2morton[matched_events_mycatalog2morton['orid'].duplicated(keep=False)]
print(duplicates)
# Out:
#       Unnamed: 0  latitude  longitude   depth          time   orid  nass  \
# 6              6  48.37994 -124.62987  28.566  1.312364e+09  13409    12
# 7              7  48.37994 -124.62987  28.566  1.312364e+09  13409    12
# 8              8  48.37994 -124.62987  28.566  1.312364e+09  13409    12
# 137          137  44.34098 -124.51877  10.794  1.337284e+09  21676    51
# 138          138  44.34098 -124.51877  10.794  1.337284e+09  21676    51
# 139          139  44.33286 -124.50797   9.281  1.337285e+09  21677    16
# 140          140  44.33286 -124.50797   9.281  1.337285e+09  21677    16
# 604          604  44.61739 -124.36422  13.322  1.356338e+09  30377    25
# 605          605  44.61739 -124.36422  13.322  1.356338e+09  30377    25
# 606          606  44.61739 -124.36422  13.322  1.356338e+09  30377    25
# 727          727  44.46544 -124.64085  11.007  1.359103e+09  31550    27
# 728          728  44.46544 -124.64085  11.007  1.359103e+09  31550    27
# ...

# %%
duplicates = matched_events_mycatalog2anss[matched_events_mycatalog2anss['orid'].duplicated(keep=False)]
print(duplicates)
# Out:
#       Unnamed: 0  latitude  longitude   depth          time   orid  nass  \
# 268          268  40.35405 -124.66714  13.839  1.267865e+09   2006    16
# 269          269  40.35405 -124.66714  13.839  1.267865e+09   2006    16
# 363          363  46.93749 -121.89510   5.819  1.270478e+09   2646    31
# 364          364  46.93749 -121.89510   5.819  1.270478e+09   2646    31
# 365          365  46.93749 -121.89510   5.819  1.270478e+09   2646    31
# ...          ...       ...        ...     ...           ...    ...   ...
# 8242        8242  48.60540 -123.01584  16.948  1.429692e+09  61020    14
# 8243        8243  48.60540 -123.01584  16.948  1.429692e+09  61020    14
# 8368        8368  45.35098 -121.78383  31.331  1.431849e+09  62310    19
# 8369        8369  45.35098 -121.78383  31.331  1.431849e+09  62310    19
# 8370        8370  45.35098 -121.78383  31.331  1.431849e+09  62310    19
#
#       p_picks  s_picks    rms  nsphz         gap algorithm  id_Morton  \
# ...

# %%
len(unmatched_events_mycatalog2anss)+len(matched_events_mycatalog2anss.drop_duplicates(subset='orid'))
# Out:
# 31020

# %% [markdown]
# ### Number of P and S picks

# %%
bins = np.linspace(df['nass'].min(), df['nass'].max(), 100)

plt.figure()
plt.hist(df['nass'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['nass'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['nass'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('Number of P and S Picks')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_nass_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.png')

# %%
bins = np.linspace(df['nass'].min(), df['nass'].max(), 100)

plt.figure()
plt.hist(df['nass'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['nass'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['nass'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('Number of P and S Picks')
plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_nass_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %%
bins = np.linspace(df['p_picks'].min(), df['p_picks'].max(), 100)

plt.figure()
plt.hist(df['p_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['p_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['p_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('Number of P Picks')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_p_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_.png')

# %%
bins = np.linspace(df['p_picks'].min(), df['p_picks'].max(), 100)

plt.figure()
plt.hist(df['p_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['p_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['p_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('Number of P Picks')
plt.legend(loc='upper right')
plt.yscale('log')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_p_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %%
bins = np.linspace(df['s_picks'].min(), df['s_picks'].max(), 100)

plt.figure()
plt.hist(df['s_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['s_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['s_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('Number of S Picks')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_s_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_.png')

# %%
bins = np.linspace(df['s_picks'].min(), df['s_picks'].max(), 100)

plt.figure()
plt.hist(df['s_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['s_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['s_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('Number of S Picks')
plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_s_picks_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %%
bins = np.linspace(df['rms'].min(), df['rms'].max(), 100)

plt.figure()
plt.hist(df['rms'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['rms'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['rms'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('RMS')
# plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_rms_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.png')

# %%
bins = np.linspace(df['rms'].min(), df['rms'].max(), 100)

plt.figure()
plt.hist(df['rms'],bins=bins, alpha=0.5, label='All events')
plt.hist(unmatched_events_mycatalog2morton['rms'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.hist(unmatched_events_mycatalog2anss['rms'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.title('RMS')
plt.yscale('log')
plt.legend(loc='upper right')
plt.savefig(f'../data/datasets_{year}/hist_unmatched_rms_{method}_cog_morton_{version}_p_4_s_4_rms_2_5_ylog.png')

# %%
events = pd.read_csv(f'/home/hbito/cascadia_obs_ensemble_backup/data/datasets_{year}/Cascadia_relocated_catalog_ver_3.csv')

picks = pd.read_csv('/home/hbito/cascadia_obs_ensemble_backup/data/datasets_all_regions/Cascadia_relocated_catalog_picks_ver_3.csv')
events = events.rename(columns={' Event ID ':'idx',' Origin Time (UTC)':'datetime','Latitude':'latitude',' Longitude':'longitude',' Depth (km)':'depth',' Num. P':'Num. P', ' Num. S':'Num. S',' RMS Residual (s)':'RMS Residual (s)',' Detection Value': 'Detection Value',' Std. (km)':'Std. (km)'})
# picks = picks.rename(columns={' Event ID':'idx',' Station Name':'station', ' Phase Type':'phase',' Pick ID ':'arid','Pick Time (UTC)':'time_pick',' Residual (s)':'timeres'})
events['datetime'] = pd.to_datetime(events['datetime'], utc=True)
events
# Out:
#        latitude  longitude   depth                         datetime  \
# 0      47.22533 -122.16895  56.111 2010-01-01 00:15:17.262282+00:00
# 1      48.19518 -121.77276   3.820 2010-01-01 00:16:49.375360+00:00
# 2      47.86208 -122.09903  17.799 2010-01-01 07:18:03.689209+00:00
# 3      47.96435 -122.91906  21.286 2010-01-01 08:51:56.371091+00:00
# 4      45.87262 -122.19180   9.822 2010-01-01 16:12:43.838660+00:00
# ...         ...        ...     ...                              ...
# 63882  40.59439 -124.42438  19.741 2015-06-23 22:11:15.735288+00:00
# 63883  40.54636 -127.10076  26.165 2015-06-23 22:45:51.899203+00:00
# 63884  49.74167 -124.58578   5.274 2015-06-23 23:03:49.638010+00:00
# 63885  40.64363 -125.36531   1.891 2015-06-23 23:12:21.788775+00:00
# 63886  43.37085 -127.35251   5.915 2015-06-23 23:18:18.841147+00:00
#
#         Uncertainity (km)   Horizontal Uncertainity (km)  \
# 0                  10.223                         10.216
# ...

# %%
df_origin = pd.read_csv('/home/hbito/cascadia_obs_ensemble_backup/data/datasets_all_regions/origin_2010_2015_reloc_cog_morton_ver3.csv')
df_origin
# Out:
#        Unnamed: 0       lat        lon   depth          time   orid  nass  \
# 0               0  47.22533 -122.16895  56.111  1.262305e+09      0     7
# 1               1  48.19518 -121.77276   3.820  1.262305e+09      1    55
# 2               2  47.86208 -122.09903  17.799  1.262330e+09      2    28
# 3               3  47.96435 -122.91906  21.286  1.262336e+09      3    20
# 4               4  45.87262 -122.19180   9.822  1.262362e+09      4    39
# ...           ...       ...        ...     ...           ...    ...   ...
# 63882       63882  40.59439 -124.42438  19.741  1.435097e+09  63882    23
# 63883       63883  40.54636 -127.10076  26.165  1.435100e+09  63883    12
# 63884       63884  49.74167 -124.58578   5.274  1.435101e+09  63884    13
# 63885       63885  40.64363 -125.36531   1.891  1.435101e+09  63885     8
# 63886       63886  43.37085 -127.35251   5.915  1.435101e+09  63886     9
#
#        p_picks  s_picks    rms  nsphz         gap algorithm  id_Morton  \
# ...
