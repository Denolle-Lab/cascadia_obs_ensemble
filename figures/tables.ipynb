# %% [markdown]
# # Make tables for the paper

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
method = 'reloc'
year = 'all_regions'
version = 'ver3'
# Load the catalogs 
df = pd.read_csv('../data/datasets_all_regions/origin_2010_2015_reloc_cog_morton_ver3_p_4_s_4_rms_2_5.csv',index_col=0)

matched_events_mycatalog2morton= pd.read_csv(f'../data/datasets_{year}/matched_events_with_morton_mycatalog_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
unmatched_events_mycatalog2morton_and_anss= pd.read_csv(f'../data/datasets_{year}/new_events_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
# new_events_filtered = pd.read_csv(f'../data/datasets_{year}/new_events_filtered_{year}.csv')
unmatched_events_morton2mycatalog= pd.read_csv(f'../data/datasets_{year}/missing_events_from_mycatalog_morton_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
matched_events_morton2mycatalog= pd.read_csv(f'../data/datasets_{year}/matched_events_with_mycatalog_morton_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
unmatched_events_anss2mycatalog = pd.read_csv(f'../data/datasets_{year}/missing_events_from_mycatalog_anss_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
matched_events_mycatalog2anss= pd.read_csv(f'../data/datasets_{year}/matched_events_with_anss_mycatalog_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')
matched_events_anss2mycatalog= pd.read_csv(f'../data/datasets_{year}/matched_events_with_mycatalog_anss_{method}_cog_morton_{version}_p_4_s_4_rms_2_5.csv')

# %%
bins = np.linspace(df['nass'].min(), df['nass'].max(), 100)

plt.figure()
plt.hist(df['nass'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['nass'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['nass'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P and S Picks')
plt.legend(loc='upper right')

# %%
bins = np.linspace(df['nass'].min(), df['nass'].max(), 100)

plt.figure()
plt.hist(df['nass'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['nass'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['nass'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P and S Picks')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
df
# Out:
#             lat        lon   depth          time   orid  nass  p_picks  \
# 27593  40.46402 -124.63921  21.674  1.350339e+09  27593    33       14
# 33313  40.46453 -124.64685  19.221  1.363883e+09  33313    23        9
# 44330  49.75784 -123.42677   4.296  1.395439e+09  44330    10        5
# 42581  49.04914 -122.09718  13.249  1.393710e+09  42581    26       16
# 36355  40.39732 -124.58839  16.076  1.371875e+09  36355    22        9
# ...         ...        ...     ...           ...    ...   ...      ...
# 1542   46.14740 -122.14032  44.614  1.266069e+09   1542    10        5
# 8390   48.79538 -123.26321  -0.782  1.293723e+09   8390    10        5
# 8590   48.57995 -123.03222  13.812  1.294554e+09   8590    10        5
# 41383  46.32146 -122.37012  13.638  1.390093e+09  41383    10        5
# 774    48.46791 -123.44927  20.314  1.264059e+09    774    10        5
#
#        s_picks    rms  nsphz         gap algorithm  id_Morton      dist  \
# ...

# %%
bins = np.linspace(df['p_picks'].min(), df['p_picks'].max(), 100)

plt.figure()
plt.hist(df['p_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['p_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['p_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P Picks')
plt.legend(loc='upper right')

# %%
bins = np.linspace(df['p_picks'].min(), df['p_picks'].max(), 100)

plt.figure()
plt.hist(df['p_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['p_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['p_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of P Picks')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
bins = np.linspace(df['s_picks'].min(), df['s_picks'].max(), 100)

plt.figure()
plt.hist(df['s_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['s_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['s_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of S Picks')
plt.legend(loc='upper right')

# %%
bins = np.linspace(df['s_picks'].min(), df['s_picks'].max(), 100)

plt.figure()
plt.hist(df['s_picks'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['s_picks'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['s_picks'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('Number of S Picks')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
bins = np.linspace(df['rms'].min(), df['rms'].max(), 100)

plt.figure()
plt.hist(df['rms'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['rms'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['rms'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('RMS')
# plt.yscale('log')
plt.legend(loc='upper right')

# %%
bins = np.linspace(df['rms'].min(), df['rms'].max(), 100)

plt.figure()
plt.hist(df['rms'],bins=bins, alpha=0.5, label='All events')
plt.hist(matched_events_mycatalog2anss['rms'],bins=bins, alpha=0.5, label='Matched events to ANSS')
plt.hist(matched_events_mycatalog2morton['rms'],bins=bins, alpha=0.5, label='Matched events to Morton-2023')
plt.title('RMS')
plt.yscale('log')
plt.legend(loc='upper right')
