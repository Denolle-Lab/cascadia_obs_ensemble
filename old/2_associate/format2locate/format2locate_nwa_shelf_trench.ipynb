# %% [markdown]
# ## Notebook for formatting data frames for location with Hypoinverse
# Source:
# - https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file
# - https://www.usgs.gov/software/hypoinverse-earthquake-location
# - https://chatgpt.com/c/67491af9-aaf8-800c-82e9-1033e094d8d0
# - https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2017JB014966

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from pnwstore.mseed import WaveformClient
from obspy import UTCDateTime
from obspy.core.stream import Stream
from obspy.clients.fdsn import Client
from tqdm import tqdm
import datetime

# %% [markdown]
# ### 1.3 Create a CSV file for picks for the association

# %% [markdown]
# ### Format the files for HypoInverse and HypoDD
# References: https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file

# %% [markdown]
# ### Format the station files

# %%
region = 'nwa_shelf_trench'
df = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)

# %%
TOFB = df[df['station_code']=='TOFB']

# %%
TOFB['station_network_code'].unique()
# Out:
# array([], dtype=object)

# %%
from obspy import read_inventory
from collections import defaultdict
import pandas as pd

client2 = Client("IRIS")
networks = pd.read_csv("../data/networks.csv")
networks = ','.join(list(networks['networks']))
starttime = UTCDateTime(year=2011, month=1, day=1)
endtime = UTCDateTime(year=2016, month=1, day=1)
inv = [] 
# inv = read_inventory("./stations/*.xml")
station_locs = defaultdict(dict)
# stations=inv


for station in df['station_code'].unique():
    inv += client2.get_stations(network=networks,
                                    station=station, channel="?H?", 
                                    starttime=starttime, endtime=endtime, level="response")
stations=inv

print(len(stations))

for network in stations:
    print(network)
    for station in network:
        print(station)
        has_HH = bool(station.select(channel="HH?"))
        has_BH = bool(station.select(channel="BH?"))

        # Apply selection logic based on channel presence
        if has_HH and has_BH:
            # If both HH and BH channels are present, select only HH
            selected_station = station.select(channel="HH?")
        elif has_HH:
            # If only HH channels are present
            selected_station = station.select(channel="HH?")
        elif has_BH:
            # If only BH channels are present
            selected_station = station.select(channel="BH?")

        for chn in selected_station:
            print('This is chn: ', chn)
            sid = f"{network.code}.{station.code}.{chn.location_code}.{chn.code[:-1]}"
            if sid in station_locs:
                station_locs[sid]["component"] += f",{chn.code[-1]}"
                station_locs[sid]["response"] += f",{chn.response.instrument_sensitivity.value:.2f}"
            else:
                component = f"{chn.code[-1]}"
                response = f"{chn.response.instrument_sensitivity.value:.2f}"
                dtype = chn.response.instrument_sensitivity.input_units.lower()
                tmp_dict = {}
                tmp_dict["longitude"], tmp_dict["latitude"], tmp_dict["elevation(m)"] = (
                    chn.longitude,
                    chn.latitude,
                    chn.elevation,
                )
                tmp_dict["component"], tmp_dict["response"], tmp_dict["unit"] = component, response, dtype
                station_locs[sid] = tmp_dict
            if station_locs[sid]["component"]=='Z':
                station_locs[sid]["response"]= f"0,0,"+station_locs[sid]["response"]
            elif station_locs[sid]["component"]=='N,Z':
                station_locs[sid]["response"]= f"0,"+station_locs[sid]["response"]
station_locs = pd.DataFrame.from_dict(station_locs, orient='index')
station_locs["id"] = station_locs.index
station_locs = station_locs.rename_axis('station').reset_index()
station_locs.to_csv(f"./stations_{region}.csv",sep='\t')
station_locs
# Out:
# 27
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W09 (WHOI OBS ID S84)
# 		Channels (6):
# 			7A.W09..BHZ, 7A.W09..BH1, 7A.W09..BH2, 7A.W09..LHZ, 7A.W09..LH1,
# 			7A.W09..LH2
# Station W09 (WHOI OBS ID S84)
# 	Station Code: W09
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-15T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.6880, Longitude: -126.5770, Elevation: -1156.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-15 to 2011-06-28
# 	    ..LH[Z21]     1.0 Hz  2010-07-15 to 2011-06-28
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Latitude: 48.6880, Longitude: -126.5770, Elevation: -1156.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Latitude: 48.6880, Longitude: -126.5770, Elevation: -1156.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Latitude: 48.6880, Longitude: -126.5770, Elevation: -1156.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W01 (WHOI OBS ID S85)
# 		Channels (6):
# 			7A.W01..BHZ, 7A.W01..BH1, 7A.W01..BH2, 7A.W01..LHZ, 7A.W01..LH1,
# 			7A.W01..LH2
# Station W01 (WHOI OBS ID S85)
# 	Station Code: W01
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-13T00:00:00.000000Z - 2011-06-24T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.0797, Longitude: -126.3425, Elevation: -1697.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-13 to 2011-06-24
# 	    ..LH[Z21]     1.0 Hz  2010-07-13 to 2011-06-24
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-13T00:00:00.000000Z - 2011-06-24T23:59:59.000000Z
# 	Latitude: 48.0797, Longitude: -126.3425, Elevation: -1697.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-13T00:00:00.000000Z - 2011-06-24T23:59:59.000000Z
# 	Latitude: 48.0797, Longitude: -126.3425, Elevation: -1697.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-13T00:00:00.000000Z - 2011-06-24T23:59:59.000000Z
# 	Latitude: 48.0797, Longitude: -126.3425, Elevation: -1697.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W02 (WHOI OBS ID S83)
# 		Channels (6):
# 			7A.W02..BHZ, 7A.W02..BH1, 7A.W02..BH2, 7A.W02..LHZ, 7A.W02..LH1,
# 			7A.W02..LH2
# Station W02 (WHOI OBS ID S83)
# 	Station Code: W02
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-13T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.2593, Longitude: -126.4968, Elevation: -2133.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-13 to 2011-06-25
# 	    ..LH[Z21]     1.0 Hz  2010-07-13 to 2011-06-25
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-13T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.2593, Longitude: -126.4968, Elevation: -2133.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-13T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.2593, Longitude: -126.4968, Elevation: -2133.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-13T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.2593, Longitude: -126.4968, Elevation: -2133.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W07 (WHOI OBS ID S82)
# 		Channels (6):
# 			7A.W07..BHZ, 7A.W07..BH1, 7A.W07..BH2, 7A.W07..LHZ, 7A.W07..LH1,
# 			7A.W07..LH2
# Station W07 (WHOI OBS ID S82)
# 	Station Code: W07
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.3747, Longitude: -126.2822, Elevation: -1152.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-15 to 2011-06-25
# 	    ..LH[Z21]     1.0 Hz  2010-07-15 to 2011-06-25
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.3747, Longitude: -126.2822, Elevation: -1152.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.3747, Longitude: -126.2822, Elevation: -1152.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.3747, Longitude: -126.2822, Elevation: -1152.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W03 (WHOI OBS ID S86)
# 		Channels (6):
# 			7A.W03..BHZ, 7A.W03..BH1, 7A.W03..BH2, 7A.W03..LHZ, 7A.W03..LH1,
# 			7A.W03..LH2
# Station W03 (WHOI OBS ID S86)
# 	Station Code: W03
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-14T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.3875, Longitude: -126.7287, Elevation: -2489.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-14 to 2011-06-26
# 	    ..LH[Z21]     1.0 Hz  2010-07-14 to 2011-06-26
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Latitude: 48.3875, Longitude: -126.7287, Elevation: -2489.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Latitude: 48.3875, Longitude: -126.7287, Elevation: -2489.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Latitude: 48.3875, Longitude: -126.7287, Elevation: -2489.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W10 (WHOI OBS ID S88)
# 		Channels (6):
# 			7A.W10..BHZ, 7A.W10..BH1, 7A.W10..BH2, 7A.W10..LHZ, 7A.W10..LH1,
# 			7A.W10..LH2
# Station W10 (WHOI OBS ID S88)
# 	Station Code: W10
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-14T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.7879, Longitude: -126.7022, Elevation: -1070.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-14 to 2011-06-28
# 	    ..LH[Z21]     1.0 Hz  2010-07-14 to 2011-06-28
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Latitude: 48.7879, Longitude: -126.7022, Elevation: -1070.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Latitude: 48.7879, Longitude: -126.7022, Elevation: -1070.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-28T23:59:59.000000Z
# 	Latitude: 48.7879, Longitude: -126.7022, Elevation: -1070.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W08 (WHOI OBS ID S81)
# 		Channels (6):
# 			7A.W08..BHZ, 7A.W08..BH1, 7A.W08..BH2, 7A.W08..LHZ, 7A.W08..LH1,
# 			7A.W08..LH2
# Station W08 (WHOI OBS ID S81)
# 	Station Code: W08
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-15T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.5645, Longitude: -126.4011, Elevation: -1028.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-15 to 2011-06-26
# 	    ..LH[Z21]     1.0 Hz  2010-07-15 to 2011-06-26
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Latitude: 48.5645, Longitude: -126.4011, Elevation: -1028.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Latitude: 48.5645, Longitude: -126.4011, Elevation: -1028.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-26T23:59:59.000000Z
# 	Latitude: 48.5645, Longitude: -126.4011, Elevation: -1028.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W04 (WHOI OBS ID S89)
# 		Channels (6):
# 			7A.W04..BHZ, 7A.W04..BH1, 7A.W04..BH2, 7A.W04..LHZ, 7A.W04..LH1,
# 			7A.W04..LH2
# Station W04 (WHOI OBS ID S89)
# 	Station Code: W04
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-14T00:00:00.000000Z - 2011-06-27T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.5317, Longitude: -126.8908, Elevation: -2319.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-14 to 2011-06-27
# 	    ..LH[Z21]     1.0 Hz  2010-07-14 to 2011-06-27
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-27T23:59:59.000000Z
# 	Latitude: 48.5317, Longitude: -126.8908, Elevation: -2319.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-27T23:59:59.000000Z
# 	Latitude: 48.5317, Longitude: -126.8908, Elevation: -2319.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-14T00:00:00.000000Z - 2011-06-27T23:59:59.000000Z
# 	Latitude: 48.5317, Longitude: -126.8908, Elevation: -2319.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network 7A (Cascadia- Keck ())
# 	Station Count: 1/10 (Selected/Total)
# 	2010-01-01T00:00:00.000000Z - 2011-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7A.W06 (WHOI OBS ID S80)
# 		Channels (6):
# 			7A.W06..BHZ, 7A.W06..BH1, 7A.W06..BH2, 7A.W06..LHZ, 7A.W06..LH1,
# 			7A.W06..LH2
# Station W06 (WHOI OBS ID S80)
# 	Station Code: W06
# 	Channel Count: 6/45 (Selected/Total)
# 	2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.1827, Longitude: -126.0647, Elevation: -1001.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2010-07-15 to 2011-06-25
# 	    ..LH[Z21]     1.0 Hz  2010-07-15 to 2011-06-25
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.1827, Longitude: -126.0647, Elevation: -1001.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.1827, Longitude: -126.0647, Elevation: -1001.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2010-07-15T00:00:00.000000Z - 2011-06-25T23:59:59.000000Z
# 	Latitude: 48.1827, Longitude: -126.0647, Elevation: -1001.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Guralp CMG3T_120sec WHOI OBSIP/Quanterra Q330 Line)
# 	Response information available
# Network NV (NEPTUNE Canada ())
# 	Station Count: 1/14 (Selected/Total)
# 	2009-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			NV.NC89 (Clayoquot Slope, Bullseye (ODP 1089))
# 		Channels (15):
# 			NV.NC89..HHZ (2x), NV.NC89..HHN (2x), NV.NC89..HHE (2x),
# 			NV.NC89..LHZ, NV.NC89..LHN, NV.NC89..LHE, NV.NC89..MHZ (2x),
# 			NV.NC89..MHN (2x), NV.NC89..MHE (2x)
# Station NC89 (Clayoquot Slope, Bullseye (ODP 1089))
# 	Station Code: NC89
# 	Channel Count: 15/70 (Selected/Total)
# 	2009-09-17T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 48.6705, Longitude: -126.8488, Elevation: -1258.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   200.0 Hz  2013-03-01 to None
# 	    ..HH[ZNE]   100.0 Hz  2010-09-10 to 2013-03-01
# 	    ..MH[ZNE]     8.0 Hz  2013-03-01 to None
# 	    ..MH[ZNE]     1.0 Hz  2010-09-10 to 2013-03-01
# 	    ..LH[ZNE]     1.0 Hz  2010-09-10 to 2013-03-01
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2010-09-10T22:51:30.000000Z - 2013-03-01T22:30:59.000000Z
# 	Latitude: 48.6705, Longitude: -126.8488, Elevation: -1256.0 m, Local Depth: 0.0 m
# 	Azimuth: 102.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2013-03-01T22:31:00.000000Z - --
# 	Latitude: 48.6705, Longitude: -126.8488, Elevation: -1256.0 m, Local Depth: 0.0 m
# 	Azimuth: 102.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2010-09-10T22:51:30.000000Z - 2013-03-01T22:30:59.000000Z
# 	Latitude: 48.6705, Longitude: -126.8488, Elevation: -1256.0 m, Local Depth: 0.0 m
# 	Azimuth: 12.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2013-03-01T22:31:00.000000Z - --
# 	Latitude: 48.6705, Longitude: -126.8488, Elevation: -1256.0 m, Local Depth: 0.0 m
# 	Azimuth: 12.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2010-09-10T22:51:30.000000Z - 2013-03-01T22:30:59.000000Z
# 	Latitude: 48.6705, Longitude: -126.8488, Elevation: -1256.0 m, Local Depth: 0.0 m
# 	Azimuth: 12.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-03-01T22:31:00.000000Z - --
# 	Latitude: 48.6705, Longitude: -126.8488, Elevation: -1256.0 m, Local Depth: 0.0 m
# 	Azimuth: 12.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# Network NV (NEPTUNE Canada ())
# 	Station Count: 1/14 (Selected/Total)
# 	2009-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			NV.NCBC (Barkley Canyon)
# 		Channels (15):
# 			NV.NCBC..EHZ, NV.NCBC..EHN, NV.NCBC..EHE, NV.NCBC..HHZ (2x),
# 			NV.NCBC..HHN (2x), NV.NCBC..HHE (2x), NV.NCBC..LHZ, NV.NCBC..LHN,
# 			NV.NCBC..LHE, NV.NCBC..MHZ, NV.NCBC..MHN, NV.NCBC..MHE
# Station NCBC (Barkley Canyon)
# 	Station Code: NCBC
# 	Channel Count: 15/76 (Selected/Total)
# 	2009-09-07T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 48.4275, Longitude: -126.1752, Elevation: -398.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   200.0 Hz  2013-03-01 to None
# 	    ..EH[ZNE]   100.0 Hz  2010-10-02 to 2011-09-13
# 	    ..HH[ZNE]   100.0 Hz  2010-09-11 to 2013-03-01
# 	    ..MH[ZNE]     8.0 Hz  2013-03-01 to None
# 	    ..LH[ZNE]     1.0 Hz  2010-09-11 to 2013-03-01
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2010-09-11T01:15:00.000000Z - 2013-03-01T19:59:59.000000Z
# 	Latitude: 48.4275, Longitude: -126.1752, Elevation: -398.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.70 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2013-03-01T20:00:00.000000Z - --
# 	Latitude: 48.4275, Longitude: -126.1752, Elevation: -398.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.70 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2010-09-11T01:15:00.000000Z - 2013-03-01T19:59:59.000000Z
# 	Latitude: 48.4275, Longitude: -126.1752, Elevation: -398.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.70 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2013-03-01T20:00:00.000000Z - --
# 	Latitude: 48.4275, Longitude: -126.1752, Elevation: -398.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.70 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2010-09-11T01:15:00.000000Z - 2013-03-01T19:59:59.000000Z
# 	Latitude: 48.4275, Longitude: -126.1752, Elevation: -398.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.70 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-03-01T20:00:00.000000Z - --
# 	Latitude: 48.4275, Longitude: -126.1752, Elevation: -398.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.70 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 200.00 Hz
# 	Sensor (Description): None (Guralp CMG-1T 360s/Guralp CMG-DM24 Datalogger)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J65A (SIO OBS ID J65A)
# 		Channels (3):
# 			7D.J65A..BHZ, 7D.J65A..BH1, 7D.J65A..BH2
# Station J65A (SIO OBS ID J65A)
# 	Station Code: J65A
# 	Channel Count: 3/8 (Selected/Total)
# 	2011-10-17T00:00:00.000000Z - 2012-07-16T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.8913, Longitude: -125.1396, Elevation: -165.2 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-10-17 to 2012-07-16
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-10-17T22:31:00.000000Z - 2012-07-16T07:21:00.000000Z
# 	Latitude: 47.8913, Longitude: -125.1396, Elevation: -165.2 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-10-17T22:31:00.000000Z - 2012-07-16T07:21:00.000000Z
# 	Latitude: 47.8913, Longitude: -125.1396, Elevation: -165.2 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-17T22:31:00.000000Z - 2012-07-16T07:21:00.000000Z
# 	Latitude: 47.8913, Longitude: -125.1396, Elevation: -165.2 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J73A (SIO OBS ID J73A)
# 		Channels (3):
# 			7D.J73A..BHZ, 7D.J73A..BH1, 7D.J73A..BH2
# Station J73A (SIO OBS ID J73A)
# 	Station Code: J73A
# 	Channel Count: 3/4 (Selected/Total)
# 	2011-10-18T00:00:00.000000Z - 2012-07-17T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.7677, Longitude: -126.1925, Elevation: -143.3 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-10-18 to 2012-07-17
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-10-18T03:52:00.000000Z - 2012-07-17T00:59:00.000000Z
# 	Latitude: 48.7677, Longitude: -126.1925, Elevation: -143.3 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-10-18T03:52:00.000000Z - 2012-07-17T00:59:00.000000Z
# 	Latitude: 48.7677, Longitude: -126.1925, Elevation: -143.3 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-18T03:52:00.000000Z - 2012-07-17T00:59:00.000000Z
# 	Latitude: 48.7677, Longitude: -126.1925, Elevation: -143.3 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M01A (SIO OBS ID M01A)
# 		Channels (3):
# 			7D.M01A..BHZ, 7D.M01A..BH1, 7D.M01A..BH2
# Station M01A (SIO OBS ID M01A)
# 	Station Code: M01A
# 	Channel Count: 3/4 (Selected/Total)
# 	2011-10-18T00:00:00.000000Z - 2012-07-16T23:59:59.000000Z
# 	Access: open
# 	Latitude: 49.1504, Longitude: -126.7221, Elevation: -132.9 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2011-10-18 to 2012-07-16
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2011-10-18T04:54:00.000000Z - 2012-07-16T21:24:00.000000Z
# 	Latitude: 49.1504, Longitude: -126.7221, Elevation: -132.9 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2011-10-18T04:54:00.000000Z - 2012-07-16T21:24:00.000000Z
# 	Latitude: 49.1504, Longitude: -126.7221, Elevation: -132.9 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2011-10-18T04:54:00.000000Z - 2012-07-16T21:24:00.000000Z
# 	Latitude: 49.1504, Longitude: -126.7221, Elevation: -132.9 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M03A (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.M03A..HHZ, 7D.M03A..HH1, 7D.M03A..HH2
# Station M03A (LDEO OBS STANDARD DEEP)
# 	Station Code: M03A
# 	Channel Count: 3/8 (Selected/Total)
# 	2011-10-19T00:00:00.000000Z - 2012-07-11T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.8883, Longitude: -126.1040, Elevation: -1818.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-10-19 to 2012-07-11
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-10-19T14:55:32.000000Z - 2012-07-11T10:24:00.000000Z
# 	Latitude: 47.8883, Longitude: -126.1040, Elevation: -1818.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-10-19T14:55:32.000000Z - 2012-07-11T10:24:00.000000Z
# 	Latitude: 47.8883, Longitude: -126.1040, Elevation: -1818.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-10-19T14:55:32.000000Z - 2012-07-11T10:24:00.000000Z
# 	Latitude: 47.8883, Longitude: -126.1040, Elevation: -1818.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J58A (LDEO Standard Deep OBS)
# 		Channels (3):
# 			7D.J58A..HHZ, 7D.J58A..HH1, 7D.J58A..HH2
# Station J58A (LDEO Standard Deep OBS)
# 	Station Code: J58A
# 	Channel Count: 3/6 (Selected/Total)
# 	2011-10-18T00:00:00.000000Z - 2012-07-11T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2011-10-18 to 2012-07-11
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2011-10-18T09:03:00.000000Z - 2012-07-11T18:11:00.000000Z
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2011-10-18T09:03:00.000000Z - 2012-07-11T18:11:00.000000Z
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-10-18T09:03:00.000000Z - 2012-07-11T18:11:00.000000Z
# 	Latitude: 47.3188, Longitude: -125.5344, Elevation: -1511.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.J58A (Remsen, NY, USA)
# 		Channels (15):
# 			TA.J58A..BHZ, TA.J58A..BHN, TA.J58A..BHE, TA.J58A..HHZ,
# 			TA.J58A..HHN, TA.J58A..HHE, TA.J58A..LHZ, TA.J58A..LHN,
# 			TA.J58A..LHE, TA.J58A..UHZ, TA.J58A..UHN, TA.J58A..UHE,
# 			TA.J58A..VHZ, TA.J58A..VHN, TA.J58A..VHE
# Station J58A (Remsen, NY, USA)
# 	Station Code: J58A
# 	Channel Count: 15/43 (Selected/Total)
# 	2013-08-27T00:00:00.000000Z - 2015-08-10T23:59:59.000000Z
# 	Access: open
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2015-01-20 to 2015-08-10
# 	    ..BH[ZNE]    40.0 Hz  2013-08-27 to 2015-08-10
# 	    ..LH[ZNE]     1.0 Hz  2013-08-27 to 2015-08-10
# 	    ..VH[ZNE]     0.1 Hz  2013-08-27 to 2015-08-10
# 	    ..UH[ZNE]     0.0 Hz  2013-08-27 to 2015-08-10
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-08-10T15:11:16.000000Z
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-08-10T15:11:16.000000Z
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.40 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2015-01-20T18:00:00.000000Z - 2015-08-10T15:11:16.000000Z
# 	Latitude: 43.3603, Longitude: -75.2852, Elevation: 436.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Streckeisen STS-2 G3/Quanterra 330 Linear Phase Co)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M04C (SIO OBS ID M04C)
# 		Channels (3):
# 			7D.M04C..BHZ, 7D.M04C..BH1, 7D.M04C..BH2
# Station M04C (SIO OBS ID M04C)
# 	Station Code: M04C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-29
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T00:31:00.000000Z - 2014-05-29T21:05:12.000000Z
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T00:31:00.000000Z - 2014-05-29T21:05:12.000000Z
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T00:31:00.000000Z - 2014-05-29T21:05:12.000000Z
# 	Latitude: 47.5584, Longitude: -125.1923, Elevation: -570.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.M04C (Macdoel, CA, USA)
# 		Channels (30):
# 			TA.M04C..BHZ (2x), TA.M04C..BHN (2x), TA.M04C..BHE (2x),
# 			TA.M04C..HHZ (2x), TA.M04C..HHN (2x), TA.M04C..HHE (2x),
# 			TA.M04C..LHZ (2x), TA.M04C..LHN (2x), TA.M04C..LHE (2x),
# 			TA.M04C..UHZ (2x), TA.M04C..UHN (2x), TA.M04C..UHE (2x),
# 			TA.M04C..VHZ (2x), TA.M04C..VHN (2x), TA.M04C..VHE (2x)
# Station M04C (Macdoel, CA, USA)
# 	Station Code: M04C
# 	Channel Count: 30/207 (Selected/Total)
# 	2005-06-30T00:00:00.000000Z - 2016-04-25T23:59:59.000000Z
# 	Access: open
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2014-04-15 to 2016-04-25
# 	    ..HH[ZNE]   100.0 Hz  2011-05-02 to 2014-04-15
# 	    ..BH[ZNE]    40.0 Hz  2014-04-15 to 2016-04-25
# 	    ..BH[ZNE]    40.0 Hz  2009-10-11 to 2014-04-15
# 	    ..LH[ZNE]     1.0 Hz  2014-04-15 to 2016-04-25
# 	    ..LH[ZNE]     1.0 Hz  2009-10-11 to 2014-04-15
# 	    ..VH[ZNE]     0.1 Hz  2014-04-15 to 2016-04-25
# 	    ..VH[ZNE]     0.1 Hz  2009-10-11 to 2014-04-15
# 	    ..UH[ZNE]     0.0 Hz  2014-04-15 to 2016-04-25
# 	    ..UH[ZNE]     0.0 Hz  2009-10-11 to 2014-04-15
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2014-04-15T19:55:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2014-04-15T19:55:00.000000Z - 2016-04-25T21:25:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2014-04-15T19:55:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2014-04-15T19:55:00.000000Z - 2016-04-25T21:25:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2014-04-15T19:55:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2014-04-15T19:55:00.000000Z - 2016-04-25T21:25:00.000000Z
# 	Latitude: 41.7826, Longitude: -121.8393, Elevation: 1391.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J65C (SIO OBS ID J65C)
# 		Channels (3):
# 			7D.J65C..BHZ, 7D.J65C..BH1, 7D.J65C..BH2
# Station J65C (SIO OBS ID J65C)
# 	Station Code: J65C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.8913, Longitude: -125.1398, Elevation: -169.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-29
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T01:32:00.000000Z - 2014-05-29T23:45:59.000000Z
# 	Latitude: 47.8913, Longitude: -125.1398, Elevation: -169.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T01:32:00.000000Z - 2014-05-29T23:45:59.000000Z
# 	Latitude: 47.8913, Longitude: -125.1398, Elevation: -169.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T01:32:00.000000Z - 2014-05-29T23:45:59.000000Z
# 	Latitude: 47.8913, Longitude: -125.1398, Elevation: -169.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M02C (SIO OBS ID M02C)
# 		Channels (3):
# 			7D.M02C..BHZ, 7D.M02C..BH1, 7D.M02C..BH2
# Station M02C (SIO OBS ID M02C)
# 	Station Code: M02C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-30T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.3069, Longitude: -125.6012, Elevation: -141.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-30
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T15:48:00.000000Z - 2014-05-30T08:04:00.000000Z
# 	Latitude: 48.3069, Longitude: -125.6012, Elevation: -141.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T15:48:00.000000Z - 2014-05-30T08:04:00.000000Z
# 	Latitude: 48.3069, Longitude: -125.6012, Elevation: -141.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T15:48:00.000000Z - 2014-05-30T08:04:00.000000Z
# 	Latitude: 48.3069, Longitude: -125.6012, Elevation: -141.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.M02C (Callahan, CA, USA)
# 		Channels (15):
# 			TA.M02C..BHZ, TA.M02C..BHN, TA.M02C..BHE, TA.M02C..HHZ,
# 			TA.M02C..HHN, TA.M02C..HHE, TA.M02C..LHZ, TA.M02C..LHN,
# 			TA.M02C..LHE, TA.M02C..UHZ, TA.M02C..UHN, TA.M02C..UHE,
# 			TA.M02C..VHZ, TA.M02C..VHN, TA.M02C..VHE
# Station M02C (Callahan, CA, USA)
# 	Station Code: M02C
# 	Channel Count: 15/158 (Selected/Total)
# 	2005-06-30T00:00:00.000000Z - 2016-05-01T23:59:59.000000Z
# 	Access: open
# 	Latitude: 41.3920, Longitude: -122.8538, Elevation: 960.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2011-05-02 to 2016-05-01
# 	    ..BH[ZNE]    40.0 Hz  2009-10-10 to 2016-05-01
# 	    ..LH[ZNE]     1.0 Hz  2009-10-10 to 2016-05-01
# 	    ..VH[ZNE]     0.1 Hz  2009-10-10 to 2016-05-01
# 	    ..UH[ZNE]     0.0 Hz  2009-10-10 to 2016-05-01
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2016-05-01T15:45:00.000000Z
# 	Latitude: 41.3920, Longitude: -122.8538, Elevation: 960.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2016-05-01T15:45:00.000000Z
# 	Latitude: 41.3920, Longitude: -122.8538, Elevation: 960.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-05-02T15:30:00.000000Z - 2016-05-01T15:45:00.000000Z
# 	Latitude: 41.3920, Longitude: -122.8538, Elevation: 960.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M03C (SIO OBS ID M03C)
# 		Channels (3):
# 			7D.M03C..BHZ, 7D.M03C..BH1, 7D.M03C..BH2
# Station M03C (SIO OBS ID M03C)
# 	Station Code: M03C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-30T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.8884, Longitude: -126.1046, Elevation: -1839.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-30
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T16:13:00.000000Z - 2014-05-30T04:45:00.000000Z
# 	Latitude: 47.8884, Longitude: -126.1046, Elevation: -1839.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T16:13:00.000000Z - 2014-05-30T04:45:00.000000Z
# 	Latitude: 47.8884, Longitude: -126.1046, Elevation: -1839.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T16:13:00.000000Z - 2014-05-30T04:45:00.000000Z
# 	Latitude: 47.8884, Longitude: -126.1046, Elevation: -1839.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J73C (SIO OBS ID J73C)
# 		Channels (3):
# 			7D.J73C..BHZ, 7D.J73C..BH1, 7D.J73C..BH2
# Station J73C (SIO OBS ID J73C)
# 	Station Code: J73C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-30T23:59:59.000000Z
# 	Access: open
# 	Latitude: 48.7679, Longitude: -126.1926, Elevation: -133.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-30
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T16:50:00.000000Z - 2014-05-30T11:59:00.000000Z
# 	Latitude: 48.7679, Longitude: -126.1926, Elevation: -133.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T16:50:00.000000Z - 2014-05-30T11:59:00.000000Z
# 	Latitude: 48.7679, Longitude: -126.1926, Elevation: -133.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T16:50:00.000000Z - 2014-05-30T11:59:00.000000Z
# 	Latitude: 48.7679, Longitude: -126.1926, Elevation: -133.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.M01C (SIO OBS ID M01C)
# 		Channels (3):
# 			7D.M01C..BHZ, 7D.M01C..BH1, 7D.M01C..BH2
# Station M01C (SIO OBS ID M01C)
# 	Station Code: M01C
# 	Channel Count: 3/8 (Selected/Total)
# 	2013-08-19T00:00:00.000000Z - 2014-05-30T23:59:59.000000Z
# 	Access: open
# 	Latitude: 49.1504, Longitude: -126.7222, Elevation: -138.0 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2013-08-19 to 2014-05-30
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2013-08-19T20:08:00.000000Z - 2014-05-30T19:32:58.000000Z
# 	Latitude: 49.1504, Longitude: -126.7222, Elevation: -138.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2013-08-19T20:08:00.000000Z - 2014-05-30T19:32:58.000000Z
# 	Latitude: 49.1504, Longitude: -126.7222, Elevation: -138.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2013-08-19T20:08:00.000000Z - 2014-05-30T19:32:58.000000Z
# 	Latitude: 49.1504, Longitude: -126.7222, Elevation: -138.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (trillium_compact_OBS_SIO/ABALONES-4x4)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.FN13C (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.FN13C..HHZ, 7D.FN13C..HH1, 7D.FN13C..HH2
# Station FN13C (LDEO OBS STANDARD DEEP)
# 	Station Code: FN13C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-04T00:00:00.000000Z - 2014-06-28T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.0004, Longitude: -125.3011, Elevation: -1764.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-05 to 2014-06-28
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-05T11:23:00.000000Z - 2014-06-28T08:47:21.000000Z
# 	Latitude: 47.0004, Longitude: -125.3011, Elevation: -1764.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-05T11:23:00.000000Z - 2014-06-28T08:47:21.000000Z
# 	Latitude: 47.0004, Longitude: -125.3011, Elevation: -1764.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-05T11:23:00.000000Z - 2014-06-28T08:47:21.000000Z
# 	Latitude: 47.0004, Longitude: -125.3011, Elevation: -1764.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.J58C (LDEO OBS STANDARD DEEP)
# 		Channels (3):
# 			7D.J58C..HHZ, 7D.J58C..HH1, 7D.J58C..HH2
# Station J58C (LDEO OBS STANDARD DEEP)
# 	Station Code: J58C
# 	Channel Count: 3/9 (Selected/Total)
# 	2013-09-04T00:00:00.000000Z - 2014-06-27T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.3178, Longitude: -125.5346, Elevation: -1527.0 m
# 	Available Channels:
# 	    ..HH[Z21]   125.0 Hz  2013-09-05 to 2014-06-27
#
# This is chn:  Channel 'HH1', Location ''
# 	Time range: 2013-09-05T15:31:00.000000Z - 2014-06-27T22:09:20.000000Z
# 	Latitude: 47.3178, Longitude: -125.5346, Elevation: -1527.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HH2', Location ''
# 	Time range: 2013-09-05T15:31:00.000000Z - 2014-06-27T22:09:20.000000Z
# 	Latitude: 47.3178, Longitude: -125.5346, Elevation: -1527.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-09-05T15:31:00.000000Z - 2014-06-27T22:09:20.000000Z
# 	Latitude: 47.3178, Longitude: -125.5346, Elevation: -1527.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 125.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium Compact Response/LDEO OBS 201)
# 	Response information available
#          station   longitude   latitude  elevation(m)    component  \
# 0     7A.W09..BH -126.577003  48.688000       -1156.0        1,2,Z
# 1     7A.W01..BH -126.342499  48.079700       -1697.0        1,2,Z
# 2     7A.W02..BH -126.496803  48.259300       -2133.0        1,2,Z
# 3     7A.W07..BH -126.282204  48.374699       -1152.0        1,2,Z
# 4     7A.W03..BH -126.728699  48.387501       -2489.0        1,2,Z
# 5     7A.W10..BH -126.702202  48.787899       -1070.0        1,2,Z
# 6     7A.W08..BH -126.401100  48.564499       -1028.0        1,2,Z
# 7     7A.W04..BH -126.890800  48.531700       -2319.0        1,2,Z
# 8     7A.W06..BH -126.064697  48.182701       -1001.0        1,2,Z
# 9    NV.NC89..HH -126.848770  48.670536       -1256.0  E,E,N,N,Z,Z
# 10   NV.NCBC..HH -126.175201  48.427502        -398.0  E,E,N,N,Z,Z
# 11   7D.J65A..BH -125.139603  47.891300        -165.2        1,2,Z
# 12   7D.J73A..BH -126.192497  48.767700        -143.3        1,2,Z
# 13   7D.M01A..BH -126.722099  49.150398        -132.9        1,2,Z
# 14   7D.M03A..HH -126.103996  47.888302       -1818.0        1,2,Z
# 15   7D.J58A..HH -125.534401  47.318802       -1511.0        1,2,Z
# 16   TA.J58A..HH  -75.285202  43.360298         436.0        E,N,Z
# 17   7D.M04C..BH -125.192299  47.558399        -570.0        1,2,Z
# 18   TA.M04C..HH -121.839302  41.782600        1391.0  E,E,N,N,Z,Z
# 19   7D.J65C..BH -125.139801  47.891300        -169.0        1,2,Z
# 20   7D.M02C..BH -125.601196  48.306900        -141.0        1,2,Z
# 21   TA.M02C..HH -122.853798  41.391998         960.0        E,N,Z
# 22   7D.M03C..BH -126.104599  47.888401       -1839.0        1,2,Z
# 23   7D.J73C..BH -126.192596  48.767899        -133.0        1,2,Z
# 24   7D.M01C..BH -126.722198  49.150398        -138.0        1,2,Z
# 25  7D.FN13C..HH -125.301102  47.000401       -1764.0        1,2,Z
# 26   7D.J58C..HH -125.534599  47.317799       -1527.0        1,2,Z
#
#                                              response unit            id
# 0              629980000.00,632496000.00,625786000.00  m/s    7A.W09..BH
# 1              628302000.00,627463000.00,622430000.00  m/s    7A.W01..BH
# 2              629141000.00,626624000.00,622430000.00  m/s    7A.W02..BH
# 3              627463000.00,628302000.00,641724000.00  m/s    7A.W07..BH
# 4              624108000.00,629980000.00,623269000.00  m/s    7A.W03..BH
# 5              626624000.00,623269000.00,624108000.00  m/s    7A.W10..BH
# 6              627463000.00,630819000.00,629980000.00  m/s    7A.W08..BH
# 7              635013000.00,635852000.00,629141000.00  m/s    7A.W04..BH
# 8              628302000.00,629141000.00,625786000.00  m/s    7A.W06..BH
# 9   448102000.00,448125000.00,466851000.00,4668750...  m/s   NV.NC89..HH
# 10  464976000.00,465000000.00,467476000.00,4675000...  m/s   NV.NCBC..HH
# 11          1846390000.00,1846390000.00,1846390000.00  m/s   7D.J65A..BH
# 12          1846390000.00,1846390000.00,1846390000.00  m/s   7D.J73A..BH
# 13          1846390000.00,1846390000.00,1846390000.00  m/s   7D.M01A..BH
# 14             971188000.00,971188000.00,971188000.00  m/s   7D.M03A..HH
# 15             971188000.00,971188000.00,971188000.00  m/s   7D.J58A..HH
# 16             627604000.00,627604000.00,627604000.00  m/s   TA.J58A..HH
# 17          1846390000.00,1846390000.00,1846390000.00  m/s   7D.M04C..BH
# 18  502116000.00,502116000.00,502116000.00,5021160...  m/s   TA.M04C..HH
# 19          1846390000.00,1846390000.00,1846390000.00  m/s   7D.J65C..BH
# 20          1846390000.00,1846390000.00,1846390000.00  m/s   7D.M02C..BH
# 21             502116000.00,502116000.00,502116000.00  m/s   TA.M02C..HH
# 22          1846390000.00,1846390000.00,1846390000.00  m/s   7D.M03C..BH
# 23          1846390000.00,1846390000.00,1846390000.00  m/s   7D.J73C..BH
# 24          1846390000.00,1846390000.00,1846390000.00  m/s   7D.M01C..BH
# 25             971188000.00,971188000.00,971188000.00  m/s  7D.FN13C..HH
# 26             971188000.00,971188000.00,971188000.00  m/s   7D.J58C..HH

# %% [markdown]
# ### Convert the station file from a CSV file to dat files

# %%
stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
converted_hypoinverse = []
converted_hypoDD = {}

for i in tqdm(range(len(stations))):

    network_code, station_code, comp_code, channel_code = stations.iloc[i]['station'].split('.')
    station_weight = " "
    lat_degree = int(stations.iloc[i]['latitude'])
    lat_minute = (stations.iloc[i]['latitude'] - lat_degree) * 60
    north = "N" if lat_degree >= 0 else "S"
    lng_degree = int(stations.iloc[i]['longitude'])
    lng_minute = (stations.iloc[i]['longitude'] - lng_degree) * 60
    west = "W" if lng_degree <= 0 else "E"
    elevation = stations.iloc[i]['elevation(m)']
    line_hypoinverse = f"{station_code:<5} {network_code:<2} {comp_code[:-1]:<1}{channel_code:<3} {station_weight}{abs(lat_degree):2.0f} {abs(lat_minute):7.4f}{north}{abs(lng_degree):3.0f} {abs(lng_minute):7.4f}{west}{elevation:4.0f}\n"
    converted_hypoinverse.append(line_hypoinverse)
    converted_hypoDD[f"{station_code}"] = f"{network_code:<2}{station_code:<5} {stations.iloc[i]['latitude']:.3f} {stations.iloc[i]['longitude']:.3f} {elevation:4.0f}\n"

out_file = f'stations_hypoinverse_{region}.dat'
with open(out_file, 'w') as f:
    f.writelines(converted_hypoinverse)

out_file = f'stations_hypoDD_{region}.dat'
with open(out_file, 'w') as f:
    for k, v in converted_hypoDD.items():
        f.write(v)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 5417.96it/s]

# %% [markdown]
# ### Format the pick files

# %%
# Load necessary files
# Load all event data into a list of DataFrames
import datetime 
pick_assignment_files = [
    f'../data/datasets_{region}/all_pick_assignments_{region}.csv'
]

# Read all event files into DataFrames
dfs = [pd.read_csv(file, index_col=0) for file in pick_assignment_files]

# Concatenate all DataFrames into a single DataFrame
assignments =  pd.concat(dfs)

assignments = assignments.rename(columns={"time": "origin_time"})
assignments['origin_time'] = pd.to_datetime(assignments['origin_time'], utc = True)
assignments["pick_time"] = assignments["time_pick"].apply(datetime.datetime.fromtimestamp, tz=datetime.timezone.utc)
assignments = assignments.sort_values(by='origin_time').reset_index(drop=True)

# Reset the idx column so that each group with the same 'time' has a new numbered event index
assignments['idx'] = assignments.groupby('origin_time').ngroup()


# picks = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)
# picks = picks.sort_values(by='trace_start_time').reset_index(drop=True)

# %%
assignments
# Out:
#      idx                      origin_time           x           y          z  \
# 0      0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 1      0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 2      0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 3      0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 4      0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# ..   ...                              ...         ...         ...        ...
# 970  122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
# 971  122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
# 972  122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
# 973  122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
# 974  122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
#
#      picks   latitude   longitude      depth  event_idx  pick_idx  residual  \
# 0       10  49.206819 -125.232068  49.609375          0      1409  0.215366
# 1       10  49.206819 -125.232068  49.609375          0    529384 -0.095951
# 2       10  49.206819 -125.232068  49.609375          0      1293  0.273670
# 3       10  49.206819 -125.232068  49.609375          0    529219  0.403824
# 4       10  49.206819 -125.232068  49.609375          0      1514 -0.425773
# ..     ...        ...         ...        ...        ...       ...       ...
# 970      6  48.910006 -129.388983   7.421875        277    811981 -0.357134
# 971      6  48.910006 -129.388983   7.421875        277    812097  0.218010
# 972      6  48.910006 -129.388983   7.421875        277    509326 -0.955544
# 973      6  48.910006 -129.388983   7.421875        277    811999  0.915856
# 974      6  48.910006 -129.388983   7.421875        277    812153 -0.806692
#
#     station phase     time_pick   pick_id                        pick_time
# 0       W01     P  1.293934e+09      6480 2011-01-02 02:11:06.849100+00:00
# 1       W01     S  1.293934e+09      6386 2011-01-02 02:11:22.029100+00:00
# 2       W02     P  1.293934e+09      6134 2011-01-02 02:11:05.728100+00:00
# 3       W02     S  1.293934e+09      5874 2011-01-02 02:11:20.488100+00:00
# 4       W03     P  1.293934e+09      6658 2011-01-02 02:11:05.229901+00:00
# ..      ...   ...           ...       ...                              ...
# 970    J58C     S  1.401229e+09  15038819 2014-05-27 22:11:10.675100+00:00
# 971    J73C     S  1.401229e+09  15054341 2014-05-27 22:10:49.612559+00:00
# 972    M01C     P  1.401229e+09  15054036 2014-05-27 22:10:20.249473+00:00
# 973    M02C     S  1.401229e+09  15038989 2014-05-27 22:11:01.583625+00:00
# 974    M03C     S  1.401229e+09  15054888 2014-05-27 22:10:55.236924+00:00
#
# [975 rows x 17 columns]

# %%
# Merge the picks and assignments DataFrames on the pick_id column

# Convert the datetime columns to datetime objects
# picks['trace_p_arrival'] = pd.to_datetime(picks['trace_p_arrival'])
# picks['trace_s_arrival'] = pd.to_datetime(picks['trace_s_arrival'])
assignments['pick_time'] = pd.to_datetime(assignments['pick_time'])

# picks = pd.merge(picks, assignments, left_on="pick_id", right_on="pick_id", how='left')

# # Fill NaN values and convert idx columns to integers
# picks = picks.fillna(-1).astype({'idx': int})

# # Rename columns for consistency
# picks = picks.rename(columns={"station_code": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
# picks['type'] = picks['type'].str.lower()

# Rename columns for consistency
assignments = assignments.rename(columns={"station": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
assignments['type'] = assignments['type'].str.lower()

# %%
# picks.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
#                     date_format='%Y-%m-%dT%H:%M:%S.%f',
#                     columns=["id", "timestamp", "type", "event_index"])
assignments.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["id", "timestamp", "type", "event_index"])

# %%
assignments
# Out:
#      event_index                      origin_time           x           y  \
# 0              0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993
# 1              0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993
# 2              0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993
# 3              0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993
# 4              0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993
# ..           ...                              ...         ...         ...
# 970          122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757
# 971          122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757
# 972          122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757
# 973          122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757
# 974          122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757
#
#              z  picks   latitude   longitude      depth  event_idx  pick_idx  \
# 0    49.609375     10  49.206819 -125.232068  49.609375          0      1409
# 1    49.609375     10  49.206819 -125.232068  49.609375          0    529384
# 2    49.609375     10  49.206819 -125.232068  49.609375          0      1293
# 3    49.609375     10  49.206819 -125.232068  49.609375          0    529219
# 4    49.609375     10  49.206819 -125.232068  49.609375          0      1514
# ..         ...    ...        ...         ...        ...        ...       ...
# 970   7.421875      6  48.910006 -129.388983   7.421875        277    811981
# 971   7.421875      6  48.910006 -129.388983   7.421875        277    812097
# 972   7.421875      6  48.910006 -129.388983   7.421875        277    509326
# 973   7.421875      6  48.910006 -129.388983   7.421875        277    811999
# 974   7.421875      6  48.910006 -129.388983   7.421875        277    812153
#
#      residual    id type     time_pick   pick_id  \
# 0    0.215366   W01    p  1.293934e+09      6480
# 1   -0.095951   W01    s  1.293934e+09      6386
# 2    0.273670   W02    p  1.293934e+09      6134
# 3    0.403824   W02    s  1.293934e+09      5874
# 4   -0.425773   W03    p  1.293934e+09      6658
# ..        ...   ...  ...           ...       ...
# 970 -0.357134  J58C    s  1.401229e+09  15038819
# 971  0.218010  J73C    s  1.401229e+09  15054341
# 972 -0.955544  M01C    p  1.401229e+09  15054036
# 973  0.915856  M02C    s  1.401229e+09  15038989
# 974 -0.806692  M03C    s  1.401229e+09  15054888
#
#                            timestamp
# 0   2011-01-02 02:11:06.849100+00:00
# 1   2011-01-02 02:11:22.029100+00:00
# 2   2011-01-02 02:11:05.728100+00:00
# 3   2011-01-02 02:11:20.488100+00:00
# 4   2011-01-02 02:11:05.229901+00:00
# ..                               ...
# 970 2014-05-27 22:11:10.675100+00:00
# 971 2014-05-27 22:10:49.612559+00:00
# 972 2014-05-27 22:10:20.249473+00:00
# 973 2014-05-27 22:11:01.583625+00:00
# 974 2014-05-27 22:10:55.236924+00:00
#
# [975 rows x 17 columns]

# %% [markdown]
# ### Format event files

# %%
catalog = assignments.drop_duplicates(subset='event_idx')

# %%
catalog = catalog.rename(columns={'origin_time':'time',"depth": "depth_km",'idx':'event_index'})

# %%
catalog
# Out:
#      event_index                             time           x           y  \
# 0              0 2011-01-02 02:10:45.481987+00:00   19.523735  523.281993
# 10             1 2011-01-03 22:30:53.445832+00:00  -78.652760  277.252856
# 16             2 2011-01-05 05:25:45.145580+00:00  -97.618674  461.774708
# 22             3 2011-01-05 09:29:58.041704+00:00  -92.040464  551.890032
# 29             4 2011-01-05 14:35:15.536295+00:00 -290.624737  559.042042
# ..           ...                              ...         ...         ...
# 938          118 2014-05-04 09:37:25.896488+00:00 -306.243725  507.547571
# 944          119 2014-05-21 04:04:16.795543+00:00  -77.537118  533.294806
# 954          120 2014-05-25 11:21:40.359990+00:00  232.611354  414.571444
# 961          121 2014-05-27 08:51:10.491000+00:00 -285.046527  507.547571
# 969          122 2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757
#
#              z  picks   latitude   longitude   depth_km  event_idx  pick_idx  \
# 0    49.609375     10  49.206819 -125.232068  49.609375          0      1409
# 10   12.890625      6  46.989816 -126.533950  12.890625          8      2249
# 16    4.296875      6  48.646430 -126.824766   4.296875         10      4783
# 22   24.609375      7  49.457391 -126.769550  24.609375         11    533169
# 29    5.078125      6  49.459134 -129.509297   5.078125         12    533068
# ..         ...    ...        ...         ...        ...        ...       ...
# 938  13.671875      6  48.989699 -129.684922  13.671875        266    798539
# 944  41.796875     10  49.292245 -126.565918  41.796875        273    503360
# 954  49.609375      7  48.186967 -122.371453  49.609375        275    507169
# 961  11.328125      8  48.999834 -129.395983  11.328125        276    812122
# 969   7.421875      6  48.910006 -129.388983   7.421875        277    509575
#
#      residual     id type     time_pick   pick_id  \
# 0    0.215366    W01    p  1.293934e+09      6480
# 10   0.021108    W07    p  1.294094e+09     11017
# 16   0.805587    W04    p  1.294205e+09     21044
# 22  -0.253921    W10    s  1.294220e+09     20954
# 29   0.209775    W08    s  1.294238e+09     20767
# ..        ...    ...  ...           ...       ...
# 938  0.785890   M02C    s  1.399196e+09  14477206
# 944 -0.340478  FN13C    p  1.400645e+09  14913766
# 954 -0.637635   M03C    p  1.401017e+09  15008669
# 961 -0.476157   M03C    s  1.401181e+09  15054850
# 969  0.985504   M03C    p  1.401229e+09  15054875
#
#                            timestamp
# 0   2011-01-02 02:11:06.849100+00:00
# 10  2011-01-03 22:31:14.746700+00:00
# 16  2011-01-05 05:25:49.291300+00:00
# 22  2011-01-05 09:30:17.530200+00:00
# 29  2011-01-05 14:36:14.188600+00:00
# ..                               ...
# 938 2014-05-04 09:38:37.478172+00:00
# 944 2014-05-21 04:04:52.407700+00:00
# 954 2014-05-25 11:22:16.871307+00:00
# 961 2014-05-27 08:52:12.396924+00:00
# 969 2014-05-27 22:10:30.816924+00:00
#
# [123 rows x 17 columns]

# %%
catalog.to_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t", index=False,
                    float_format="%.3f",
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["time", "longitude", "latitude", "depth_km",'event_index'])

# %%
events = pd.read_csv(f'../data/datasets_nwa_shelf_trench/events_nwa_shelf_trench.csv', index_col=0)
events
# Out:
#      idx                              time           x           y          z  \
# 0      0  2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 8      8  2011-01-03 22:30:53.445832+00:00  -78.652760  277.252856  12.890625
# 10    10  2011-01-05 05:25:45.145580+00:00  -97.618674  461.774708   4.296875
# 11    11  2011-01-05 09:29:58.041704+00:00  -92.040464  551.890032  24.609375
# 12    12  2011-01-05 14:35:15.536295+00:00 -290.624737  559.042042   5.078125
# ..   ...                               ...         ...         ...        ...
# 266  266  2014-05-04 09:37:25.896488+00:00 -306.243725  507.547571  13.671875
# 273  273  2014-05-21 04:04:16.795543+00:00  -77.537118  533.294806  41.796875
# 275  275  2014-05-25 11:21:40.359990+00:00  232.611354  414.571444  49.609375
# 276  276  2014-05-27 08:51:10.491000+00:00 -285.046527  507.547571  11.328125
# 277  277  2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
#
#      picks   latitude   longitude      depth
# 0       10  49.206819 -125.232068  49.609375
# 8        6  46.989816 -126.533950  12.890625
# 10       6  48.646430 -126.824766   4.296875
# 11       7  49.457391 -126.769550  24.609375
# 12       6  49.459134 -129.509297   5.078125
# ..     ...        ...         ...        ...
# 266      6  48.989699 -129.684922  13.671875
# 273     10  49.292245 -126.565918  41.796875
# 275      7  48.186967 -122.371453  49.609375
# 276      8  48.999834 -129.395983  11.328125
# 277      6  48.910006 -129.388983   7.421875
#
# [123 rows x 9 columns]

# %%
# The parameters in the associator class: n_picks=2,n_p_picks=1,n_s_picks=1,n_p_and_s_picks=1
fig = plt.figure(figsize=(4, 8))
ax = fig.add_subplot()
ax.set_aspect("equal")

# ax.scatter(events["x"], events["y"], c=events["z"])
ax.set_xlabel("Easting [km]")
ax.set_ylabel("Northing [km]")
cax = fig.add_axes([ax.get_position().x1+0.05,ax.get_position().y0,0.02,ax.get_position().height])
cb1 = fig.colorbar(ax.scatter(events["x"], events["y"], c=events["z"],s=0.5,cmap='viridis'), cax=cax)
cb1.ax.invert_yaxis()

# %%
catalog = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv',index_col=0)
len(catalog)
# Out:
# 123

# %%
from datetime import datetime


stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
stations['net'] = stations['station'].apply(lambda x: x.split('.')[0])
stations['sta'] = stations['station'].apply(lambda x: x.split('.')[1])
stations['cha'] = stations['station'].apply(lambda x: x.split('.')[3])

picks = pd.read_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t")
events = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t")

events["match_id"] = events["event_index"]
picks["match_id"] = picks["event_index"]
events.sort_values(by="time", inplace=True, ignore_index=True)

out_file = open(f"../hypoInv/hypoInput_{region}.arc", "w")

events['time'] = pd.to_datetime(events['time'])

picks_by_event = picks.groupby("match_id").groups
for i in tqdm(range(len(events))):

    event = events.iloc[i]
    event_time = event["time"].strftime("%Y%m%d%H%M%S%f")[:-4]
    lat_degree = int(event["latitude"])
    lat_minute = (event["latitude"] - lat_degree) * 60 * 100
    south = "S" if lat_degree <= 0 else " "
    lng_degree = int(event["longitude"])
    lng_minute = (event["longitude"] - lng_degree) * 60 * 100
    east = "E" if lng_degree >= 0 else " "
    depth = event["depth_km"]
    if np.sum(picks[picks["event_index"] == events.iloc[i]['match_id']]['type'] == 'p') == 0:
        continue
    event_line = f"{event_time}{abs(lat_degree):2d}{south}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{east}{abs(lng_minute):4.0f}{depth:5.0f}"
    out_file.write(event_line + "\n")

    picks_idx = picks_by_event[event["match_id"]]
    for j in picks_idx:
        pick = picks.iloc[j]
        station_code = pick['id']
        network_code = stations['net'][stations['sta'] == pick['id']].iloc[0]
        comp_code = ''
        channel_code = stations['cha'][stations['sta'] == pick['id']].iloc[0]
        phase_type = pick['type']
        
        # Check if 'prob' column exists
        if 'prob' in pick:
            phase_weight = min(max(int((1 - pick['prob']) / (1 - 0.3) * 4) - 1, 0), 3)
        else:
            phase_weight = 0  # Default value if 'prob' column is missing

        # Assuming pick['timestamp'] has the format '2012-01-01 03:19:00.689664' or 2012-01-01 03:19:00.689664+00:00'
        try:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S.%f")  # Handle microseconds with %f
        except:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S%z")  # Handle timezone with %z
        phase_time_minute = pick_time.strftime("%Y%m%d%H%M")  # Extract YYYYMMDDHHMM
        phase_time_second = pick_time.strftime("%S%f")[:-4]  # Extract seconds with first two digits of microseconds
        tmp_line = f"{station_code:<5}{network_code:<2} {comp_code:<1}{channel_code:<3}"
        if phase_type.upper() == 'P':
            pick_line = f"{tmp_line:<13} P {phase_weight:<1d}{phase_time_minute} {phase_time_second}"
        elif phase_type.upper() == 'S':
            pick_line = f"{tmp_line:<13}   4{phase_time_minute} {'':<12}{phase_time_second} S {phase_weight:<1d}"
        else:
            raise ValueError(f"Phase type error {phase_type}")
        out_file.write(pick_line + "\n")

    out_file.write("\n")
    if i > 1e5:
        break

out_file.close()
# Out:
#   0%|          | 0/123 [00:00<?, ?it/s]
# 100%|██████████| 123/123 [00:00<00:00, 555.39it/s]
