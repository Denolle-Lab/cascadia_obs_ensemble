# %% [markdown]
# ## Notebook for formatting data frames for phase association
# Source:
# - https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file
# - https://www.usgs.gov/software/hypoinverse-earthquake-location
# - https://chatgpt.com/c/67491af9-aaf8-800c-82e9-1033e094d8d0
# - https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2017JB014966

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
from pnwstore.mseed import WaveformClient
from obspy import UTCDateTime
from obspy.core.stream import Stream
from obspy.clients.fdsn import Client
from tqdm import tqdm
import datetime

# %% [markdown]
# ### 1.3 Create a CSV file for picks for the association

# %% [markdown]
# ### Format the files for HypoInverse and HypoDD
# References: https://github.com/kaiwenwang233/scoped_ML_tutorial?tab=readme-ov-file

# %% [markdown]
# ### Format the station files

# %%
region = 'pnsn_wa'
df = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)

# %%
TOFB = df[df['station_code']=='TOFB']

# %%
TOFB['station_network_code'].unique()
# Out:
# array(['C8'], dtype=object)

# %%
from obspy import read_inventory
from collections import defaultdict
import pandas as pd

client2 = Client("IRIS")
networks = pd.read_csv("../data/networks.csv")
networks = ','.join(list(networks['networks']))
starttime = UTCDateTime(year=2011, month=1, day=1)
endtime = UTCDateTime(year=2016, month=1, day=1)
inv = [] 
# inv = read_inventory("./stations/*.xml")
station_locs = defaultdict(dict)
# stations=inv


for station in df['station_code'].unique():
    inv += client2.get_stations(network=networks,
                                    station=station, channel="?H?", 
                                    starttime=starttime, endtime=endtime, level="response")
stations=inv

print(len(stations))

for network in stations:
    print(network)
    for station in network:
        print(station)
        has_HH = bool(station.select(channel="HH?"))
        has_BH = bool(station.select(channel="BH?"))

        # Apply selection logic based on channel presence
        if has_HH and has_BH:
            # If both HH and BH channels are present, select only HH
            selected_station = station.select(channel="HH?")
        elif has_HH:
            # If only HH channels are present
            selected_station = station.select(channel="HH?")
        elif has_BH:
            # If only BH channels are present
            selected_station = station.select(channel="BH?")

        for chn in selected_station:
            print('This is chn: ', chn)
            sid = f"{network.code}.{station.code}.{chn.location_code}.{chn.code[:-1]}"
            if sid in station_locs:
                station_locs[sid]["component"] += f",{chn.code[-1]}"
                station_locs[sid]["response"] += f",{chn.response.instrument_sensitivity.value:.2f}"
            else:
                component = f"{chn.code[-1]}"
                response = f"{chn.response.instrument_sensitivity.value:.2f}"
                dtype = chn.response.instrument_sensitivity.input_units.lower()
                tmp_dict = {}
                tmp_dict["longitude"], tmp_dict["latitude"], tmp_dict["elevation(m)"] = (
                    chn.longitude,
                    chn.latitude,
                    chn.elevation,
                )
                tmp_dict["component"], tmp_dict["response"], tmp_dict["unit"] = component, response, dtype
                station_locs[sid] = tmp_dict
            if station_locs[sid]["component"]=='Z':
                station_locs[sid]["response"]= f"0,0,"+station_locs[sid]["response"]
            elif station_locs[sid]["component"]=='N,Z':
                station_locs[sid]["response"]= f"0,"+station_locs[sid]["response"]
station_locs = pd.DataFrame.from_dict(station_locs, orient='index')
station_locs["id"] = station_locs.index
station_locs = station_locs.rename_axis('station').reset_index()
station_locs.to_csv(f"./stations_{region}.csv",sep='\t')
station_locs
# Out:
# 34
# Network CN (Canadian National Seismograph Network (CNSN))
# 	Station Count: 1/300 (Selected/Total)
# 	1975-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			CN
0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2013-08-08 to 2016-06-24
# 	    ..BH[ZNE]    40.0 Hz  2008-11-12 to 2013-08-08
# 	    ..LH[ZNE]     1.0 Hz  2008-11-12 to 2013-08-08
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2013-08-08T00:00:00.000000Z - 2016-06-24T00:00:00.000000Z
# 	Latitude: 45.9306, Longitude: -123.5591, Elevation: 327.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (CMG-3T,Velocity Sensor,GURALP)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2013-08-08T00:00:00.000000Z - 2016-06-24T00:00:00.000000Z
# 	Latitude: 45.9306, Longitude: -123.5591, Elevation: 327.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (CMG-3T,Velocity Sensor,GURALP)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-08-08T00:00:00.000000Z - 2016-06-24T00:00:00.000000Z
# 	Latitude: 45.9306, Longitude: -123.5591, Elevation: 327.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (CMG-3T,Velocity Sensor,GURALP)
# 	Response information available
# Network 7D (Cascadia Initiative Community Experiment - OBS Component (CIET1))
# 	Station Count: 1/259 (Selected/Total)
# 	2011-01-01T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			7D.G03D (WHOI OBS ID T111)
# 		Channels (6):
# 			7D.G03D..BHZ, 7D.G03D..BH1, 7D.G03D..BH2, 7D.G03D..LHZ,
# 			7D.G03D..LH1, 7D.G03D..LH2
# Station G03D (WHOI OBS ID T111)
# 	Station Code: G03D
# 	Channel Count: 6/37 (Selected/Total)
# 	2014-07-14T00:00:00.000000Z - 2015-08-29T23:59:59.000000Z
# 	Access: open
# 	Latitude: 40.0587, Longitude: -126.1612, Elevation: -4056.5 m
# 	Available Channels:
# 	    ..BH[Z21]    50.0 Hz  2014-07-14 to 2015-08-29
# 	    ..LH[Z21]     1.0 Hz  2014-07-14 to 2015-08-29
#
# This is chn:  Channel 'BH1', Location ''
# 	Time range: 2014-07-14T00:00:00.000000Z - 2015-08-29T23:59:59.000000Z
# 	Latitude: 40.0587, Longitude: -126.1612, Elevation: -4056.5 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BH2', Location ''
# 	Time range: 2014-07-14T00:00:00.000000Z - 2015-08-29T23:59:59.000000Z
# 	Latitude: 40.0587, Longitude: -126.1612, Elevation: -4056.5 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2014-07-14T00:00:00.000000Z - 2015-08-29T23:59:59.000000Z
# 	Latitude: 40.0587, Longitude: -126.1612, Elevation: -4056.5 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (Nanometrics trillium_compact_obs WHOI OBSIP/Quante)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.G03D (McMinnville, OR, USA)
# 		Channels (15):
# 			TA.G03D..BHZ, TA.G03D..BHN, TA.G03D..BHE, TA.G03D..HHZ,
# 			TA.G03D..HHN, TA.G03D..HHE, TA.G03D..LHZ, TA.G03D..LHN,
# 			TA.G03D..LHE, TA.G03D..UHZ, TA.G03D..UHN, TA.G03D..UHE,
# 			TA.G03D..VHZ, TA.G03D..VHN, TA.G03D..VHE
# Station G03D (McMinnville, OR, USA)
# 	Station Code: G03D
# 	Channel Count: 15/93 (Selected/Total)
# 	2009-10-24T00:00:00.000000Z - 2016-09-30T23:59:59.000000Z
# 	Access: open
# 	Latitude: 45.2115, Longitude: -123.2641, Elevation: 222.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2015-10-16 to 2016-02-18
# 	    ..BH[ZNE]    40.0 Hz  2009-10-24 to 2016-02-18
# 	    ..LH[ZNE]     1.0 Hz  2009-10-24 to 2016-02-18
# 	    ..VH[ZNE]     0.1 Hz  2009-10-24 to 2016-02-18
# 	    ..UH[ZNE]     0.0 Hz  2009-10-24 to 2016-02-18
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2015-10-16T18:00:00.000000Z - 2016

# 	Response information available
# Network UW (Pacific Northwest Seismic Network (PNSN))
# 	Station Count: 1/874 (Selected/Total)
# 	1963-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			UW.OFR (Olympics - Forest Resource Center)
# 		Channels (3):
# 			UW.OFR..BHZ, UW.OFR..BHN, UW.OFR..BHE
# Station OFR (Olympics - Forest Resource Center)
# 	Station Code: OFR
# 	Channel Count: 3/9 (Selected/Total)
# 	1995-10-25T00:00:00.000000Z - 2013-01-17T00:00:00.000000Z
# 	Access: open
# 	Latitude: 47.9331, Longitude: -124.3960, Elevation: 152.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    50.0 Hz  2001-10-20 to 2013-01-17
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2001-10-20T00:00:00.000000Z - 2013-01-17T00:00:00.000000Z
# 	Latitude: 47.9331, Longitude: -124.3960, Elevation: 152.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (G40T_60-4872=72A07-7941)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2001-10-20T00:00:00.000000Z - 2013-01-17T00:00:00.000000Z
# 	Latitude: 47.9331, Longitude: -124.3960, Elevation: 152.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (G40T_60-4872=72A07-7941)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# 	Time range: 2001-10-20T00:00:00.000000Z - 2013-01-17T00:00:00.000000Z
# 	Latitude: 47.9331, Longitude: -124.3960, Elevation: 152.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: CONTINUOUS
# 	Sampling Rate: 50.00 Hz
# 	Sensor (Description): None (G40T_60-4872=72A07-7941)
# 	Response information available
# Network UW (Pacific Northwest Seismic Network (PNSN))
# 	Station Count: 1/874 (Selected/Total)
# 	1963-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			UW.LEBA (Lebam, WA, USA)
# 		Channels (12):
# 			UW.LEBA..BHZ, UW.LEBA..BHN, UW.LEBA..BHE, UW.LEBA..HHZ,
# 			UW.LEBA..HHN, UW.LEBA..HHE, UW.LEBA..LHZ, UW.LEBA..LHN,
# 			UW.LEBA..LHE, UW.LEBA..VHZ, UW.LEBA..VHN, UW.LEBA..VHE
# Station LEBA (Lebam, WA, USA)
# 	Station Code: LEBA
# 	Channel Count: 12/119 (Selected/Total)
# 	2009-01-08T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 46.5459, Longitude: -123.5632, Elevation: 78.6 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2013-07-12 to 2020-10-21
# 	    ..BH[ZNE]    40.0 Hz  2009-01-08 to 2013-07-12
# 	    ..LH[ZNE]     1.0 Hz  2009-01-08 to 2013-07-12
# 	    ..VH[ZNE]     0.1 Hz  2009-01-08 to 2013-07-12
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2013-07-12T00:00:00.000000Z - 2020-10-21T00:00:00.000000Z
# 	Latitude: 46.5459, Longitude: -123.5632, Elevation: 78.6 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (STS-2,Velocity Sensor,STRECKEISEN)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2013-07-12T00:00:00.000000Z - 2020-10-21T00:00:00.000000Z
# 	Latitude: 46.5459, Longitude: -123.5632, Elevation: 78.6 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (STS-2,Velocity Sensor,STRECKEISEN)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2013-07-12T00:00:00.000000Z - 2020-10-21T00:00:00.000000Z
# 	Latitude: 46.5459, Longitude: -123.5632, Elevation: 78.6 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: CONTINUOUS, GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (STS-2,Velocity Sensor,STRECKEISEN)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.F04D (Rainier, OR, USA)
# 		Channels (15):
# 			TA.F04D..BHZ, TA.F04D..BHN, TA.F04D..BHE, TA.F04D..HHZ,
# 			TA.F04D..HHN, TA.F04D..HHE, TA.F04D..LHZ, TA.F04D..LHN,
# 			TA.F04D..LHE, TA.F04D..UHZ, TA.F04D..UHN, TA.F04D..UHE,
# 			TA.F04D..VHZ, TA.F04D..VHN, TA.F04D..VHE
# Station F04D (Rainier, OR, USA)
# 	Station Code: F04D
# 	Channel Count: 15/62 (Selected/Total)
# 	2009-11-14T00:00:00.000000Z - 2016-09-30T23:59:59.000000Z
# 	Access: open
# 	Latitude: 46.0829, Longitude: -123.0108, Elevation: 236.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2015-10-16 to 2016-09-30
# 	    ..BH[ZNE]    40.0 Hz  2009-11-14 to 2016-09-30
# 	    ..LH[ZNE]     1.0 Hz  2009-11-14 to 2016-09-30
# 	    ..VH[ZNE]     0.1 Hz  2009-11-14 to 2016-09-30
# 	    ..UH[ZNE]     0.0 Hz  2009-11-14 to 2016-09-30
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2015-10-16T18:00:00.000000Z - 2016-09-30T19:30:00.000000Z
# 	Latitude: 46.0829, Longitude: -123.0108, Elevation: 236.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2015-10-16T18:00:00.000000Z - 2016-09-30T19:30:00.000000Z
# 	Latitude: 46.0829, Longitude: -123.0108, Elevation: 236.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2015-10-16T18:00:00.000000Z - 2016-09-30T19:30:00.000000Z
# 	Latitude: 46.0829, Longitude: -123.0108, Elevation: 236.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 400 and a)
# 	Response information available
# Network TA (USArray Transportable Array (EarthScope_TA))
# 	Station Count: 1/1893 (Selected/Total)
# 	2003-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			TA.D03D (Eldon, WA, USA)
# 		Channels (15):
# 			TA.D03D..BHZ, TA.D03D..BHN, TA.D03D..BHE, TA.D03D..HHZ,
# 			TA.D03D..HHN, TA.D03D..HHE, TA.D03D..LHZ, TA.D03D..LHN,
# 			TA.D03D..LHE, TA.D03D..UHZ, TA.D03D..UHN, TA.D03D..UHE,
# 			TA.D03D..VHZ, TA.D03D..VHN, TA.D03D..VHE
# Station D03D (Eldon, WA, USA)
# 	Station Code: D03D
# 	Channel Count: 15/55 (Selected/Total)
# 	2010-08-25T00:00:00.000000Z - 2016-06-15T23:59:59.000000Z
# 	Access: open
# 	Latitude: 47.5347, Longitude: -123.0894, Elevation: 262.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2015-10-16 to 2016-06-15
# 	    ..BH[ZNE]    40.0 Hz  2010-08-25 to 2016-06-15
# 	    ..LH[ZNE]     1.0 Hz  2010-08-25 to 2016-06-15
# 	    ..VH[ZNE]     0.1 Hz  2010-08-25 to 2016-06-15
# 	    ..UH[ZNE]     0.0 Hz  2010-08-25 to 2016-06-15
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2015-10-16T18:00:00.000000Z - 2016-06-15T17:25:00.000000Z
# 	Latitude: 47.5347, Longitude: -123.0894, Elevation: 262.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.10 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 0-399/Qua)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2015-10-16T18:00:00.000000Z - 2016-06-15T17:25:00.000000Z
# 	Latitude: 47.5347, Longitude: -123.0894, Elevation: 262.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.10 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 0-399/Qua)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2015-10-16T18:00:00.000000Z - 2016-06-15T17:25:00.000000Z
# 	Latitude: 47.5347, Longitude: -123.0894, Elevation: 262.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 240 Sec Response sn 0-399/Qua)
# 	Response information available
# Network CN (Canadian National Seismograph Network (CNSN))
# 	Station Count: 1/300 (Selected/Total)
# 	1975-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			CN.BMSB (Bamfield Marine Station, BC, CA)
# 		Channels (3):
# 			CN.BMSB..BHZ, CN.BMSB..BHN, CN.BMSB..BHE
# Station BMSB (Bamfield Marine Station, BC, CA)
# 	Station Code: BMSB
# 	Channel Count: 3/3 (Selected/Total)
# 	2003-03-07T00:00:00.000000Z - 2011-11-24T23:59:59.999900Z
# 	Access: open
# 	Latitude: 48.8356, Longitude: -125.1355, Elevation: 10.0 m
# 	Available Channels:
# 	    ..BH[ZNE]    40.0 Hz  2003-03-07 to 2011-11-24
#
# This is chn:  Channel 'BHE', Location ''
# 	Time range: 2003-03-07T00:00:00.000000Z - 2011-11-24T00:42:00.000000Z
# 	Latitude: 48.8356, Longitude: -125.1355, Elevation: 10.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Guralp CMG3ESP/CNSN GD2_v12 digitizer)
# 	Response information available
# This is chn:  Channel 'BHN', Location ''
# 	Time range: 2003-03-07T00:00:00.000000Z - 2011-11-24T00:42:00.000000Z
# 	Latitude: 48.8356, Longitude: -125.1355, Elevation: 10.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 40.00 Hz
# 	Sensor (Description): None (Guralp CMG3ESP/CNSN GD2_v12 digitizer)
# 	Response information available
# This is chn:  Channel 'BHZ', Location ''
# ...
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG3ESP_100sec/Taurus Standard 47k)
# 	Response information available
# Network CN (Canadian National Seismograph Network (CNSN))
# 	Station Count: 1/300 (Selected/Total)
# 	1975-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			CN.TOFB (Tofino, BC, CA)
# 		Channels (3):
# 			CN.TOFB..HHZ, CN.TOFB..HHN, CN.TOFB..HHE
# Station TOFB (Tofino, BC, CA)
# 	Station Code: TOFB
# 	Channel Count: 3/12 (Selected/Total)
# 	2009-02-14T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 49.1543, Longitude: -125.9078, Elevation: 13.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2009-02-14 to 2021-12-01
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2009-02-14T01:55:00.000000Z - 2021-12-01T19:35:00.000000Z
# 	Latitude: 49.1543, Longitude: -125.9078, Elevation: 13.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG3ESP_100sec/Taurus Standard 47k)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2009-02-14T01:55:00.000000Z - 2021-12-01T19:35:00.000000Z
# 	Latitude: 49.1543, Longitude: -125.9078, Elevation: 13.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG3ESP_100sec/Taurus Standard 47k)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2009-02-14T01:55:00.000000Z - 2021-12-01T19:35:00.000000Z
# 	Latitude: 49.1543, Longitude: -125.9078, Elevation: 13.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG3ESP_100sec/Taurus Standard 47k)
# 	Response information available
# Network C8 (Canadian Seismic Research Network ())
# 	Station Count: 1/70 (Selected/Total)
# 	2002-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			C8.PA01 (Sidney PGC North, BC, CA)
# 		Channels (6):
# 			C8.PA01..HHZ (2x), C8.PA01..HHN (2x), C8.PA01..HHE (2x)
# Station PA01 (Sidney PGC North, BC, CA)
# 	Station Code: PA01
# 	Channel Count: 6/6 (Selected/Total)
# 	2010-07-22T00:00:00.000000Z - 2018-12-31T23:59:59.999900Z
# 	Access: open
# 	Latitude: 48.6526, Longitude: -123.4470, Elevation: 3.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2011-10-21 to 2018-12-31
# 	    ..HH[ZNE]   100.0 Hz  2010-07-22 to 2011-10-21
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2010-07-22T19:41:00.000000Z - 2011-10-21T17:18:00.000000Z
# 	Latitude: 48.6526, Longitude: -123.4470, Elevation: 3.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2011-10-21T17:19:00.000000Z - 2018-12-31T23:59:00.000000Z
# 	Latitude: 48.6526, Longitude: -123.4470, Elevation: 3.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2010-07-22T19:41:00.000000Z - 2011-10-21T17:18:00.000000Z
# 	Latitude: 48.6526, Longitude: -123.4470, Elevation: 3.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2011-10-21T17:19:00.000000Z - 2018-12-31T23:59:00.000000Z
# 	Latitude: 48.6526, Longitude: -123.4470, Elevation: 3.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2010-07-22T19:41:00.000000Z - 2011-10-21T17:18:00.000000Z
# 	Latitude: 48.6526, Longitude: -123.4470, Elevation: 3.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2011-10-21T17:19:00.000000Z - 2018-12-31T23:59:00.000000Z
# 	Latitude: 48.6526, Longitude: -123.4470, Elevation: 3.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# Network C8 (Canadian Seismic Research Network ())
# 	Station Count: 1/70 (Selected/Total)
# 	2002-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			C8.PA05 (Sidney PGC Willingdon, BC, CA)
# 		Channels (3):
# 			C8.PA05..HHZ, C8.PA05..HHN, C8.PA05..HHE
# Station PA05 (Sidney PGC Willingdon, BC, CA)
# 	Station Code: PA05
# 	Channel Count: 3/3 (Selected/Total)
# 	2010-07-22T00:00:00.000000Z - 2017-12-31T23:59:59.999900Z
# 	Access: open
# 	Latitude: 48.6497, Longitude: -123.4438, Elevation: 8.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2010-07-22 to 2017-12-31
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2010-07-22T18:43:00.000000Z - 2017-12-31T23:59:00.000000Z
# 	Latitude: 48.6497, Longitude: -123.4438, Elevation: 8.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2010-07-22T18:43:00.000000Z - 2017-12-31T23:59:00.000000Z
# 	Latitude: 48.6497, Longitude: -123.4438, Elevation: 8.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2010-07-22T18:43:00.000000Z - 2017-12-31T23:59:00.000000Z
# 	Latitude: 48.6497, Longitude: -123.4438, Elevation: 8.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Nanometrics Trillium 120 Sec Response/Taurus Stand)
# 	Response information available
# Network C8 (Canadian Seismic Research Network ())
# 	Station Count: 1/70 (Selected/Total)
# 	2002-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			C8.SPLB (Strathcona Park Lodge, BC, CA)
# 		Channels (3):
# 			C8.SPLB..HHZ, C8.SPLB..HHN, C8.SPLB..HHE
# Station SPLB (Strathcona Park Lodge, BC, CA)
# 	Station Code: SPLB
# 	Channel Count: 3/3 (Selected/Total)
# 	2009-07-30T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 49.8921, Longitude: -125.6526, Elevation: 276.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2009-07-30 to None
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2009-07-30T01:00:00.000000Z - --
# 	Latitude: 49.8921, Longitude: -125.6526, Elevation: 276.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG40T_30sec/Taurus Standard 47k)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2009-07-30T01:00:00.000000Z - --
# 	Latitude: 49.8921, Longitude: -125.6526, Elevation: 276.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG40T_30sec/Taurus Standard 47k)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2009-07-30T01:00:00.000000Z - --
# 	Latitude: 49.8921, Longitude: -125.6526, Elevation: 276.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG40T_30sec/Taurus Standard 47k)
# 	Response information available
# Network C8 (Canadian Seismic Research Network ())
# 	Station Count: 1/70 (Selected/Total)
# 	2002-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			C8.MWAB (Mount Washington, BC, CA)
# 		Channels (3):
# 			C8.MWAB..HHZ, C8.MWAB..HHN, C8.MWAB..HHE
# Station MWAB (Mount Washington, BC, CA)
# 	Station Code: MWAB
# 	Channel Count: 3/3 (Selected/Total)
# 	2009-07-31T00:00:00.000000Z -
# 	Access: open
# 	Latitude: 49.7411, Longitude: -125.3032, Elevation: 1176.0 m
# 	Available Channels:
# 	    ..HH[ZNE]   100.0 Hz  2009-07-31 to None
#
# This is chn:  Channel 'HHE', Location ''
# 	Time range: 2009-07-31T21:02:00.000000Z - --
# 	Latitude: 49.7411, Longitude: -125.3032, Elevation: 1176.0 m, Local Depth: 0.0 m
# 	Azimuth: 90.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG40T_30sec/Taurus Standard 47k)
# 	Response information available
# This is chn:  Channel 'HHN', Location ''
# 	Time range: 2009-07-31T21:02:00.000000Z - --
# 	Latitude: 49.7411, Longitude: -125.3032, Elevation: 1176.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: 0.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG40T_30sec/Taurus Standard 47k)
# 	Response information available
# This is chn:  Channel 'HHZ', Location ''
# 	Time range: 2009-07-31T21:02:00.000000Z - --
# 	Latitude: 49.7411, Longitude: -125.3032, Elevation: 1176.0 m, Local Depth: 0.0 m
# 	Azimuth: 0.00 degrees from north, clockwise
# 	Dip: -90.00 degrees down from horizontal
# 	Channel types: GEOPHYSICAL
# 	Sampling Rate: 100.00 Hz
# 	Sensor (Description): None (Guralp CMG40T_30sec/Taurus Standard 47k)
# 	Response information available
#          station   longitude   latitude  elevation(m)    component  \
# 0     CN.LZB..BH -123.824000  48.612200         794.0        E,N,Z
# 1     CN.VGZ..HH -123.325100  48.413100          67.0        E,N,Z
# 2     CN.BTB..HH -125.522600  49.468600        1607.0        E,N,Z
# 3     CN.PFB..HH -124.454100  48.574700         449.0        E,N,Z
# 4    CN.NLLB..BH -123.988200  49.227100         199.0        E,N,Z
# 5     CN.SNB..HH -123.172300  48.775100         402.0        E,N,Z
# 6     CN.PGC..BH -123.452100  48.649800          12.0  E,E,N,N,Z,Z
# 7     CN.SHB..BH -123.877100  49.598500        1129.0        E,N,Z
# 8   CN.SHB.00.BH -123.880501  49.592999        1143.0        E,N,Z
# 9     CN.OZB..BH -125.497800  48.961200         626.0        E,N,Z
# 10   UW.FISH..HH -123.559100  45.930600         327.0        E,N,Z
# 11   7D.G03D..BH -126.161201  40.058701       -4056.5        1,2,Z
# 12   TA.G03D..HH -123.264099  45.211498         222.0        E,N,Z
# 13    UW.SQM..BH -123.048058  48.073681          45.0        E,N,Z
# 14   UW.MEGW..BH -123.877090  46.266090         351.0        E,N,Z
# 15   UW.WISH..BH -123.771180  47.116980          45.0  E,E,N,N,Z,Z
# 16   UW.HEBO..BH -123.755390  45.213500         875.0  E,E,N,N,Z,Z
# 17   UW.LRIV..BH -123.504000  48.057500         293.8        E,N,Z
# 18    UW.OFR..BH -124.396042  47.933128         152.0        E,N,Z
# 19   UW.LEBA..HH -123.563202  46.545898          78.6        E,N,Z
# 20   TA.F04D..HH -123.010803  46.082901         236.0        E,N,Z
# 21   TA.D03D..HH -123.089401  47.534698         262.0        E,N,Z
# 22   CN.BMSB..BH -125.135500  48.835600          10.0        E,N,Z
# 23   UW.RADR..BH -123.798970  46.421810         591.4        E,N,Z
# 24   CN.BFSB..HH -125.136000  48.833600          33.0        E,N,Z
# 25   CN.CLRS..HH -124.130900  48.820300         174.0        E,N,Z
# 26   C8.SOKB..HH -123.673100  48.394700          45.0        E,N,Z
# 27   C8.PA12..HH -123.449600  48.648200          10.0        E,N,Z
# 28   C8.PA02..HH -123.448900  48.651800           3.0  E,E,N,N,Z,Z
# 29   C8.TOFB..HH -125.907800  49.154300          13.0        E,N,Z
# 30   CN.TOFB..HH -125.907800  49.154300          13.0        E,N,Z
# 31   C8.PA01..HH -123.447000  48.652600           3.0  E,E,N,N,Z,Z
# 32   C8.PA05..HH -123.443800  48.649700           8.0        E,N,Z
# 33   C8.SPLB..HH -125.652600  49.892100         276.0        E,N,Z
# 34   C8.MWAB..HH -125.303200  49.741100        1176.0        E,N,Z
#
#                                              response unit            id
# 0              338563000.00,338563000.00,338563000.00  m/s    CN.LZB..BH
# 1           6788330000.00,6788330000.00,6788330000.00  m/s    CN.VGZ..HH
# 2           6788330000.00,6788330000.00,6788330000.00  m/s    CN.BTB..HH
# 3              848541000.00,848541000.00,848541000.00  m/s    CN.PFB..HH
# 4              848553000.00,848553000.00,848553000.00  m/s   CN.NLLB..BH
# 5              848541000.00,848541000.00,848541000.00  m/s    CN.SNB..HH
# 6   5019760000.00,5091330000.00,5019760000.00,5091...  m/s    CN.PGC..BH
# 7              848553000.00,848553000.00,848553000.00  m/s    CN.SHB..BH
# 8           6788420000.00,6788420000.00,6788420000.00  m/s  CN.SHB.00.BH
# 9              636397000.00,636397000.00,636397000.00  m/s    CN.OZB..BH
# 10             629871000.00,629871000.00,629871000.00  m/s   UW.FISH..HH
# 11             313645000.00,313645000.00,313645000.00  m/s   7D.G03D..BH
# 12             502116000.00,502116000.00,502116000.00  m/s   TA.G03D..HH
# 13             419430000.00,419430000.00,419430000.00  m/s    UW.SQM..BH
# 14             417438000.00,419221000.00,419745000.00  m/s   UW.MEGW..BH
# 15  419430400.00,754954800.00,419430400.00,7549548...  m/s   UW.WISH..BH
# 16  419430000.00,754955000.00,419430000.00,7549550...  m/s   UW.HEBO..BH
# 17             755583929.00,755583929.00,755583929.00  m/s   UW.LRIV..BH
# 18             419430000.00,419430000.00,419430000.00  m/s    UW.OFR..BH
# 19             627897000.00,627897000.00,627897000.00  m/s   UW.LEBA..HH
# 20             502116000.00,502116000.00,502116000.00  m/s   TA.F04D..HH
# 21             502130000.00,502130000.00,502130000.00  m/s   TA.D03D..HH
# 22             640640000.00,640640000.00,640640000.00  m/s   CN.BMSB..BH
# 23             755585130.00,755585130.00,755585130.00  m/s   UW.RADR..BH
# 24             809221000.00,809221000.00,809221000.00  m/s   CN.BFSB..HH
# 25             478269000.00,478269000.00,478269000.00  m/s   CN.CLRS..HH
# 26          2715250000.00,2715250000.00,2715250000.00  m/s   C8.SOKB..HH
# 27             478269000.00,478269000.00,478269000.00  m/s   C8.PA12..HH
# 28  2391350000.00,478269000.00,2391350000.00,47826...  m/s   C8.PA02..HH
# 29             801138000.00,801138000.00,801138000.00  m/s   C8.TOFB..HH
# 30             801138000.00,801138000.00,801138000.00  m/s   CN.TOFB..HH
# 31  2391350000.00,478269000.00,2391350000.00,47826...  m/s   C8.PA01..HH
# 32             478269000.00,478269000.00,478269000.00  m/s   C8.PA05..HH
# 33             323679000.00,323679000.00,323679000.00  m/s   C8.SPLB..HH
# 34             323679000.00,323679000.00,323679000.00  m/s   C8.MWAB..HH

# %% [markdown]
# ### Convert the station file from a CSV file to dat files

# %%
stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
converted_hypoinverse = []
converted_hypoDD = {}

for i in tqdm(range(len(stations))):

    network_code, station_code, comp_code, channel_code = stations.iloc[i]['station'].split('.')
    station_weight = " "
    lat_degree = int(stations.iloc[i]['latitude'])
    lat_minute = (stations.iloc[i]['latitude'] - lat_degree) * 60
    north = "N" if lat_degree >= 0 else "S"
    lng_degree = int(stations.iloc[i]['longitude'])
    lng_minute = (stations.iloc[i]['longitude'] - lng_degree) * 60
    west = "W" if lng_degree <= 0 else "E"
    elevation = stations.iloc[i]['elevation(m)']
    line_hypoinverse = f"{station_code:<5} {network_code:<2} {comp_code[:-1]:<1}{channel_code:<3} {station_weight}{abs(lat_degree):2.0f} {abs(lat_minute):7.4f}{north}{abs(lng_degree):3.0f} {abs(lng_minute):7.4f}{west}{elevation:4.0f}\n"
    converted_hypoinverse.append(line_hypoinverse)
    converted_hypoDD[f"{station_code}"] = f"{network_code:<2}{station_code:<5} {stations.iloc[i]['latitude']:.3f} {stations.iloc[i]['longitude']:.3f} {elevation:4.0f}\n"

out_file = f'stations_hypoinverse_{region}.dat'
with open(out_file, 'w') as f:
    f.writelines(converted_hypoinverse)

out_file = f'stations_hypoDD_{region}.dat'
with open(out_file, 'w') as f:
    for k, v in converted_hypoDD.items():
        f.write(v)
# Out:
# 100%|██████████| 35/35 [00:00<00:00, 2287.54it/s]

# %% [markdown]
# ### Format the pick files

# %%
# Load necessary files
# Load all event data into a list of DataFrames
import datetime 
pick_assignment_files = [
    f'../data/datasets_{region}/all_pick_assignments_{region}.csv'
]

# Read all event files into DataFrames
dfs = [pd.read_csv(file, index_col=0) for file in pick_assignment_files]

# Concatenate all DataFrames into a single DataFrame
assignments =  pd.concat(dfs)

assignments = assignments.rename(columns={"time": "origin_time"})
assignments['origin_time'] = pd.to_datetime(assignments['origin_time'], utc = True)
assignments["pick_time"] = assignments["time_pick"].apply(datetime.datetime.fromtimestamp, tz=datetime.timezone.utc)
assignments = assignments.sort_values(by='origin_time').reset_index(drop=True)

# Reset the idx column so that each group with the same 'time' has a new numbered event index
assignments['idx'] = assignments.groupby('origin_time').ngroup()


# picks = pd.read_csv(f'../data/datasets_{region}/all_picks_all_years_for_assoc_{region}.csv',index_col=0)
# picks = picks.sort_values(by='trace_start_time').reset_index(drop=True)

# %%
assignments
# Out:
#         idx                      origin_time           x           y  \
# 0         0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 1         0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 2         0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 3         0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 4         0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# ...     ...                              ...         ...         ...
# 86286  8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86287  8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86288  8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86289  8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86290  8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
#
#                z  picks   latitude   longitude      depth  event_idx  \
# 0       0.390625      6  48.487194 -122.534153   0.390625          0
# 1       0.390625      6  48.487194 -122.534153   0.390625          0
# 2       0.390625      6  48.487194 -122.534153   0.390625          0
# 3       0.390625      6  48.487194 -122.534153   0.390625          0
# 4       0.390625      6  48.487194 -122.534153   0.390625          0
# ...          ...    ...        ...         ...        ...        ...
# 86286  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86287  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86288  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86289  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86290  38.671875     18  48.620884 -124.191036  38.671875      10955
#
#        pick_idx  residual station phase     time_pick   pick_id  \
# 0       1244309  0.030308    D03D     S  1.293858e+09      4432
# 1       1244109  0.335511    LRIV     S  1.293858e+09      2646
# 2       1243638 -0.433839     LZB     S  1.293858e+09         9
# 3       1243772  0.160251     SHB     S  1.293858e+09       422
# 4            70 -0.245795     VGZ     P  1.293858e+09       353
# ...         ...       ...     ...   ...           ...       ...
# 86286   2249682  0.362806    CLRS     S  1.451524e+09  23569367
# 86287   1243149 -0.121397    CLRS     P  1.451524e+09  23569346
# 86288   1243204  0.334027     VGZ     P  1.451524e+09  23569677
# 86289   2249825 -0.009274    PA12     S  1.451524e+09  23569698
# 86290   2249800 -0.790659     VGZ     S  1.451524e+09  23569662
#
#                              pick_time
# 0     2011-01-01 04:58:35.024998+00:00
# 1     2011-01-01 04:58:28.135000+00:00
# 2     2011-01-01 04:58:30.125000+00:00
# 3            2011-01-01 04:58:47+00:00
# 4            2011-01-01 04:58:13+00:00
# ...                                ...
# 86286 2015-12-31 01:10:27.700000+00:00
# 86287 2015-12-31 01:10:22.300000+00:00
# 86288 2015-12-31 01:10:27.630000+00:00
# 86289 2015-12-31 01:10:32.960000+00:00
# 86290 2015-12-31 01:10:34.990000+00:00
#
# [86291 rows x 17 columns]

# %%
picks[picks['pick_id'] ==6134]
# Out:
# Empty DataFrame
# Columns: [event_id, source_type, station_network_code, station_channel_code, station_code, station_location_code, station_latitude_deg, station_longitude_deg, station_elevation_m, trace_name, trace_sampling_rate_hz, trace_start_time, trace_S_arrival_sample, trace_P_arrival_sample, trace_S_onset, trace_P_onset, trace_snr_db, trace_s_arrival, trace_p_arrival, pick_id]
# Index: []

# %%
# Merge the picks and assignments DataFrames on the pick_id column

# Convert the datetime columns to datetime objects
# picks['trace_p_arrival'] = pd.to_datetime(picks['trace_p_arrival'])
# picks['trace_s_arrival'] = pd.to_datetime(picks['trace_s_arrival'])
assignments['pick_time'] = pd.to_datetime(assignments['pick_time'])

# picks = pd.merge(picks, assignments, left_on="pick_id", right_on="pick_id", how='left')

# # Fill NaN values and convert idx columns to integers
# picks = picks.fillna(-1).astype({'idx': int})

# # Rename columns for consistency
# picks = picks.rename(columns={"station_code": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
# picks['type'] = picks['type'].str.lower()

# Rename columns for consistency
assignments = assignments.rename(columns={"station": "id", "pick_time": "timestamp","phase":'type','idx':'event_index'})
assignments['type'] = assignments['type'].str.lower()

# %%
# picks.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
#                     date_format='%Y-%m-%dT%H:%M:%S.%f',
#                     columns=["id", "timestamp", "type", "event_index"])
assignments.to_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t", index=False,
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["id", "timestamp", "type", "event_index"])

# %%
assignments
# Out:
#        event_index                      origin_time           x           y  \
# 0                0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 1                0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 2                0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 3                0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 4                0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# ...            ...                              ...         ...         ...
# 86286         8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86287         8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86288         8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86289         8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
# 86290         8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
#
#                z  picks   latitude   longitude      depth  event_idx  \
# 0       0.390625      6  48.487194 -122.534153   0.390625          0
# 1       0.390625      6  48.487194 -122.534153   0.390625          0
# 2       0.390625      6  48.487194 -122.534153   0.390625          0
# 3       0.390625      6  48.487194 -122.534153   0.390625          0
# 4       0.390625      6  48.487194 -122.534153   0.390625          0
# ...          ...    ...        ...         ...        ...        ...
# 86286  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86287  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86288  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86289  38.671875     18  48.620884 -124.191036  38.671875      10955
# 86290  38.671875     18  48.620884 -124.191036  38.671875      10955
#
#        pick_idx  residual    id type     time_pick   pick_id  \
# 0       1244309  0.030308  D03D    s  1.293858e+09      4432
# 1       1244109  0.335511  LRIV    s  1.293858e+09      2646
# 2       1243638 -0.433839   LZB    s  1.293858e+09         9
# 3       1243772  0.160251   SHB    s  1.293858e+09       422
# 4            70 -0.245795   VGZ    p  1.293858e+09       353
# ...         ...       ...   ...  ...           ...       ...
# 86286   2249682  0.362806  CLRS    s  1.451524e+09  23569367
# 86287   1243149 -0.121397  CLRS    p  1.451524e+09  23569346
# 86288   1243204  0.334027   VGZ    p  1.451524e+09  23569677
# 86289   2249825 -0.009274  PA12    s  1.451524e+09  23569698
# 86290   2249800 -0.790659   VGZ    s  1.451524e+09  23569662
#
#                              timestamp
# 0     2011-01-01 04:58:35.024998+00:00
# 1     2011-01-01 04:58:28.135000+00:00
# 2     2011-01-01 04:58:30.125000+00:00
# 3            2011-01-01 04:58:47+00:00
# 4            2011-01-01 04:58:13+00:00
# ...                                ...
# 86286 2015-12-31 01:10:27.700000+00:00
# 86287 2015-12-31 01:10:22.300000+00:00
# 86288 2015-12-31 01:10:27.630000+00:00
# 86289 2015-12-31 01:10:32.960000+00:00
# 86290 2015-12-31 01:10:34.990000+00:00
#
# [86291 rows x 17 columns]

# %% [markdown]
# ### Format event files

# %%
catalog = assignments.drop_duplicates(subset='event_idx')

# %%
catalog = catalog.rename(columns={'origin_time':'time',"depth": "depth_km",'idx':'event_index'})

# %%
catalog
# Out:
#        event_index                             time           x           y  \
# 0                0 2011-01-01 04:58:03.504768+00:00  219.223650  447.470689
# 6                1 2011-01-01 14:29:11.051052+00:00  218.108008  129.921454
# 13               2 2011-01-01 19:52:46.661153+00:00  140.013069  351.633757
# 19               3 2011-01-01 21:15:56.139179+00:00  181.291823  464.635512
# 29               4 2011-01-02 02:10:45.376984+00:00   -0.557821  518.990787
# ...            ...                              ...         ...         ...
# 86205         8342 2015-12-29 07:33:12.504298+00:00   -0.557821  490.382747
# 86222         8343 2015-12-30 07:39:30.008994+00:00  158.978983  456.053100
# 86259         8344 2015-12-30 10:12:04.084015+00:00  224.801860  458.913904
# 86267         8345 2015-12-30 14:04:12.055910+00:00  126.625365  540.446816
# 86273         8346 2015-12-31 01:10:15.705291+00:00   96.503032  458.913904
#
#                z  picks   latitude   longitude   depth_km  event_idx  \
# 0       0.390625      6  48.487194 -122.534153   0.390625          0
# 6       0.390625      7  45.634798 -122.702693   0.390625          1
# 13      8.203125      6  47.648376 -123.636385   8.203125          3
# 19     19.140625     10  48.653486 -123.039309  19.140625          4
# 29     49.609375     17  49.168544 -125.507649  49.609375          5
# ...          ...    ...        ...         ...        ...        ...
# 86205  30.078125     17  48.911302 -125.507610  30.078125      10950
# 86222  49.609375     37  48.582432 -123.345211  49.609375      10951
# 86259   9.765625      8  48.587986 -122.452629   9.765625      10952
# 86267   5.859375      6  49.348330 -123.757253   5.859375      10953
# 86273  38.671875     18  48.620884 -124.191036  38.671875      10955
#
#        pick_idx  residual    id type     time_pick   pick_id  \
# 0       1244309  0.030308  D03D    s  1.293858e+09      4432
# 6       1244307  0.820150  D03D    s  1.293892e+09      4430
# 13          456  1.123529  WISH    p  1.293912e+09      1568
# 19      1243736 -0.201916   VGZ    s  1.293917e+09       209
# 29      1244502  0.223097   OZB    s  1.293934e+09      5263
# ...         ...       ...   ...  ...           ...       ...
# 86205   2248694  0.386450  TOFB    s  1.451374e+09  23564801
# 86222   1242766  0.180779  PA12    p  1.451461e+09  23567817
# 86259   2249077  0.166482   SHB    s  1.451470e+09  23566888
# 86267   2249082 -0.058455  SPLB    s  1.451484e+09  23566905
# 86273   2249665 -0.082967   PFB    s  1.451524e+09  23569255
#
#                              timestamp
# 0     2011-01-01 04:58:35.024998+00:00
# 6     2011-01-01 14:30:08.824998+00:00
# 13    2011-01-01 19:52:57.386000+00:00
# 19    2011-01-01 21:16:06.650000+00:00
# 29    2011-01-02 02:10:59.475000+00:00
# ...                                ...
# 86205 2015-12-29 07:33:26.160000+00:00
# 86222 2015-12-30 07:39:37.450000+00:00
# 86259 2015-12-30 10:12:45.525000+00:00
# 86267 2015-12-30 14:04:52.330000+00:00
# 86273 2015-12-31 01:10:27.010000+00:00
#
# [8347 rows x 17 columns]

# %%
catalog.to_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t", index=False,
                    float_format="%.3f",
                    date_format='%Y-%m-%dT%H:%M:%S.%f',
                    columns=["time", "longitude", "latitude", "depth_km",'event_index'])

# %%
events = pd.read_csv(f'../data/datasets_nwa_shelf_trench/events_nwa_shelf_trench.csv', index_col=0)
events
# Out:
#      idx                              time           x           y          z  \
# 0      0  2011-01-02 02:10:45.481987+00:00   19.523735  523.281993  49.609375
# 8      8  2011-01-03 22:30:53.445832+00:00  -78.652760  277.252856  12.890625
# 10    10  2011-01-05 05:25:45.145580+00:00  -97.618674  461.774708   4.296875
# 11    11  2011-01-05 09:29:58.041704+00:00  -92.040464  551.890032  24.609375
# 12    12  2011-01-05 14:35:15.536295+00:00 -290.624737  559.042042   5.078125
# ..   ...                               ...         ...         ...        ...
# 266  266  2014-05-04 09:37:25.896488+00:00 -306.243725  507.547571  13.671875
# 273  273  2014-05-21 04:04:16.795543+00:00  -77.537118  533.294806  41.796875
# 275  275  2014-05-25 11:21:40.359990+00:00  232.611354  414.571444  49.609375
# 276  276  2014-05-27 08:51:10.491000+00:00 -285.046527  507.547571  11.328125
# 277  277  2014-05-27 22:09:54.035500+00:00 -285.046527  497.534757   7.421875
#
#      picks   latitude   longitude      depth
# 0       10  49.206819 -125.232068  49.609375
# 8        6  46.989816 -126.533950  12.890625
# 10       6  48.646430 -126.824766   4.296875
# 11       7  49.457391 -126.769550  24.609375
# 12       6  49.459134 -129.509297   5.078125
# ..     ...        ...         ...        ...
# 266      6  48.989699 -129.684922  13.671875
# 273     10  49.292245 -126.565918  41.796875
# 275      7  48.186967 -122.371453  49.609375
# 276      8  48.999834 -129.395983  11.328125
# 277      6  48.910006 -129.388983   7.421875
#
# [123 rows x 9 columns]

# %%
# The parameters in the associator class: n_picks=2,n_p_picks=1,n_s_picks=1,n_p_and_s_picks=1
fig = plt.figure(figsize=(4, 8))
ax = fig.add_subplot()
ax.set_aspect("equal")

# ax.scatter(events["x"], events["y"], c=events["z"])
ax.set_xlabel("Easting [km]")
ax.set_ylabel("Northing [km]")
cax = fig.add_axes([ax.get_position().x1+0.05,ax.get_position().y0,0.02,ax.get_position().height])
cb1 = fig.colorbar(ax.scatter(events["x"], events["y"], c=events["z"],s=0.5,cmap='viridis'), cax=cax)
cb1.ax.invert_yaxis()

# %%
catalog = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv',index_col=0)
len(catalog)
# Out:
# 8347

# %%
from datetime import datetime


stations = pd.read_csv(f"./stations_{region}.csv", sep="\t")
stations['net'] = stations['station'].apply(lambda x: x.split('.')[0])
stations['sta'] = stations['station'].apply(lambda x: x.split('.')[1])
stations['cha'] = stations['station'].apply(lambda x: x.split('.')[3])

picks = pd.read_csv(f'../data/datasets_{region}/picks_hypoinverse_{region}.csv', sep="\t")
events = pd.read_csv(f'../data/datasets_{region}/catalog_hypoinverse_{region}.csv', sep="\t")

events["match_id"] = events["event_index"]
picks["match_id"] = picks["event_index"]
events.sort_values(by="time", inplace=True, ignore_index=True)

out_file = open(f"../hypoInv/hypoInput_{region}.arc", "w")

events['time'] = pd.to_datetime(events['time'])

picks_by_event = picks.groupby("match_id").groups
for i in tqdm(range(len(events))):

    event = events.iloc[i]
    event_time = event["time"].strftime("%Y%m%d%H%M%S%f")[:-4]
    lat_degree = int(event["latitude"])
    lat_minute = (event["latitude"] - lat_degree) * 60 * 100
    south = "S" if lat_degree <= 0 else " "
    lng_degree = int(event["longitude"])
    lng_minute = (event["longitude"] - lng_degree) * 60 * 100
    east = "E" if lng_degree >= 0 else " "
    depth = event["depth_km"]
    if np.sum(picks[picks["event_index"] == events.iloc[i]['match_id']]['type'] == 'p') == 0:
        continue
    event_line = f"{event_time}{abs(lat_degree):2d}{south}{abs(lat_minute):4.0f}{abs(lng_degree):3d}{east}{abs(lng_minute):4.0f}{depth:5.0f}"
    out_file.write(event_line + "\n")

    picks_idx = picks_by_event[event["match_id"]]
    for j in picks_idx:
        pick = picks.iloc[j]
        station_code = pick['id']
        network_code = stations['net'][stations['sta'] == pick['id']].iloc[0]
        comp_code = ''
        channel_code = stations['cha'][stations['sta'] == pick['id']].iloc[0]
        phase_type = pick['type']
        
        # Check if 'prob' column exists
        if 'prob' in pick:
            phase_weight = min(max(int((1 - pick['prob']) / (1 - 0.3) * 4) - 1, 0), 3)
        else:
            phase_weight = 0  # Default value if 'prob' column is missing
        # 2011-01-02 02:11:06.849100+00:00
        # Assuming pick['timestamp'] has the format '2012-01-01 03:19:00.689664+00:00'
        try:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S.%f")  # Handle timezone with %z
        except:
            pick_time = datetime.strptime(pick["timestamp"], "%Y-%m-%dT%H:%M:%S%z")  # Handle timezone with %z
        phase_time_minute = pick_time.strftime("%Y%m%d%H%M")  # Extract YYYYMMDDHHMM
        phase_time_second = pick_time.strftime("%S%f")[:-4]  # Extract seconds with first two digits of microseconds
        tmp_line = f"{station_code:<5}{network_code:<2} {comp_code:<1}{channel_code:<3}"
        if phase_type.upper() == 'P':
            pick_line = f"{tmp_line:<13} P {phase_weight:<1d}{phase_time_minute} {phase_time_second}"
        elif phase_type.upper() == 'S':
            pick_line = f"{tmp_line:<13}   4{phase_time_minute} {'':<12}{phase_time_second} S {phase_weight:<1d}"
        else:
            raise ValueError(f"Phase type error {phase_type}")
        out_file.write(pick_line + "\n")

    out_file.write("\n")
    if i > 1e5:
        break

out_file.close()
# Out:
# 100%|██████████| 8347/8347 [00:41<00:00, 200.86it/s]
