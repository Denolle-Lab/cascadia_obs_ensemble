# %% [markdown]
# ## Notebook for formatting data frames for phase association

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Format data frames for picks

# %% [markdown]
# ### 1.1 Format one data frame first

# %%
df_FS09B_20121001 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/FS09B_20121001.csv')

# %%
df_FS09B_20121001
# Out:
#      Unnamed: 0 event_id source_type station_network_code  \
# 0             0                                        7D
# 1             1                                        7D
# 2             2                                        7D
# 3             3                                        7D
# 4             4                                        7D
# ..          ...      ...         ...                  ...
# 203         203                                        7D
# 204         204                                        7D
# 205         205                                        7D
# 206         206                                        7D
# 207         207                                        7D
#
#     station_channel_code station_code  station_location_code  \
# 0                               FS09B                    NaN
# 1                               FS09B                    NaN
# 2                               FS09B                    NaN
# ...

# %%
df_FS09B_20121001['phase'] = np.nan
df_FS09B_20121001
# Out:
#      Unnamed: 0 event_id source_type station_network_code  \
# 0             0                                        7D
# 1             1                                        7D
# 2             2                                        7D
# 3             3                                        7D
# 4             4                                        7D
# ..          ...      ...         ...                  ...
# 203         203                                        7D
# 204         204                                        7D
# 205         205                                        7D
# 206         206                                        7D
# 207         207                                        7D
#
#     station_channel_code station_code  station_location_code  \
# 0                               FS09B                    NaN
# 1                               FS09B                    NaN
# 2                               FS09B                    NaN
# ...

# %%
p_picks = df_FS09B_20121001.loc[df_FS09B_20121001['trace_p_arrival'].notna(), 'trace_p_arrival']
p_phase = df_FS09B_20121001.loc[df_FS09B_20121001['trace_p_arrival'].notna(), 'phase'] = "P"
p_stations = df_FS09B_20121001.loc[df_FS09B_20121001['trace_p_arrival'].notna(), 'station_code']
p_phase = df_FS09B_20121001.loc[df_FS09B_20121001['trace_p_arrival'].notna(), 'phase']

# %%
p_phase = df_FS09B_20121001.loc[df_FS09B_20121001['trace_p_arrival'].notna(), 'phase']

# %%
# print(p_picks)
# print(p_phase)
# print(p_stations)
p_phase
# Out:
# 0      P
# 1      P
# 2      P
# 3      P
# 4      P
#       ..
# 109    P
# 110    P
# 111    P
# 112    P
# 113    P
# Name: phase, Length: 114, dtype: object

# %%
s_picks =  df_FS09B_20121001.loc[df_FS09B_20121001['trace_s_arrival'].notna(), 'trace_s_arrival']
s_phase = df_FS09B_20121001.loc[df_FS09B_20121001['trace_s_arrival'].notna(), 'phase'] = "S"
s_stations = df_FS09B_20121001.loc[df_FS09B_20121001['trace_s_arrival'].notna(), 'station_code']
s_phase = df_FS09B_20121001.loc[df_FS09B_20121001['trace_s_arrival'].notna(), 'phase']

# %%
s_phase = df_FS09B_20121001.loc[df_FS09B_20121001['trace_s_arrival'].notna(), 'phase']

# %%
s_phase
# Out:
# 114    S
# 115    S
# 116    S
# 117    S
# 118    S
#       ..
# 203    S
# 204    S
# 205    S
# 206    S
# 207    S
# Name: phase, Length: 94, dtype: object

# %%
time = pd.concat(objs = [p_picks,s_picks] , axis=0)
phase = pd.concat(objs = [p_phase,s_phase] , axis=0)

# %%
print(time)
print(phase)
# Out:
# 0      2012-10-01T00:04:09.141700Z
# 1      2012-10-01T00:36:41.601700Z
# 2      2012-10-01T00:55:43.061700Z
# 3      2012-10-01T01:16:07.681700Z
# 4      2012-10-01T01:41:37.561700Z
#                   ...
# 203    2012-10-01T22:53:32.401700Z
# 204    2012-10-01T23:25:19.181700Z
# 205    2012-10-01T23:31:08.241700Z
# 206    2012-10-01T23:49:13.461700Z
# 207    2012-10-01T23:56:56.121700Z
# Length: 208, dtype: object
# 0      P
# 1      P
# 2      P
# 3      P
# 4      P
#       ..
# 203    S
# 204    S
# 205    S
# 206    S
# 207    S
# Name: phase, Length: 208, dtype: object

# %%
stations = df_FS09B_20121001['station_code']
stations
# Out:
# 0      FS09B
# 1      FS09B
# 2      FS09B
# 3      FS09B
# 4      FS09B
#        ...
# 203    FS09B
# 204    FS09B
# 205    FS09B
# 206    FS09B
# 207    FS09B
# Name: station_code, Length: 208, dtype: object

# %%
picks = pd.concat(objs = [stations,phase,time] , axis=1)

# %%
picks
# Out:
#     station_code phase                            0
# 0          FS09B     P  2012-10-01T00:04:09.141700Z
# 1          FS09B     P  2012-10-01T00:36:41.601700Z
# 2          FS09B     P  2012-10-01T00:55:43.061700Z
# 3          FS09B     P  2012-10-01T01:16:07.681700Z
# 4          FS09B     P  2012-10-01T01:41:37.561700Z
# ..           ...   ...                          ...
# 203        FS09B     S  2012-10-01T22:53:32.401700Z
# 204        FS09B     S  2012-10-01T23:25:19.181700Z
# 205        FS09B     S  2012-10-01T23:31:08.241700Z
# 206        FS09B     S  2012-10-01T23:49:13.461700Z
# 207        FS09B     S  2012-10-01T23:56:56.121700Z
#
# [208 rows x 3 columns]

# %% [markdown]
# ### 1.2 Concatenate data frames from several stations and format

# %%
df_FS09B_20121001 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/FS09B_20121001.csv')
df_FS13B_20121006 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/FS13B_20121006.csv')
df_G10B_20121001 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/G10B_20121001.csv')
df_G19B_20121005 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/G19B_20121005.csv')
df_G25B_20121014 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/G25B_20121014.csv')
df_G27B_20121001 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/G27B_20121001.csv')
df_J09B_20121001 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/J09B_20121001.csv')
df_M12B_20121001 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/M12B_20121001.csv')
df_M14B_20121001 = pd.read_csv('~/elep-test/surface_events/src/catalogs_elep_filtered_stations_20121001_to_20121031/M14B_20121001.csv')

# %%
df = pd.concat(objs = [df_FS09B_20121001,df_FS13B_20121006,df_G10B_20121001,df_G19B_20121005,df_G25B_20121014,df_G27B_20121001,df_J09B_20121001,df_M12B_20121001,df_M14B_20121001] , axis=0)
df = df.reset_index()
df
# Out:
#       index  Unnamed: 0 event_id source_type station_network_code  \
# 0         0           0                                        7D
# 1         1           1                                        7D
# 2         2           2                                        7D
# 3         3           3                                        7D
# 4         4           4                                        7D
# ...     ...         ...      ...         ...                  ...
# 2444    254         254                                        7D
# 2445    255         255                                        7D
# 2446    256         256                                        7D
# 2447    257         257                                        7D
# 2448    258         258                                        7D
#
#      station_channel_code station_code  station_location_code  \
# 0                                FS09B                    NaN
# ...

# %%
len(df)
# Out:
# 2449

# %%
p_picks = df.loc[df['trace_p_arrival'].notna(), 'trace_p_arrival']
p_phase = df.loc[df['trace_p_arrival'].notna(), 'phase'] = "P"
p_stations = df.loc[df['trace_p_arrival'].notna(), 'station_code']
p_phase = df.loc[df['trace_p_arrival'].notna(), 'phase']

# %%
p_picks
# Out:
# 0       2012-10-01T00:04:09.141700Z
# 1       2012-10-01T00:36:41.601700Z
# 2       2012-10-01T00:55:43.061700Z
# 3       2012-10-01T01:16:07.681700Z
# 4       2012-10-01T01:41:37.561700Z
#                    ...
# 2385    2012-10-01T23:08:32.619925Z
# 2386    2012-10-01T23:34:34.899925Z
# 2387    2012-10-01T23:49:53.619925Z
# 2388    2012-10-01T23:50:36.679925Z
# 2389    2012-10-01T23:52:27.199925Z
# Name: trace_p_arrival, Length: 1662, dtype: object

# %%
s_picks =  df.loc[df['trace_s_arrival'].notna(), 'trace_s_arrival']
s_phase = df.loc[df['trace_s_arrival'].notna(), 'phase'] = "S"
s_stations = df.loc[df['trace_s_arrival'].notna(), 'station_code']
s_phase = df.loc[df['trace_s_arrival'].notna(), 'phase']

# %%
s_phase
# Out:
# 114     S
# 115     S
# 116     S
# 117     S
# 118     S
#        ..
# 2444    S
# 2445    S
# 2446    S
# 2447    S
# 2448    S
# Name: phase, Length: 787, dtype: object

# %%
print(len(p_phase))
# Out:
# 1662

# %%
print(len(s_phase))
# Out:
# 787

# %%
time = pd.Series(pd.concat(objs = [p_picks,s_picks] , axis=0), name='time')
phase = pd.Series(pd.concat(objs = [p_phase,s_phase] , axis=0),name='phase')

# %%
time
# Out:
# 0       2012-10-01T00:04:09.141700Z
# 1       2012-10-01T00:36:41.601700Z
# 2       2012-10-01T00:55:43.061700Z
# 3       2012-10-01T01:16:07.681700Z
# 4       2012-10-01T01:41:37.561700Z
#                    ...
# 2444    2012-10-01T19:43:53.779925Z
# 2445    2012-10-01T21:19:41.539925Z
# 2446    2012-10-01T21:38:06.599925Z
# 2447    2012-10-01T23:08:32.799925Z
# 2448    2012-10-01T23:34:35.179925Z
# Name: time, Length: 2449, dtype: object

# %%
type(time)
# Out:
# pandas.core.series.Series

# %%
stations = pd.Series(df['station_code'],name='station')

# %%
picks = pd.concat(objs = [stations,phase,time] , axis=1)
picks
# Out:
#      station phase                         time
# 0      FS09B     P  2012-10-01T00:04:09.141700Z
# 1      FS09B     P  2012-10-01T00:36:41.601700Z
# 2      FS09B     P  2012-10-01T00:55:43.061700Z
# 3      FS09B     P  2012-10-01T01:16:07.681700Z
# 4      FS09B     P  2012-10-01T01:41:37.561700Z
# ...      ...   ...                          ...
# 2444    M14B     S  2012-10-01T19:43:53.779925Z
# 2445    M14B     S  2012-10-01T21:19:41.539925Z
# 2446    M14B     S  2012-10-01T21:38:06.599925Z
# 2447    M14B     S  2012-10-01T23:08:32.799925Z
# 2448    M14B     S  2012-10-01T23:34:35.179925Z
#
# [2449 rows x 3 columns]

# %%
picks.loc[]

# %%
picks.to_csv("~/elep-test/surface_events/data/phase_association/picks")

# %% [markdown]
# ## 2. Format data frames for stations

# %%
row_FS09B_20121001 = df_FS09B_20121001.iloc[0]
row_FS09B_20121001
# Out:
# Unnamed: 0                                          0
# event_id
# source_type
# station_network_code                               7D
# station_channel_code
# station_code                                    FS09B
# station_location_code                             NaN
# station_latitude_deg                        40.438702
# station_longitude_deg                     -124.808502
# station_elevation_m                           -2161.0
# trace_name
# trace_sampling_rate_hz                           50.0
# trace_start_time          2012-10-01T00:00:00.001700Z
# trace_S_arrival_sample
# trace_P_arrival_sample
# trace_S_onset
# trace_P_onset
# trace_snr_db
# trace_s_arrival                                   NaN
# trace_p_arrival           2012-10-01T00:04:09.141700Z
# Name: 0, dtype: object

# %%
_row_FS09B_20121001 = row_FS09B_20121001.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]

# %%
_row_FS09B_20121001
# Out:
# station_code                  FS09B
# station_longitude_deg   -124.808502
# station_latitude_deg      40.438702
# station_elevation_m         -2161.0
# Name: 0, dtype: object

# %%
row_FS09B_20121001 = df_FS09B_20121001.iloc[0]
row_FS13B_20121006 =df_FS13B_20121006.iloc[0]
row_G10B_20121001 =df_G10B_20121001.iloc[0]
row_G19B_20121005 =df_G19B_20121005.iloc[0]
row_G25B_20121014 =df_G25B_20121014.iloc[0]
row_G27B_20121001 =df_G27B_20121001.iloc[0]
row_J09B_20121001 =df_J09B_20121001.iloc[0]
row_M12B_20121001 =df_M12B_20121001.iloc[0]
row_M14B_20121001 =df_M14B_20121001.iloc[0]

# %%
_row_FS09B_20121001 = row_FS09B_20121001.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_FS13B_20121006  = row_FS13B_20121006 .loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_G10B_20121001 = row_G10B_20121001.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_G19B_20121005 = row_G19B_20121005.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_G25B_20121014 = row_G25B_20121014.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_G27B_20121001 = row_G27B_20121001.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_J09B_20121001 = row_J09B_20121001.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_M12B_20121001 = row_M12B_20121001.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]
_row_M14B_20121001 = row_M14B_20121001.loc[['station_code','station_longitude_deg','station_latitude_deg','station_elevation_m']]

# %%
_row_FS09B_20121001  = pd.DataFrame(np.array(_row_FS09B_20121001).reshape(1,len(_row_FS09B_20121001)))
_row_FS13B_20121006  = pd.DataFrame(np.array(_row_FS13B_20121006).reshape(1,len(_row_FS13B_20121006)))
_row_G10B_20121001 = pd.DataFrame(np.array(_row_G10B_20121001).reshape(1,len(_row_G10B_20121001)))
_row_G19B_20121005 = pd.DataFrame(np.array(_row_G19B_20121005).reshape(1,len(_row_G19B_20121005)))
_row_G25B_20121014 = pd.DataFrame(np.array(_row_G25B_20121014).reshape(1,len(_row_G25B_20121014)))
_row_G27B_20121001 = pd.DataFrame(np.array(_row_G27B_20121001).reshape(1,len(_row_G27B_20121001)))
_row_J09B_20121001 = pd.DataFrame(np.array(_row_J09B_20121001).reshape(1,len(_row_J09B_20121001)))
_row_M12B_20121001 = pd.DataFrame(np.array(_row_M12B_20121001).reshape(1,len(_row_M12B_20121001)))
_row_M14B_20121001 = pd.DataFrame(np.array(_row_M14B_20121001).reshape(1,len(_row_M14B_20121001)))

# %%
stations = pd.concat(objs = [_row_FS09B_20121001,_row_FS13B_20121006,_row_G10B_20121001,_row_G19B_20121005,_row_G25B_20121014,_row_G27B_20121001,_row_J09B_20121001,_row_M12B_20121001,_row_M14B_20121001] , axis=0, ignore_index=True)
stations
# Out:
#        0           1          2       3
# 0  FS09B -124.808502  40.438702 -2161.0
# 1  FS13B -124.806503  40.493099 -2332.0
# 2   G10B -125.553299  40.677898 -2936.0
# 3   G19B -125.773598    41.3074 -3071.0
# 4   G25B -124.586098  41.919899  -430.0
# 5   G27B -126.016701  41.916599 -3480.0
# 6   J09B -124.726997  43.151001  -252.0
# 7   M12B -124.946098  42.183998 -1045.0
# 8   M14B -124.589699  40.985001  -638.0

# %%
_stations = stations.rename(columns={0: 'id',1: 'longitude',2: 'latitude',3: 'elevation'})
_stations
# Out:
#       id   longitude   latitude elevation
# 0  FS09B -124.808502  40.438702   -2161.0
# 1  FS13B -124.806503  40.493099   -2332.0
# 2   G10B -125.553299  40.677898   -2936.0
# 3   G19B -125.773598    41.3074   -3071.0
# 4   G25B -124.586098  41.919899    -430.0
# 5   G27B -126.016701  41.916599   -3480.0
# 6   J09B -124.726997  43.151001    -252.0
# 7   M12B -124.946098  42.183998   -1045.0
# 8   M14B -124.589699  40.985001    -638.0

# %%
_stations.to_csv("~/elep-test/surface_events/data/phase_association/stations")

# %% [markdown]
# ## 3. Split the data frame in half to possibly make it work in the pyocto phase associator

# %% [markdown]
# ### 3.1 Split the CSV data frame in half and pick the first half

# %%
df_picks = pd.read_csv('~/elep-test/surface_events/data/phase_association/pick')
df_picks
# Out:
#       Unnamed: 0 station phase                         time
# 0              0   FS09B     P  2012-10-01T00:04:09.141700Z
# 1              1   FS09B     P  2012-10-01T00:36:41.601700Z
# 2              2   FS09B     P  2012-10-01T00:55:43.061700Z
# 3              3   FS09B     P  2012-10-01T01:16:07.681700Z
# 4              4   FS09B     P  2012-10-01T01:41:37.561700Z
# ...          ...     ...   ...                          ...
# 2444        2444    M14B     S  2012-10-01T19:43:53.779925Z
# 2445        2445    M14B     S  2012-10-01T21:19:41.539925Z
# 2446        2446    M14B     S  2012-10-01T21:38:06.599925Z
# 2447        2447    M14B     S  2012-10-01T23:08:32.799925Z
# 2448        2448    M14B     S  2012-10-01T23:34:35.179925Z
#
# [2449 rows x 4 columns]

# %%
df_picks_first_half = df_picks.iloc[0:1224]
df_picks_first_half
# Out:
#       Unnamed: 0 station phase                         time
# 0              0   FS09B     P  2012-10-01T00:04:09.141700Z
# 1              1   FS09B     P  2012-10-01T00:36:41.601700Z
# 2              2   FS09B     P  2012-10-01T00:55:43.061700Z
# 3              3   FS09B     P  2012-10-01T01:16:07.681700Z
# 4              4   FS09B     P  2012-10-01T01:41:37.561700Z
# ...          ...     ...   ...                          ...
# 1219        1219    G25B     P  2012-10-14T04:50:49.077500Z
# 1220        1220    G25B     P  2012-10-14T04:51:20.781500Z
# 1221        1221    G25B     P  2012-10-14T04:56:46.781500Z
# 1222        1222    G25B     P  2012-10-14T04:58:18.253500Z
# 1223        1223    G25B     P  2012-10-14T05:08:42.061500Z
#
# [1224 rows x 4 columns]

# %%
df_picks_first_half.drop(columns="Unnamed: 0", inplace=True)
df_picks_first_half
# Out:
# /tmp/ipykernel_1752187/3189789851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_picks_first_half.drop(columns="Unnamed: 0", inplace=True)
#      station phase                         time
# 0      FS09B     P  2012-10-01T00:04:09.141700Z
# 1      FS09B     P  2012-10-01T00:36:41.601700Z
# 2      FS09B     P  2012-10-01T00:55:43.061700Z
# 3      FS09B     P  2012-10-01T01:16:07.681700Z
# 4      FS09B     P  2012-10-01T01:41:37.561700Z
# ...      ...   ...                          ...
# 1219    G25B     P  2012-10-14T04:50:49.077500Z
# 1220    G25B     P  2012-10-14T04:51:20.781500Z
# 1221    G25B     P  2012-10-14T04:56:46.781500Z
# 1222    G25B     P  2012-10-14T04:58:18.253500Z
# 1223    G25B     P  2012-10-14T05:08:42.061500Z
#
# [1224 rows x 3 columns]

# %%
df_picks_first_half.to_csv("~/elep-test/surface_events/data/phase_association/picks_first_half")

# %%
len(df_picks_first_half[df_picks_first_half['phase']=="S"])
# Out:
# 427

# %%
797+427
# Out:
# 1224

# %% [markdown]
# ### 3.2 Cut the list of stations so that it only includes stations up to G25B

# %%
df_stations = pd.read_csv('~/elep-test/surface_events/data/phase_association/stations')

# %%
df_stations
# Out:
#    Unnamed: 0     id   longitude   latitude  elevation
# 0           0  FS09B -124.808502  40.438702    -2161.0
# 1           1  FS13B -124.806503  40.493099    -2332.0
# 2           2   G10B -125.553299  40.677898    -2936.0
# 3           3   G19B -125.773598  41.307400    -3071.0
# 4           4   G25B -124.586098  41.919899     -430.0
# 5           5   G27B -126.016701  41.916599    -3480.0
# 6           6   J09B -124.726997  43.151001     -252.0
# 7           7   M12B -124.946098  42.183998    -1045.0
# 8           8   M14B -124.589699  40.985001     -638.0

# %%
df_stations_first_half = df_stations.iloc[0:5]
df_stations_first_half
# Out:
#    Unnamed: 0     id   longitude   latitude  elevation
# 0           0  FS09B -124.808502  40.438702    -2161.0
# 1           1  FS13B -124.806503  40.493099    -2332.0
# 2           2   G10B -125.553299  40.677898    -2936.0
# 3           3   G19B -125.773598  41.307400    -3071.0
# 4           4   G25B -124.586098  41.919899     -430.0

# %%
df_stations_first_half.drop(columns="Unnamed: 0", inplace=True)
df_stations_first_half
# Out:
# /tmp/ipykernel_1752187/2894109736.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stations_first_half.drop(columns="Unnamed: 0", inplace=True)
#       id   longitude   latitude  elevation
# 0  FS09B -124.808502  40.438702    -2161.0
# 1  FS13B -124.806503  40.493099    -2332.0
# 2   G10B -125.553299  40.677898    -2936.0
# 3   G19B -125.773598  41.307400    -3071.0
# 4   G25B -124.586098  41.919899     -430.0

# %%
df_stations_first_half.to_csv("~/elep-test/surface_events/data/phase_association/stations_first_half")
