# %% [markdown]
# # Make Figure 2 of the paper
# Reference:
# - https://stackoverflow.com/questions/35634238/how-to-save-a-pandas-dataframe-table-as-a-png/69250659#69250659

# %%
# !pip install df2img
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 27.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 68.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 339.2/339.2 kB 91.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import table 
import df2img

# %%
df_arrival = pd.read_csv('../data/datasets_all_regions/arrival_2010_2015_reloc_cog_ver3.csv',index_col=0)
df_arrival.head()
# Out:
#        sta          time  arid iphase  prob
# 0  UW.PCMD  1.262305e+09     0      P  0.68
# 1   UW.RVW  1.262305e+09     1      P  0.68
# 2  UW.PCMD  1.262305e+09     2      S  0.68
# 3   UW.GNW  1.262305e+09     3      S  0.68
# 4  PB.B013  1.262305e+09     4      S  0.68

# %%
fig = df2img.plot_dataframe(
    df_arrival.head(),

    tbl_header=dict(
        align="right",
        fill_color="purple",
        font_color="white",
        font_size=10,
        line_color="darkslategray",
    ),
    tbl_cells=dict(
        align="right",
        line_color="darkslategray",
    ),
    row_fill_color=("#ffffff", "#d7d8d6"),
    fig_size=(400, 160),
    col_width=[1, 3.4, 6, 2, 2.7,2.5]
)

df2img.save_dataframe(fig=fig, filename="df_arrival_head.png")

# %%
df_assoc = pd.read_csv('../data/datasets_all_regions/assoc_2010_2015_reloc_cog_ver3.csv',index_col=0)
df_assoc.head()
# Out:
#    arid  orid      sta phase  prob  timeres  slatitude  slongitude  \
# 0     0     0  UW.PCMD     P  0.68    0.049  46.888962 -122.301483
# 1     1     0   UW.RVW     P  0.68    1.264  46.149750 -122.742996
# 2     2     0  UW.PCMD     S  0.68   -0.243  46.888962 -122.301483
# 3     3     0   UW.GNW     S  0.68    2.402  47.564130 -122.824980
# 4     4     0  PB.B013     S  0.68   -0.651  47.813000 -122.910797
#
#    selevation       delta        esaz        seaz
# 0       239.0   38.726602  195.021971   15.021971
# 1       504.0  127.374667  199.958459   19.958459
# 2       239.0   38.726602  195.021971   15.021971
# 3       220.0   62.222486  307.013042  127.013042
# 4        75.3   85.968984  319.190764  139.190764

# %%
fig = df2img.plot_dataframe(
    df_assoc.head(),

    tbl_header=dict(
        align="right",
        fill_color="purple",
        font_color="white",
        font_size=10,
        line_color="darkslategray",
    ),
    tbl_cells=dict(
        align="right",
        line_color="darkslategray",
    ),
    row_fill_color=("#ffffff", "#d7d8d6"),
    fig_size=(1140, 160),
    col_width=[0.5, 0.5,0.5, 1.0, 0.7,0.7,0.7,0.9,1,0.9,1.6,1.8,1.8]
)

df2img.save_dataframe(fig=fig, filename="df_assoc_head.png")

# %%
df_origin = pd.read_csv('../data/datasets_all_regions/origin_2010_2015_reloc_cog_ver3.csv',index_col=0)
df_origin.lat = df_origin.lat.round(2)
df_origin.lon = df_origin.lon.round(2)
df_origin.depth = df_origin.depth.round(2)
df_origin.gap = df_origin.gap.round(2)
df_origin.head()
# Out:
#        lat     lon  depth          time  orid  nass  p_picks  s_picks    rms  \
# 0    47.23 -122.17  56.11  1.262305e+09     0     7        2        5  1.081
# 7    48.20 -121.77   3.82  1.262305e+09     1    55       25       30  0.985
# 62   47.86 -122.10  17.80  1.262330e+09     2    28       10       18  0.784
# 90   47.96 -122.92  21.29  1.262336e+09     3    20       10       10  0.465
# 110  45.87 -122.19   9.82  1.262362e+09     4    39       20       19  0.657
#
#      nsphz     gap algorithm
# 0      5.0  235.83     genie
# 7     30.0  201.70     genie
# 62    18.0  181.02     genie
# 90    10.0  150.53     genie
# 110   19.0  237.32     genie

# %%
len(df_origin)
# Out:
# 63887

# %%
fig = df2img.plot_dataframe(
    df_origin.head(),

    tbl_header=dict(
        align="right",
        fill_color="purple",
        font_color="white",
        font_size=10,
        line_color="darkslategray",
    ),
    tbl_cells=dict(
        align="right",
        line_color="darkslategray",
    ),
    row_fill_color=("#ffffff", "#d7d8d6"),
    fig_size=(1100, 160),
    col_width=[0.5,0.8,0.8,0.7,1.4,0.5,0.5,0.6,0.6,0.6,0.6,1.4,0.6]
)

df2img.save_dataframe(fig=fig, filename="df_origin_head.png")

# %%
fig = df2img.plot_dataframe(
    df_origin.head(),

    tbl_header=dict(
        align="right",
        fill_color="purple",
        font_color="white",
        font_size=80,
        line_color="darkslategray",
        height=115
    ),
    tbl_cells=dict(
        align="right",
        line_color="darkslategray",
        font_size=90,
        height=115
    ),
    row_fill_color=("#ffffff", "#d7d8d6"),
    fig_size=(6000, 750),
    col_width=[0.2,0.4,0.4,0.4,1,0.3,0.3,0.4,0.4,0.4,0.4,0.4,0.45]
)

df2img.save_dataframe(fig=fig, filename="df_origin_head.png")
